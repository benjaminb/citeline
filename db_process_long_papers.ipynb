# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage
from llm.models import Findings
import logging

logging.basicConfig(
    filename="logs/long_paper_processing.log",
    filemode="w",
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
)

llm = ChatOllama(
    model="deepseek-r1:70b",
    reasoning=True,
    max_tokens=2048,
    num_ctx=2048,
    temperature=0.0,
).with_structured_output(Findings, method="json_schema")

# Just for testing token lengths
model = ChatOllama(
    model="deepseek-r1:70b",
    reasoning=True,
    max_tokens=2048,
    num_ctx=2048,
    temperature=0.0,
)

with open("llm/prompts/original_contributions.txt", "r") as file:
    sys_prompt = file.read()
system_message = SystemMessage(content=sys_prompt)
print(system_message.content[:1000])

print(f"System message token length: {model.get_num_tokens(system_message.content)}")
# Out:
# You are an expert research assistant. Summarize the original scientific findings of the following research paper. Then write them out as a list of strings.
#
# ## Task
# - Write the findings as a JSON array of strings, each finding being one string element.
# - Do not include acknowledgments or references: focus only on the original research contributions made in this paper
# - Only write out the JSON array, do not include any other text or formatting.
#
# Example output:
# {
#   findings: ["Contribution 1", "Contribution 2", "Contribution 3"]
# }
#
# ## Paper:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# System message token length: 125

# %% [markdown]
# 1. Set up ChatOllama with system prompt to accept a paper and return the findings object
# 1. Set up db client
# 1. Read in the long papers dataset
# 1. Read in the research dataset, filter to long papers only
# 1. Get the DOI's from the contributions table, filter out any in dataset already in db
# 1. for every doi in the dataset, send to ChatOllama to get its findings

# %%
# Get the unique dois from the database contribution table
from database.database import Database

db = Database()
db.test_connection()

results = db.query("SELECT DISTINCT doi FROM contributions")
existing_dois = {row[0] for row in results}
print(f"Number of unique DOIs in contributions: {len(existing_dois)}")
# Out:
# =================================CONFIG=================================
# Database         User             Host                             Port
# citelinedb       bbasseri         localhost                        5432
# ========================================================================
# Database version: ('PostgreSQL 17.5 (Homebrew) on aarch64-apple-darwin24.4.0, compiled by Apple clang version 17.0.0 (clang-1700.0.13.3), 64-bit',)
# Number of unique DOIs in contributions: 4864

# %%
import pandas as pd

research = pd.read_json("data/preprocessed/research.jsonl", lines=True)
long_papers_df = pd.read_json("logs/long_papers.jsonl", lines=True)

def reconstruct_paper(example: pd.Series) -> str:
    return f"{example['title']}\n\nAbstract: {example['abstract']}\n\n{example['body']}"

assert set(long_papers_df.doi).issubset(set(research.doi)), "Long papers DOIs must be a subset of research DOIs"

# %%
import json
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()

def openai_client():
    assert "OPENAI_API_KEY" in os.environ, "OPENAI_API_KEY must be set in .env file"
    client = OpenAI(
        api_key=os.environ["OPENAI_API_KEY"],
        model="gpt-4-1106-preview",
        max_retries=3,
        timeout=60,
    )

# %%
# 3. Read in the long papers dataset
import json

for i, row in long_papers_df.iterrows():
    
    doi = row["doi"]
    if doi in existing_dois:
        continue
    print(f"Processing DOI: {doi}")

    # Get paper from the research df
    paper = None
    try:
        paper = research[research["doi"] == doi].iloc[0]
    except IndexError:
        logging.error(f"DOI {doi} not found in research dataset, skipping.")
        continue
    paper_text = reconstruct_paper(paper)
    print(f"Paper {i + 1} length: {len(paper_text)} characters, {model.get_num_tokens(paper_text)} tokens")
        
    try:
        response = llm.invoke(
            [
                system_message,
                HumanMessage(content=paper_text),
            ]
        )
        with open("long_findings.jsonl", "a") as file:
            file.write(json.dumps({"doi": doi, "findings": response.findings}) + "\n")
    except Exception as e:
        # log the error and save the response for later inspection
        logging.error(f"Error processing DOI {doi} (see long_paper_llm_errors.jsonl): {e}")
        with open("logs/long_paper_llm_errors.jsonl", "a") as file:
            file.write(json.dumps({"doi": doi, "content": json.dumps(response), "error": str(e)}) + "\n")
# Out:
# Processing DOI: 10.1088/0004-637X/794/2/156
# Paper 1 length: 211187 characters, 50206 tokens
# Processing DOI: 10.1088/0004-637X/706/2/1364
# Paper 2 length: 259750 characters, 61079 tokens
# Processing DOI: 10.1086/191823
# Paper 3 length: 307033 characters, 138225 tokens
# Processing DOI: 10.1111/j.1365-2966.2008.12991.x
# Paper 4 length: 257902 characters, 58074 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20937.x
# Paper 5 length: 296922 characters, 67986 tokens
# Processing DOI: 10.1111/j.1365-2966.2007.12671.x
# Paper 6 length: 428161 characters, 102382 tokens
# Processing DOI: 10.12942/lrr-2009-2
# Paper 7 length: 338218 characters, 70508 tokens
# Processing DOI: 10.1103/RevModPhys.82.3121
# Paper 8 length: 287782 characters, 63530 tokens
# Processing DOI: 10.1086/192235
# Paper 9 length: 203303 characters, 68620 tokens
# Processing DOI: 10.1051/0004-6361/202243782
# Paper 10 length: 229744 characters, 54499 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.20043.x
# Paper 11 length: 327951 characters, 81222 tokens
# Processing DOI: 10.1111/j.1365-2966.2010.17064.x
# Paper 12 length: 274813 characters, 62404 tokens
# Processing DOI: 10.1111/j.1365-2966.2005.09865.x
# Paper 13 length: 209215 characters, 47569 tokens
# Processing DOI: 10.1086/191163
# Paper 14 length: 745682 characters, 330876 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19955.x
# Paper 15 length: 525649 characters, 121203 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18795.x
# Paper 16 length: 365752 characters, 113665 tokens
# Processing DOI: 10.1086/499298
# Paper 17 length: 269900 characters, 58279 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19306.x
# Paper 18 length: 335724 characters, 77854 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.20078.x
# Paper 19 length: 195429 characters, 49982 tokens
# Processing DOI: 10.1088/0067-0049/211/2/19
# Paper 20 length: 244476 characters, 53182 tokens
# Processing DOI: 10.1103/RevModPhys.93.015002
# Paper 21 length: 330934 characters, 75433 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18496.x
# Paper 22 length: 309631 characters, 85766 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.20246.x
# Paper 23 length: 322319 characters, 80795 tokens
# Processing DOI: 10.1111/j.1365-2966.2008.13472.x
# Paper 24 length: 200509 characters, 47353 tokens
# Processing DOI: 10.1093/mnras/stz1182
# Paper 25 length: 196638 characters, 47150 tokens
# Processing DOI: 10.1007/978-94-007-5612-0_4
# Paper 26 length: 388109 characters, 101913 tokens
# Processing DOI: 10.1103/RevModPhys.70.1
# Paper 27 length: 268451 characters, 61220 tokens
# Processing DOI: 10.1111/j.1365-2966.2010.17064.x
# Paper 28 length: 274813 characters, 62404 tokens
# Processing DOI: 10.1016/0370-1573(91)90064-S
# Paper 29 length: 411177 characters, 106589 tokens
# Processing DOI: 10.1086/113874
# Paper 30 length: 226584 characters, 91645 tokens
# Processing DOI: 10.1016/j.physrep.2006.08.002
# Paper 31 length: 399349 characters, 85131 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20536.x
# Paper 32 length: 278822 characters, 67816 tokens
# Processing DOI: 10.1111/j.1365-2966.2008.12991.x
# Paper 33 length: 257902 characters, 58074 tokens
# Processing DOI: 10.1086/177101
# Paper 34 length: 199852 characters, 50259 tokens
# Processing DOI: 10.1111/j.1365-2966.2006.10256.x
# Paper 35 length: 216012 characters, 50959 tokens
# Processing DOI: 10.1046/j.1365-8711.2003.06052.x
# Paper 36 length: 205382 characters, 47426 tokens
# Processing DOI: 10.1088/0067-0049/182/1/216
# Paper 37 length: 272728 characters, 64281 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20712.x
# Paper 38 length: 243180 characters, 57332 tokens
# Processing DOI: 10.1021/acsearthspacechem.1c00357
# Paper 39 length: 235044 characters, 60309 tokens
# Processing DOI: 10.1088/0004-637X/794/2/156
# Paper 40 length: 211187 characters, 50206 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19909.x
# Paper 41 length: 226334 characters, 50407 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.21905.x
# Paper 42 length: 378768 characters, 96715 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18725.x
# Paper 43 length: 196564 characters, 50020 tokens
# Processing DOI: 10.1103/RevModPhys.82.451
# Paper 44 length: 198401 characters, 48876 tokens
# Processing DOI: 10.1086/191823
# Paper 45 length: 307033 characters, 138225 tokens
# Processing DOI: 10.12942/lrr-2009-2
# Paper 46 length: 338218 characters, 70508 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19132.x
# Paper 47 length: 282387 characters, 63586 tokens
# Processing DOI: 10.1111/j.1365-2966.2005.09865.x
# Paper 48 length: 209215 characters, 47569 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20595.x
# Paper 49 length: 195343 characters, 46288 tokens
# Processing DOI: 10.1103/RevModPhys.71.173
# Paper 50 length: 286918 characters, 78530 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19213.x
# Paper 51 length: 225812 characters, 54645 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19306.x
# Paper 52 length: 335724 characters, 77854 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18467.x
# Paper 53 length: 390748 characters, 84029 tokens
# Processing DOI: 10.3847/1538-4357/ab9633
# Paper 54 length: 229080 characters, 52364 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18680.x
# Paper 55 length: 289748 characters, 66509 tokens
# Processing DOI: 10.48550/arXiv.astro-ph/9707253
# Paper 56 length: 218815 characters, 59863 tokens
# Processing DOI: 10.1016/j.physrep.2004.08.022
# Paper 57 length: 329980 characters, 76894 tokens
# Processing DOI: 10.1103/RevModPhys.69.995
# Paper 58 length: 499572 characters, 127048 tokens
# Processing DOI: 10.1111/j.1365-2966.2010.18174.x
# Paper 59 length: 278953 characters, 81215 tokens
# Processing DOI: 10.3847/0004-637X/818/2/200
# Paper 60 length: 202041 characters, 44431 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20562.x
# Paper 61 length: 303615 characters, 71449 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19538.x
# Paper 62 length: 233745 characters, 53102 tokens
# Processing DOI: 10.1126/science.aan0106
# Paper 63 length: 198632 characters, 78677 tokens
# Processing DOI: 10.48550/arXiv.2203.09562
# Paper 64 length: 200326 characters, 53602 tokens
# Processing DOI: 10.1086/133630
# Paper 65 length: 250571 characters, 66212 tokens
# Processing DOI: 10.48550/arXiv.1511.03457
# Paper 66 length: 985035 characters, 248054 tokens
# Processing DOI: 10.1088/0004-637X/706/2/1364
# Paper 67 length: 259750 characters, 61079 tokens
# Processing DOI: 10.1086/191163
# Paper 68 length: 745682 characters, 330876 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.20078.x
# Paper 69 length: 195429 characters, 49982 tokens
# Processing DOI: 10.1016/j.physrep.2014.02.001
# Paper 70 length: 480060 characters, 120603 tokens
# Processing DOI: 10.1051/0004-6361/202243782
# Paper 71 length: 229744 characters, 54499 tokens
# Processing DOI: 10.1103/RevModPhys.76.125
# Paper 72 length: 365365 characters, 90326 tokens
# Processing DOI: 10.1088/0004-637X/734/2/96
# Paper 73 length: 243960 characters, 63742 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.21697.x
# Paper 74 length: 221172 characters, 54388 tokens
# Processing DOI: 10.1088/0004-637X/749/2/157
# Paper 75 length: 272789 characters, 63502 tokens
# Processing DOI: 10.1103/RevModPhys.77.207
# Paper 76 length: 220354 characters, 45471 tokens
# Processing DOI: 10.1017/pasa.2018.29
# Paper 77 length: 239604 characters, 54202 tokens
# Processing DOI: 10.1111/j.1365-2966.2010.17992.x
# Paper 78 length: 280672 characters, 65889 tokens
# Processing DOI: 10.1111/j.1365-2966.2005.09981.x
# Paper 79 length: 203274 characters, 46818 tokens
# Processing DOI: 10.1051/0004-6361/201833910
# Paper 80 length: 302971 characters, 70250 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.20337.x
# Paper 81 length: 331917 characters, 75731 tokens
# Processing DOI: 10.1086/191522
# Paper 82 length: 200859 characters, 52257 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19583.x
# Paper 83 length: 254632 characters, 61312 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18795.x
# Paper 84 length: 365752 characters, 113665 tokens
# Processing DOI: 10.1086/499298
# Paper 85 length: 269900 characters, 58279 tokens
# Processing DOI: 10.1111/j.1365-2966.2006.10989.x
# Paper 86 length: 250169 characters, 55127 tokens
# Processing DOI: 10.48550/arXiv.astro-ph/0609591
# Paper 87 length: 237801 characters, 56609 tokens
# Processing DOI: 10.1103/RevModPhys.82.3121
# Paper 88 length: 287782 characters, 63530 tokens
# Processing DOI: 10.1111/j.1365-2966.2009.15715.x
# Paper 89 length: 520371 characters, 108882 tokens
# Processing DOI: 10.48550/arXiv.1709.09066
# Paper 90 length: 292974 characters, 77355 tokens
# Processing DOI: 10.1111/j.1365-2966.2009.14506.x
# Paper 91 length: 328996 characters, 79851 tokens
# Processing DOI: 10.3847/1538-4365/aaa297
# Paper 92 length: 411660 characters, 103592 tokens
# Processing DOI: 10.1086/511753
# Paper 93 length: 229797 characters, 51835 tokens
# Processing DOI: 10.1016/0370-1573(95)00058-5
# Paper 94 length: 511124 characters, 133406 tokens
# Processing DOI: 10.1016/S0370-1573(97)00048-3
# Paper 95 length: 279255 characters, 105526 tokens
# Processing DOI: 10.1103/RevModPhys.74.1015
# Paper 96 length: 254027 characters, 66571 tokens
# Processing DOI: 10.3389/fspas.2019.00051
# Paper 97 length: 226472 characters, 57852 tokens
# Processing DOI: 10.1007/s10686-008-9124-7
# Paper 98 length: 275180 characters, 58371 tokens
# Processing DOI: 10.1103/RevModPhys.93.015001
# Paper 99 length: 287363 characters, 62602 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18497.x
# Paper 100 length: 195580 characters, 47598 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.20022.x
# Paper 101 length: 218643 characters, 50184 tokens
# Processing DOI: 10.1088/0034-4885/75/8/086901
# Paper 102 length: 198136 characters, 47265 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19536.x
# Paper 103 length: 558305 characters, 133771 tokens
# Processing DOI: 10.1093/mnras/stv195
# Paper 104 length: 230040 characters, 52296 tokens
# Processing DOI: 10.1017/pasa.2017.51
# Paper 105 length: 211557 characters, 45365 tokens
# Processing DOI: 10.1111/j.1365-2966.2007.12256.x
# Paper 106 length: 205325 characters, 45785 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19955.x
# Paper 107 length: 525649 characters, 121203 tokens
# Processing DOI: 10.1086/191601
# Paper 108 length: 325102 characters, 143556 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.20043.x
# Paper 109 length: 327951 characters, 81222 tokens
# Processing DOI: 10.1051/0004-6361:20052967
# Paper 110 length: 360459 characters, 166237 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18842.x
# Paper 111 length: 242588 characters, 59578 tokens
# Processing DOI: 10.1086/192235
# Paper 112 length: 203303 characters, 68620 tokens
# Processing DOI: 10.1016/j.physrep.2013.05.004
# Paper 113 length: 345788 characters, 72125 tokens
# Processing DOI: 10.1086/190932
# Paper 114 length: 219030 characters, 55079 tokens
# Processing DOI: 10.1111/j.1365-2966.2010.18080.x
# Paper 115 length: 231025 characters, 54333 tokens
# Processing DOI: 10.3389/fspas.2019.00054
# Paper 116 length: 196191 characters, 49157 tokens
# Processing DOI: 10.1103/RevModPhys.86.47
# Paper 117 length: 285371 characters, 63558 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.21923.x
# Paper 118 length: 531556 characters, 125614 tokens
# Processing DOI: 10.1016/j.physrep.2005.06.005
# Paper 119 length: 465414 characters, 104265 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18598.x
# Paper 120 length: 247680 characters, 63107 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.21512.x
# Paper 121 length: 247429 characters, 60681 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18560.x
# Paper 122 length: 301232 characters, 82490 tokens
# Processing DOI: 10.1017/pasa.2021.18
# Paper 123 length: 203514 characters, 43571 tokens
# Processing DOI: 10.1111/j.1365-2966.2007.12671.x
# Paper 124 length: 428161 characters, 102382 tokens
# Processing DOI: 10.1086/191396
# Paper 125 length: 231520 characters, 58315 tokens
# Processing DOI: 10.1016/S0370-1573(02)00276-4
# Paper 126 length: 221968 characters, 49329 tokens
# Processing DOI: 10.3847/1538-4357/aa633b
# Paper 127 length: 223433 characters, 53440 tokens
# Processing DOI: 10.1103/PhysRevD.74.123507
# Paper 128 length: 222319 characters, 46615 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.21045.x
# Paper 129 length: 297813 characters, 65574 tokens
# Processing DOI: 10.1111/j.1365-2966.2007.11963.x
# Paper 130 length: 215674 characters, 48766 tokens
# Processing DOI: 10.1016/j.physrep.2022.04.005
# Paper 131 length: 299323 characters, 63772 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20937.x
# Paper 132 length: 296922 characters, 67986 tokens
# Processing DOI: 10.1093/mnras/sty1690
# Paper 133 length: 291840 characters, 66336 tokens
# Processing DOI: 10.1111/j.1365-2966.2006.10256.x
# Paper 134 length: 216012 characters, 50959 tokens
# Processing DOI: 10.1086/191163
# Paper 135 length: 745682 characters, 330876 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19306.x
# Paper 136 length: 335724 characters, 77854 tokens
# Processing DOI: 10.1016/0370-1573(95)00055-0
# Paper 137 length: 206339 characters, 51802 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20595.x
# Paper 138 length: 195343 characters, 46288 tokens
# Processing DOI: 10.1111/j.1365-2966.2010.17064.x
# Paper 139 length: 274813 characters, 62404 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18680.x
# Paper 140 length: 289748 characters, 66509 tokens
# Processing DOI: 10.1017/pasa.2021.18
# Paper 141 length: 203514 characters, 43571 tokens
# Processing DOI: 10.1103/RevModPhys.70.1
# Paper 142 length: 268451 characters, 61220 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20712.x
# Paper 143 length: 243180 characters, 57332 tokens
# Processing DOI: 10.1093/mnras/stab3673
# Paper 144 length: 203209 characters, 43984 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.20078.x
# Paper 145 length: 195429 characters, 49982 tokens
# Processing DOI: 10.1111/j.1365-2966.2007.11963.x
# Paper 146 length: 215674 characters, 48766 tokens
# Processing DOI: 10.1016/0370-1573(91)90064-S
# Paper 147 length: 411177 characters, 106589 tokens
# Processing DOI: 10.1086/191396
# Paper 148 length: 231520 characters, 58315 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19955.x
# Paper 149 length: 525649 characters, 121203 tokens
# Processing DOI: 10.1086/190932
# Paper 150 length: 219030 characters, 55079 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19213.x
# Paper 151 length: 225812 characters, 54645 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19815.x
# Paper 152 length: 236416 characters, 54286 tokens
# Processing DOI: 10.1007/s10509-009-9987-8
# Paper 153 length: 260543 characters, 73620 tokens
# Processing DOI: 10.3847/1538-4357/aa633b
# Paper 154 length: 223433 characters, 53440 tokens
# Processing DOI: 10.1016/j.physrep.2022.04.005
# Paper 155 length: 299323 characters, 63772 tokens
# Processing DOI: 10.1086/192235
# Paper 156 length: 203303 characters, 68620 tokens
# Processing DOI: 10.1103/RevModPhys.77.207
# Paper 157 length: 220354 characters, 45471 tokens
# Processing DOI: 10.1088/0067-0049/211/2/19
# Paper 158 length: 244476 characters, 53182 tokens
# Processing DOI: 10.1086/113874
# Paper 159 length: 226584 characters, 91645 tokens
# Processing DOI: 10.1088/0004-637X/794/2/156
# Paper 160 length: 211187 characters, 50206 tokens
# Processing DOI: 10.1016/j.physrep.2006.08.002
# Paper 161 length: 399349 characters, 85131 tokens
# Processing DOI: 10.1111/j.1365-2966.2009.14506.x
# Paper 162 length: 328996 characters, 79851 tokens
# Processing DOI: 10.1021/acsearthspacechem.1c00357
# Paper 163 length: 235044 characters, 60309 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18467.x
# Paper 164 length: 390748 characters, 84029 tokens
# Processing DOI: 10.1111/j.1365-2966.2008.13132.x
# Paper 165 length: 258808 characters, 62313 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20562.x
# Paper 166 length: 303615 characters, 71449 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.20043.x
# Paper 167 length: 327951 characters, 81222 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18795.x
# Paper 168 length: 365752 characters, 113665 tokens
# Processing DOI: 10.1086/191321
# Paper 169 length: 220974 characters, 74074 tokens
# Processing DOI: 10.1016/j.physrep.2005.06.005
# Paper 170 length: 465414 characters, 104265 tokens
# Processing DOI: 10.1103/RevModPhys.82.451
# Paper 171 length: 198401 characters, 48876 tokens
# Processing DOI: 10.48550/arXiv.astro-ph/0609591
# Paper 172 length: 237801 characters, 56609 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.18560.x
# Paper 173 length: 301232 characters, 82490 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.21396.x
# Paper 174 length: 383686 characters, 89362 tokens
# Processing DOI: 10.1103/RevModPhys.82.3121
# Paper 175 length: 287782 characters, 63530 tokens
# Processing DOI: 10.1103/RevModPhys.71.173
# Paper 176 length: 286918 characters, 78530 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20944.x
# Paper 177 length: 302331 characters, 77985 tokens
# Processing DOI: 10.1093/mnras/stz1182
# Paper 178 length: 196638 characters, 47150 tokens
# Processing DOI: 10.3389/fspas.2019.00054
# Paper 179 length: 196191 characters, 49157 tokens
# Processing DOI: 10.1111/j.1365-2966.2007.12671.x
# Paper 180 length: 428161 characters, 102382 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.21905.x
# Paper 181 length: 378768 characters, 96715 tokens
# Processing DOI: 10.1111/j.1365-2966.2011.19538.x
# Paper 182 length: 233745 characters, 53102 tokens
# Processing DOI: 10.1086/511753
# Paper 183 length: 229797 characters, 51835 tokens
# Processing DOI: 10.48550/arXiv.2203.09562
# Paper 184 length: 200326 characters, 53602 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.21045.x
# Paper 185 length: 297813 characters, 65574 tokens
# Processing DOI: 10.1111/j.1365-2966.2012.20536.x
# Paper 186 length: 278822 characters, 67816 tokens
# Processing DOI: 10.48550/arXiv.1511.03457
# Paper 187 length: 985035 characters, 248054 tokens
# Processing DOI: 10.1016/0370-1573(95)00058-5
# Paper 188 length: 511124 characters, 133406 tokens
# Processing DOI: 10.1093/mnras/stv195
# Paper 189 length: 230040 characters, 52296 tokens
# Processing DOI: 10.1086/177101
# Paper 190 length: 199852 characters, 50259 tokens
# Processing DOI: 10.1103/RevModPhys.93.015001
# Paper 191 length: 287363 characters, 62602 tokens
# Processing DOI: 10.1103/RevModPhys.74.1015
# Paper 192 length: 254027 characters, 66571 tokens
# Processing DOI: 10.1016/S0370-1573(97)00048-3
# Paper 193 length: 279255 characters, 105526 tokens
# Processing DOI: 10.1088/0004-637X/749/2/157
# Paper 194 length: 272789 characters, 63502 tokens
# Processing DOI: 10.1007/s41114-022-00040-z
# Paper 195 length: 445892 characters, 99094 tokens
# Processing DOI: 10.1051/0004-6361/201833910
# Paper 196 length: 302971 characters, 70250 tokens
# Processing DOI: 10.1111/j.1365-2966.2006.10989.x
# Paper 197 length: 250169 characters, 55127 tokens
# Processing DOI: 10.1086/191357
# Paper 198 length: 228600 characters, 67510 tokens
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 22
#      19 print(f"Paper {i + 1} length: {len(paper_text)} characters, {model.get_num_tokens(paper_text)} tokens")
#      21 try:
# ---> 22     response = llm.invoke(
#      23         [
#      24             system_message,
#      25             HumanMessage(content=paper_text),
#      26         ]
#      27     )
#      28     with open("long_findings.jsonl", "a") as file:
#      29         file.write(json.dumps({"doi": doi, "findings": response.findings}) + "\n")
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/langchain_core/runnables/base.py:3045, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3043 with set_config_context(config) as context:
#    3044     if i == 0:
# -> 3045         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046     else:
#    3047         input_ = context.run(step.invoke, input_, config)
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/langchain_core/runnables/base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)
#     954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/langchain_ollama/chat_models.py:715, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     708 def _generate(
#     709     self,
#     710     messages: list[BaseMessage],
#    (...)
#     713     **kwargs: Any,
#     714 ) -> ChatResult:
# --> 715     final_chunk = self._chat_stream_with_aggregation(
#     716         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     717     )
#     718     generation_info = final_chunk.generation_info
#     719     chat_generation = ChatGeneration(
#     720         message=AIMessage(
#     721             content=final_chunk.text,
#    (...)
#     726         generation_info=generation_info,
#     727     )
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/langchain_ollama/chat_models.py:652, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     643 def _chat_stream_with_aggregation(
#     644     self,
#     645     messages: list[BaseMessage],
#    (...)
#     649     **kwargs: Any,
#     650 ) -> ChatGenerationChunk:
#     651     final_chunk = None
# --> 652     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     653         if final_chunk is None:
#     654             final_chunk = chunk
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/langchain_ollama/chat_models.py:737, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     730 def _iterate_over_stream(
#     731     self,
#     732     messages: list[BaseMessage],
#     733     stop: Optional[list[str]] = None,
#     734     **kwargs: Any,
#     735 ) -> Iterator[ChatGenerationChunk]:
#     736     is_thinking = False
# --> 737     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     738         if not isinstance(stream_resp, str):
#     739             if stream_resp.get("done") is True:
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/langchain_ollama/chat_models.py:639, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     636 chat_params = self._chat_params(messages, stop, **kwargs)
#     638 if chat_params["stream"]:
# --> 639     yield from self._client.chat(**chat_params)
#     640 else:
#     641     yield self._client.chat(**chat_params)
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/ollama/_client.py:163, in Client._request.<locals>.inner()
#     162 def inner():
# --> 163   with self._client.stream(*args, **kwargs) as r:
#     164     try:
#     165       r.raise_for_status()
#
# File ~/miniforge3/envs/citeline/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpx/_client.py:880, in Client.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     857 """
#     858 Alternative to `httpx.request()` that streams the response body
#     859 instead of loading it into memory at once.
#    (...)
#     865 [0]: /quickstart#streaming-responses
#     866 """
#     867 request = self.build_request(
#     868     method=method,
#     869     url=url,
#    (...)
#     878     extensions=extensions,
#     879 )
# --> 880 response = self.send(
#     881     request=request,
#     882     auth=auth,
#     883     follow_redirects=follow_redirects,
#     884     stream=True,
#     885 )
#     886 try:
#     887     yield response
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniforge3/envs/citeline/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
