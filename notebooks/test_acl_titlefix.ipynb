# %%
import difflib
import re


with open("../src/citeline/helpers/acl_20251219_113235.log", "r") as f:
    log_data = f.readlines()

pattern = re.compile(r"No close matches found for title: (.*?) among fuzzy candidates")

# %%
with open("../src/citeline/helpers/acl_20251219_123521.log", "r") as f:
    log_data = f.readlines()

error_lines, warning_lines = [], []
for line in log_data:
    if "- ERROR -" in line:
        error_lines.append(line)
    elif "- WARNING -" in line:
        warning_lines.append(line)

print(f"Got {len(error_lines)} error lines")
print(f"Got {len(warning_lines)} warning")
# Out:
# Got 2 error lines
# Got 264 warning

# %%
pattern = re.compile(r"Multiple matches on '(.*?)'; choosing (.*?)$")
title_pairs = [m.groups() for line in warning_lines if (m := re.search(pattern, line))]
for i in range(3):
    print(title_pairs[i])
# Out:
# ('A Shallow Model of Backchannel Continuers in Spoken Dialogue', 'A model of back-channel acknowledgements in spoken dialogue')
# ('Going to the Roots of Dependency Parsing', 'Squibs: Going to the Roots of Dependency Parsing')
# ('DESIGN OF LMT: A PROLOG-BASED MACHINE TRANSLATION SYSTEMMichael C. McCord', 'Design of LMT: A Prolog-Based Machine Translation System')

# %%
title_pairs.sort(key=lambda x: difflib.SequenceMatcher(None, x[0].lower(), x[1].lower()).ratio())

# %%
for query, chosen in title_pairs:
    ratio = difflib.SequenceMatcher(None, query.lower(), chosen.lower()).ratio()
    print(f"Query: {query}\nChosen: {chosen}\nSimilarity ratio: {ratio:.4f}\n----")
# Out:
# Query: asherecgs.ut exas .edu
# Chosen: Speech Data Base
# Similarity ratio: 0.1579
# ----
# Query: Grammar-based Corpus AnnotationStefanie DipperInstitut fiir maschinelle SprachverarbeitungUniversitat Stuttgart
# Chosen: Grammar-Based Concept Alignment for Domain-Specific Machine Translation
# Similarity ratio: 0.3077
# ----
# Query: Inducing Temporal GraphsPhilip Bramsen Pawan Deshpande Yoong Keok Lee Regina BarzilayMIT CSAIL MIT CSAIL DSO National Laboratories MIT CSAIL
# Chosen: Proceedings of TextGraphs-9: the workshop on Graph-based Methods for Natural Language Processing
# Similarity ratio: 0.3390
# ----
# Query: European Media Lab GmbHSchloss-Wolfsbrunnenweg 31cD-69118 Heidelberg, Germany
# Chosen: Sequence Reducible Holdout Loss for Language Model Pretraining
# Similarity ratio: 0.3453
# ----
# Query: Cb or not Cb? Centering theory applied to NLGRodger KibbleInformation Technology Research InstituteUniversity of BrightonLewes RoadBrighton BN2 4GJ
# Chosen: Proceedings of the First Workshop on Language-driven Deliberation Technology (DELITE) @ LREC-COLING 2024
# Similarity ratio: 0.3506
# ----
# Query: Official Translation Literal Translation ECB Europarl Europarl ECB Europarl Europarl
# Chosen: iTranslate4.eu: Internet translators for all European languages.
# Similarity ratio: 0.3514
# ----
# Query: Semiautomatic creation of taxonomiesJavier Farreres and Horacio Rodríguezfarreres@lsi.upc.es and horacio@lsi.upc.esDepartment of Computer Languages and SystemsUniversitat Politècnica de Catalunya
# Chosen: Joint Satisfaction of Syntactic and Pragmatic Constraints Improves Incremental Spoken Language Understanding
# Similarity ratio: 0.3630
# ----
# Query: Barbara RosarioSIMSUC BerkeleyBerkeley, CA 94720
# Chosen: CaRB: A Crowdsourced Benchmark for Open IE
# Similarity ratio: 0.3778
# ----
# Query: Parsing into Discourse Object DescriptionsLars AhrenbergDepartment of Computer and Information ScienceLinkoping UniversityS - 581 83 Linkoping
# Chosen: Exploring the Role of Context to Distinguish Rhetorical and Information-Seeking Questions
# Similarity ratio: 0.3810
# ----
# Query: HANDLING SCOPE AMBIGUITIES IN ENGLISHSven HurumDepartment of Computing Science615 General Services BuildingUniversity of AlbertaEdmonton, Canada T6G 2H1
# Chosen: Disambiguation of English PP attachment using multilingual aligned data
# Similarity ratio: 0.4036
# ----
# Query: Overview of the 2nd Workshop on Asian Translation Toshiaki Hideya Isao Goto NHK Japan Science National Institute goto.i-es@nhk.or.jp Technology Agency Information nakazawa@pa.jst.jp Communications
# Chosen: Proceedings of the Workshop on Learning Structured Information in Natural Language Applications
# Similarity ratio: 0.4055
# ----
# Query: Statistical Machine ReorderingMarta R. Costa-juss`a and Jos´e A. R. FonollosaDepartment of Signal Theory and CommunicationsTALP Research Center (UPC)Barcelona 08034, Spain
# Chosen: Statistical Machine Translation: Foundations and Recent Advances
# Similarity ratio: 0.4085
# ----
# Query: DICTIONARIES OF THE MINDGeorge A. MillerDepartment of PsychologyPrinceton UniversityPrinceton, NJ 08544, USA
# Chosen: A Computational Treatment of Coordinate Conjunctions
# Similarity ratio: 0.4250
# ----
# Query: Two graph-based algorithms for state-of-the-art WSDEneko Agirre, David Martinez, Oier L´opez de Lacalle and Aitor SoroaIXA NLP GroupUniversity of the Basque CountryDonostia, Basque Contry
# Chosen: Two graph-based algorithms for state-of-the-art WSD
# Similarity ratio: 0.4286
# ----
# Query: Dijkstra-WSA: A Graph-Based Approach to Word Sense AlignmentMichael Matuschek $ and Iryna Gurevych †$† Ubiquitous Knowledge Processing Lab (UKP-DIPF),German Institute for Educational Research and Educational Information
# Chosen: Dijkstra-WSA: A Graph-Based Approach to Word Sense Alignment
# Similarity ratio: 0.4301
# ----
# Query: a. Forward Functional Application (f a>)X/Y Y => Xb. Backward Functional Application Cf a<)Y X\Y => X
# Chosen: Educational implications of a machine translation system
# Similarity ratio: 0.4331
# ----
# Query: Text Modification for Bulgarian Sign Language UsersSlavina Lozanova* Ivelina Stoyanovat Svetlozara Lesevatslavinal@abv.bg iva@dcl.bas.bg zarka@dcl.bas.bgSvetla Koevat Boian Savtchevt
# Chosen: Text Modification for Bulgarian Sign Language Users
# Similarity ratio: 0.4378
# ----
# Query: Improving Arabic Diacritization through Syntactic AnalysisAnas Shahrour, Salam Khalifa and Nizar HabashComputational Approaches to Modeling Language LabNew York University Abu DhabiUnited Arab Emirates
# Chosen: Improving Arabic Diacritization through Syntactic Analysis
# Similarity ratio: 0.4479
# ----
# Query: ' Faculty of Mathematics and Computer Science, University of Bremen, Germany2 Cyber-Physical Systems, DFKI GmbH, Bremen, Germany
# Chosen: The Edit Distance Transducer in Action: The University of Cambridge English-German System at WMT16
# Similarity ratio: 0.4602
# ----
# Query: Joint Bayesian Morphology learning for Dravidian languagesArun Kumar Lluís Padró Antoni OliverUniversitat Oberta de Universitat Politècnica de Universitat Oberta deCatalunya Catalunya Catalunya
# Chosen: Joint Bayesian Morphology Learning for Dravidian Languages
# Similarity ratio: 0.4622
# ----
# Query: Statistical Phrase-based Post-editingMichel Simard Cyril Goutte Pierre IsabelleInteractive Language TechnologiesNational Research Council of Canada
# Chosen: Statistical Phrase-Based Models for Interactive Computer-Assisted Translation
# Similarity ratio: 0.4643
# ----
# Query: Automated Essay Scoring for Nonnative English SpeakersJill Burstein Martin ChodorowEducational Testing Service Hunter College, CUNYPrinceton, New Jersey 08540 New York, New York
# Chosen: Automated Essay Scoring for Nonnative English Speakers
# Similarity ratio: 0.4675
# ----
# Query: Nominal Metonymy ProcessingBoyan OnyshkevychUS Department of DefenseFort Meade MD 20755
# Chosen: Nominal Metonymy Processing
# Similarity ratio: 0.4737
# ----
# Query: Adverse—Effect Relations Extraction fromMassive Clinical RecordsYasuhide Miura a, Eiji Aramaki b, Tomoko Ohkuma a, Masatsugu Tonoike a,Daigo Sugihara &quot;, Hiroshi Masuichi&quot; and Kazuhiko Ohe `
# Chosen: Adverse-Effect Relations Extraction from Massive Clinical Records
# Similarity ratio: 0.4773
# ----
# Query: What’s in a Message?Stergos D. Afantenos and Nicolas Hernandez
# Chosen: What’s in a name? In some languages, grammatical gender
# Similarity ratio: 0.4786
# ----
# Query: Michael B. KacDepartment of LinguisticsUniversity of MinnesotaMinneapolis, Minnesota 55455
# Chosen: A Measure for Transparent Comparison of Linguistic Diversity in Multilingual NLP Data Sets
# Similarity ratio: 0.4889
# ----
# Query: Treating Coordination in Logic GrammarsVeronica DahllComputing Sciences DepartmentSimon Fraser UniversityBurnaby, B.C. V5A 1S6
# Chosen: Teaching machine translation in non computer science subjects: report of an educational experience within the University of Orleans
# Similarity ratio: 0.4903
# ----
# Query: Using Scenario Knowledge in Automatic Question AnsweringSanda Harabagiu and Andrew HicklLanguage Computer Corporation1701 North Collins BoulevardRichardson, Texas 75080 USA
# Chosen: Using Scenario Knowledge in Automatic Question Answering
# Similarity ratio: 0.4912
# ----
# Query: Desiderata for Tagging with WordNet Synsets or MCCA CategoriesKenneth C. LitkowskiCL Research20239 Lea Pond PlaceGaithersburg, MD 20879(Email: ken@clres.com)(Web site: http://www.clres.com)
# Chosen: Desiderata for Tagging with WordNet Synsets or MCCA Categories
# Similarity ratio: 0.4940
# ----
# Query: Metonymy as a Cross-lingual PhenomenonWim PetersNLP GroupDepartment of Computer ScienceUniversity of SheffieldRegent Court211 Portobello Street
# Chosen: PROTEUS and PUNDIT: RESEARCH IN TEXT UNDERSTANDING at the Department of Computer Science, New York University and System Development Corporation -- A Burroughs Company
# Similarity ratio: 0.4968
# ----
# Query: Recovery Strategies forParsing Extragrammatical LanguagelJaime G. Carbonell and Philip J. HayesComputer Science DepartmentCarnegie-Mellon UniversityPittsburgh, PA 15213
# Chosen: Recovery Strategies for Parsing Extragrammatical Language
# Similarity ratio: 0.4978
# ----
# Query: A Knowledge Representation Approachto Understanding MetaphorsE. Judith WeinerComputer and Information SciencesComputer Activity BuildingTemple UniversityPhiladelphia, PA 19122
# Chosen: A Knowledge Representation Approach to Understanding Metaphors
# Similarity ratio: 0.5148
# ----
# Query: Wiktionary and NLP: Improving synonymy networks
# Chosen: The Topology of Synonymy and Homonymy Networks
# Similarity ratio: 0.5161
# ----
# Query: Investigating Cue Selection and Placement in Tutorial DiscourseMegan MoserLearning Research & Dev. Center,and Department of LinguisticsUniversity of PittsburghPittsburgh, PA 15260
# Chosen: Investigating Cue Selection and Placement in Tutorial Discourse
# Similarity ratio: 0.5207
# ----
# Query: System Precision Recall
# Chosen: ICT: System Description for CoNLL-2012
# Similarity ratio: 0.5246
# ----
# Query: Evaluating Centering for Sentence Ordering in Two New DomainsNikiforos KaramanisNatural Language and Information Processing GroupComputer LaboratoryUniversity of Cambridge
# Chosen: Evaluating Centering for Sentence Ordering in Two New Domains
# Similarity ratio: 0.5259
# ----
# Query: How Creative is Your Writing? A Linguistic Creativity Measure fromComputer Science and Cognitive Psychology Perspectives
# Chosen: Austrian German – Linguistic, Normative and Political Perspectives
# Similarity ratio: 0.5269
# ----
# Query: The Pragmatics of Referring andthe Modality of Communication'Philip R. CohenLaboratory for Artificial Intelligence ResearchFairchild Camera and Instrument Corporation
# Chosen: The Pragmatics of Referring and the Modality of Communication
# Similarity ratio: 0.5286
# ----
# Query: Estimation of ConsistentProbabilistic Context-free GrammarsMark-Jan NederhofMax Planck Institutefor PsycholinguisticsP.O. Box 310NL-6500 AH NijmegenThe Netherlands
# Chosen: Estimation of Consistent Probabilistic Context-free Grammars
# Similarity ratio: 0.5291
# ----
# Query: Methods for Using Textual Entailment inOpen-Domain Question AnsweringSanda Harabagiu and Andrew HicklLanguage Computer Corporation1701 North Collins BoulevardRichardson, Texas 75080 USA
# Chosen: Methods for Using Textual Entailment in Open-Domain Question Answering
# Similarity ratio: 0.5412
# ----
# Query: Obituary
# Chosen: Obituary: Ivan A. Sag
# Similarity ratio: 0.5517
# ----
# Query: Interpreter
# Chosen: On the Present
# Similarity ratio: 0.5600
# ----
# Query: Customizing sentiment classifiers to new domains: a case study.
# Chosen: Multi-domain Sentiment Classification
# Similarity ratio: 0.5600
# ----
# Query: French Induced Tag Correct Tag NNS NNS
# Chosen: Text Induced Spelling Correction
# Similarity ratio: 0.5714
# ----
# Query: Multilingual Term Extraction from Domain-specific CorporaUsing Morphological StructureDelphine BernhardTIMC-IMAGInstitut de l’Ing´enierie et de l’Information de Sant´eFacult´e de M´edecineF-38706 LA TRONCHE cedex
# Chosen: Multilingual Term Extraction from Domain-specific Corpora Using Morphological Structure
# Similarity ratio: 0.5753
# ----
# Query: A Computational Model of Text Reuse in Ancient Literary TextsJohn LeeSpoken Language SystemsMIT Computer Science and Artificial Intelligence Laboratory
# Chosen: A Computational Model of Text Reuse in Ancient Literary Texts
# Similarity ratio: 0.5755
# ----
# Query: Making Grammar-Based Generation Easier to Deploy in Dialogue SystemsDavid DeVault and David Traum and Ron ArtsteinUSC Institute for Creative Technologies13274 Fiji Way
# Chosen: Making Grammar-Based Generation Easier to Deploy in Dialogue Systems
# Similarity ratio: 0.5787
# ----
# Query: An API for Measuring the Relatedness of Words in WikipediaSimone Paolo Ponzetto and Michael StrubeEML Research gGmbHSchloss-Wolfsbrunnenweg 33
# Chosen: An API for Measuring the Relatedness of Words in Wikipedia
# Similarity ratio: 0.5800
# ----
# Query: Visualization of Linguistic PatternsandUncovering Language History from Multilingual Resources
# Chosen: Automatic Extraction of Syntactic Semantic Patterns for Multilingual Resources
# Similarity ratio: 0.5814
# ----
# Query: Source Language Text Transformation | J Global Search: Lexicon Model  |I Alignment Model Language Model Transformation
# Chosen: Source Language Categorization for improving a Speech into Sign Language Translation System
# Similarity ratio: 0.5837
# ----
# Query: Multi-level Dialogue Act TagsAlexander Clark and Andrei Popescu-Belis
# Chosen: Multi-level Dialogue Act Tags
# Similarity ratio: 0.5918
# ----
# Query: a unique p all Relation
# Chosen: Syntax in universal translation
# Similarity ratio: 0.5926
# ----
# Query: Incremental Structured Prediction Using a Global Learning andBeam-Search Framework
# Chosen: Structured Prediction via Learning to Search under Bandit Feedback
# Similarity ratio: 0.5946
# ----
# Query: Tools for corpus-aided lexicography: the HECTOR project.
# Chosen: Methods and Tools for Corpus Lexicography
# Similarity ratio: 0.5979
# ----
# Query: Generation of Output Style Variation in the SAMMIE Dialogue System
# Chosen: Information Presentation in Spoken Dialogue Systems
# Similarity ratio: 0.5983
# ----
# Query: Geometry and Meaning
# Chosen: Transfers of Meaning
# Similarity ratio: 0.6000
# ----
# Query: Multiword Expressions: Identifying and Exploiting
# Chosen: Multiword Expressions in Machine Translation
# Similarity ratio: 0.6022
# ----
# Query: in Bayesian networks. In of the IBERAMIA Workshop on Probabilistic Reasoning Artificial Intelligence, Paulo,
# Chosen: Proceedings of the Third Workshop on Multimodal Artificial Intelligence
# Similarity ratio: 0.6034
# ----
# Query: Association for Computational LinguisticsSemantic Parsing Based on FrameNet
# Chosen: Findings of the Association for Computational Linguistics: EMNLP 2025
# Similarity ratio: 0.6250
# ----
# Query: 2 Discourse analysis with the RST Discourse Treebank
# Chosen: Developing the Bangla RST Discourse Treebank
# Similarity ratio: 0.6250
# ----
# Query: Shared Task
# Chosen: The FEVER2.0 Shared Task
# Similarity ratio: 0.6286
# ----
# Query: BioNLP Shared Task 2013: Supporting ResourcesPontus Stenetorp 1 Wiktoria Golik 2 Thierry Hamon 3
# Chosen: BioNLP Shared Task 2013: Supporting Resources
# Similarity ratio: 0.6383
# ----
# Query: GIST-IT: Summarizing Email Using Linguistic Knowledge and MachineLearning
# Chosen: Trainable, Scalable Summarization Using Robust NLP and Machine Learning
# Similarity ratio: 0.6389
# ----
# Query: Towards universal quantification in distributional semantic space
# Chosen: Functional Distributional Semantics
# Similarity ratio: 0.6400
# ----
# Query: Last Words
# Chosen: Latvian WordNet
# Similarity ratio: 0.6400
# ----
# Query: Tailoring Explanations for the User
# Chosen: Learning Explanations from Language Data
# Similarity ratio: 0.6400
# ----
# Query: Typed Graph Models for Semi-Supervised Learning of Name Ethnicity
# Chosen: Data Selection in Semi-supervised Learning for Name Tagging
# Similarity ratio: 0.6452
# ----
# Query: BioNLP Shared Task 2011: Supporting ResourcesPontus Stenetorp*t Goran Topi´c* Sampo Pyysalo*
# Chosen: BioNLP Shared Task 2011: Supporting Resources
# Similarity ratio: 0.6569
# ----
# Query: Phrasal: A Toolkit for Statistical Machine Translationwith Facilities for Extraction and Incorporation of Arbitrary Model Features
# Chosen: Phrasal: A Statistical Machine Translation Toolkit for Exploring New Model Features
# Similarity ratio: 0.6573
# ----
# Query: Association for Computational LinguisticsThe R2D2 Team at SENSEVAL-3∗
# Chosen: Findings of the Association for Computational Linguistics: EMNLP 2023
# Similarity ratio: 0.6667
# ----
# Query: Towards Exhaustive Protein Modification Event Extraction
# Chosen: Towards Exhaustive Event Extraction for Protein Modifications
# Similarity ratio: 0.6667
# ----
# Query: SSA-UO: Unsupervised Twitter Sentiment Analysis
# Chosen: SAP-RI: Twitter Sentiment Analysis in Two Days
# Similarity ratio: 0.6667
# ----
# Query: Stylistic Variation in Multilingual Instructions
# Chosen: Knowledge, Intention, Rhetoric: Levels of Variation in Multilingual Instructions
# Similarity ratio: 0.6719
# ----
# Query: Augmenting a Small Parallel Text with Morpho-syntactic LanguageResources for Serbian-English Statistical Machine Translation
# Chosen: Augmenting a Small Parallel Text with Morpho-Syntactic Language
# Similarity ratio: 0.6738
# ----
# Query: Squibs and DiscussionsParsing and Empty Nodes
# Chosen: Squibs and Discussions: Human Variation and Lexical Choice
# Similarity ratio: 0.6796
# ----
# Query: Human-Machine Cooperation with Epistemological DBs:Supporting User Corrections to Knowledge Bases
# Chosen: Human-Machine Cooperation: Supporting User Corrections to Automatically Constructed KBs
# Similarity ratio: 0.6848
# ----
# Query: In Proceedings of the 2001 Conference on Empirical Methods in Natural Language ProcessingLimitations of Co-Training for Natural Language Learningfrom Large Datasets
# Chosen: Proceedings of the 2001 Conference on Empirical Methods in Natural Language Processing
# Similarity ratio: 0.6880
# ----
# Query: From Single to Multi-document Summarization:A Prototype System and its Evaluation
# Chosen: From Single to Multi-document Summarization
# Similarity ratio: 0.6935
# ----
# Query: Computational Approaches to Morphology and Syntax
# Chosen: Computational Approaches to Semitic Languages
# Similarity ratio: 0.7021
# ----
# Query: Comprehension and Compilation in Optimality Theory∗
# Chosen: Directional Constraint Evaluation in Optimality Theory
# Similarity ratio: 0.7048
# ----
# Query: Optimality Theory
# Chosen: Book Reviews: Optimality Theory
# Similarity ratio: 0.7083
# ----
# Query: A comparison of algorithm and human performance
# Chosen: A Dialog Control Algorithm and Its Performance
# Similarity ratio: 0.7097
# ----
# Query: High Precision CogNIAC: and Linguistic Coreference with Limited Knowledge Resources
# Chosen: CogNIAC: high precision coreference with limited knowledge and linguistic resources
# Similarity ratio: 0.7108
# ----
# Query: Domain Adaptation using Neural Network Models
# Chosen: How to Avoid Unwanted Pregnancies: Domain Adaptation using Neural Network Models
# Similarity ratio: 0.7200
# ----
# Query: The adaptation of a machine-learned sentence realization systemto French
# Chosen: French Amalgam: a quick adaptation of a sentence realization system to French
# Similarity ratio: 0.7248
# ----
# Query: KUL: A Data-driven Approach to Temporal Parsing of DocumentsOleksandr Kolomiyets
# Chosen: KUL: Data-driven Approach to Temporal Parsing of Newswire Articles
# Similarity ratio: 0.7260
# ----
# Query: Linguistic Adaptation in Conversation Threads:Analyzing Alignment in Online Health Communities
# Chosen: A Model to Qualify the Linguistic Adaptation Phenomenon in Online Conversation Threads: Analyzing Priming Effect in Online Health Community
# Similarity ratio: 0.7382
# ----
# Query: Multi-Engine Machine Translationwith an Open-Source Decoder for Statistical Machine Translation
# Chosen: Multi-Engine Machine Translation with an Open-Source SMT Decoder
# Similarity ratio: 0.7421
# ----
# Query: The UPV-PRHLT Combination System for WMT 2010 Gonz´alez-Rubio Andr´es-Ferrer
# Chosen: The UPV-PRHLT Combination System for WMT 2010
# Similarity ratio: 0.7438
# ----
# Query: Textual Entailment Features for Machine Translation Evaluation
# Chosen: Using Contextual Information for Machine Translation Evaluation
# Similarity ratio: 0.7520
# ----
# Query: Hybrid Rule-based Algorithm for Coreference Resolution *
# Chosen: Hybrid Approach for Coreference Resolution
# Similarity ratio: 0.7551
# ----
# Query: Association for Computational Linguistics
# Chosen: Findings of the Association for Computational Linguistics: ACL 2025
# Similarity ratio: 0.7593
# ----
# Query: Book ReviewLearning Machine Translation
# Chosen: Book Reviews: An Introduction to Machine Translation
# Similarity ratio: 0.7692
# ----
# Query: Overview of the Protein Coreference task in BioNLP Shared Task 2011
# Chosen: Overview of Genia Event Task in BioNLP Shared Task 2011
# Similarity ratio: 0.7705
# ----
# Query: Book Reviews Discourse Processing
# Chosen: Book Review: Discourse Processing by Manfred Stede
# Similarity ratio: 0.7711
# ----
# Query: Squibs and DiscussionsDependency Unification Grammar forPROLOG
# Chosen: Dependency Unification grammar for Prolog
# Similarity ratio: 0.7767
# ----
# Query: Sentence Level Machine Translation Evaluation as a Ranking Problem: onestep aside from BLEU
# Chosen: Sentence Level Machine Translation Evaluation as a Ranking
# Similarity ratio: 0.7785
# ----
# Query: Compositional translation
# Chosen: Book Reviews: Compositional translation
# Similarity ratio: 0.7812
# ----
# Query: Book ReviewsSemantic Role Labeling
# Chosen: Semantic Role Labeling
# Similarity ratio: 0.7857
# ----
# Query: A Shallow Model of Backchannel Continuers in Spoken Dialogue
# Chosen: A model of back-channel acknowledgements in spoken dialogue
# Similarity ratio: 0.7899
# ----
# Query: Using Natural Language Processing to Identify Pharmacokinetic Drug-Drug Interactions Described in Drug Package Inserts
# Chosen: Using Natural Language Processing to Extract Drug-Drug Interaction Information from Package Inserts
# Similarity ratio: 0.7926
# ----
# Query: Using POS Information for Statistical Machine Translation intoMorphologically Rich Languages
# Chosen: Using POS Information for SMT into Morphologically Rich Languages
# Similarity ratio: 0.8025
# ----
# Query: Semantic Role Labeling: An Introduction tothe Special Issue
# Chosen: Special Issue Introduction: Semantic Role Labeling: An Introduction to the Special Issue
# Similarity ratio: 0.8027
# ----
# Query: Qualitative and Quantitative Modelsof Speech Translation
# Chosen: INVITED TALK: Qualitative and Quantitative Designs for Speech Translation
# Similarity ratio: 0.8062
# ----
# Query: Use of Modality and Negation inSemantically-Informed Syntactic MT
# Chosen: Modality and Negation in SIMT Use of Modality and Negation in Semantically-Informed Syntactic MT
# Similarity ratio: 0.8075
# ----
# Query: Incremental Parsing via Best-First Dynamic
# Chosen: Optimal Incremental Parsing via Best-First Dynamic Programming
# Similarity ratio: 0.8077
# ----
# Query: ICT: System Description for CoNLL-2012 Hao Xiong and Qun
# Chosen: ICT: System Description for CoNLL-2012
# Similarity ratio: 0.8085
# ----
# Query: Comparison of Alignment Templates and Maximum Entropy Models forNatural Language Understanding
# Chosen: Comparison of Alignment Templates and Maximum Entropy Models for NLP
# Similarity ratio: 0.8148
# ----
# Query: Computational lexical semantics
# Chosen: Book Reviews: Computational lexical semantics
# Similarity ratio: 0.8158
# ----
# Query: Named Entity Recognition for CatalanUsing Spanish Resources
# Chosen: Named Entity Recognition For Catalan Using Only Spanish Resources and Unlabelled Data
# Similarity ratio: 0.8194
# ----
# Query: Survey ArticleUnsupervised Learning of Morphology
# Chosen: Unsupervised Learning of Morphology
# Similarity ratio: 0.8333
# ----
# Query: The Functional Treatment of Parsing
# Chosen: Book Reviews: The Functional Treatment of Parsing
# Similarity ratio: 0.8333
# ----
# Query: Semantic construction in Feature-Based TAG
# Chosen: Semantic construction in F-TAG
# Similarity ratio: 0.8333
# ----
# Query: Word Sense Disambiguation vs. Statistical Machine TranslationMarine CARPUAT Dekai WU1
# Chosen: Word Sense Disambiguation vs. Statistical Machine Translation
# Similarity ratio: 0.8356
# ----
# Query: Efficient Parsing with Linear Context-Free Rewriting SystemsAndreas van Cranenburgh
# Chosen: Efficient parsing with Linear Context-Free Rewriting Systems
# Similarity ratio: 0.8392
# ----
# Query: The Logic of Typed Feature Structures
# Chosen: Book Reviews: The Logic of Typed Feature Structures
# Similarity ratio: 0.8409
# ----
# Query: An Unsupervised Method for Multilingual Word Sense Tagging UsingParallel Corpora: A Preliminary Investigation
# Chosen: An Unsupervised Method for Multilingual Word Sense Tagging Using Parallel Corpora
# Similarity ratio: 0.8421
# ----
# Query: On the principles of interoperable semantic annotation
# Chosen: On the Principles of Semantic Annotation
# Similarity ratio: 0.8511
# ----
# Query: The Architecture of the Language Faculty
# Chosen: Book Reviews: The Architecture of the Language Faculty
# Similarity ratio: 0.8511
# ----
# Query: Flexible Semantic Composition with DUDES
# Chosen: Flexible Semantic Composition with DUDES (short paper)
# Similarity ratio: 0.8511
# ----
# Query: A Computational Theory of Writing Systems
# Chosen: Book Reviews: A Computational Theory of Writing Systems
# Similarity ratio: 0.8542
# ----
# Query: IHS R&D Belarus: Cross-domain Extraction of Product Featuresusing Conditional Random Fields
# Chosen: IHS R&D Belarus: Cross-domain extraction of product features using CRF
# Similarity ratio: 0.8571
# ----
# Query: Name Matching Between Chinese and Roman Scripts:Machine Complements Human
# Chosen: Name Matching between Roman and Chinese Scripts: Machine Complements Human
# Similarity ratio: 0.8571
# ----
# Query: Dual for Natural Language Processing
# Chosen: Natural Language Processing
# Similarity ratio: 0.8571
# ----
# Query: Towards Emotional Variation inSpeech-BasedNatural Language Generation
# Chosen: Towards Emotional Variation in Speech-Based Natural Language Processing
# Similarity ratio: 0.8571
# ----
# Query: Cooperative Model Based Language Understanding in Dialogue
# Chosen: Cooperative model-based language understanding
# Similarity ratio: 0.8654
# ----
# Query: Unsupervised Learning of Meaningful Semantic Classesfor Entity Aggregates
# Chosen: Unsupervised Learning of Coherent and General Semantic Classes for Entity Aggregates
# Similarity ratio: 0.8662
# ----
# Query: DESIGN OF LMT: A PROLOG-BASED MACHINE TRANSLATION SYSTEMMichael C. McCord
# Chosen: Design of LMT: A Prolog-Based Machine Translation System
# Similarity ratio: 0.8682
# ----
# Query: Machine learning methods for comparative and time-orientedQuality Estimation of Machine Translation output
# Chosen: Selecting Feature Sets for Comparative and Time-Oriented Quality Estimation of Machine Translation Output
# Similarity ratio: 0.8720
# ----
# Query: Semantic interpretation of Dutch spoken dialogue
# Chosen: Semantic interpretation of Dutch spoken dialogue (short paper)
# Similarity ratio: 0.8727
# ----
# Query: Grammatical Error Detection and Correction Using Tagger Disagreement
# Chosen: Grammatical Error Detection Using Tagger Disagreement
# Similarity ratio: 0.8760
# ----
# Query: Natural Language Processing for Prolog Programmers
# Chosen: Book Reviews: Natural Language Processing for Prolog Programmers
# Similarity ratio: 0.8772
# ----
# Query: HAREM and Klue: how to compare two tagsets for named entitiesannotation
# Chosen: HAREM and Klue: how to put two tagsets for named entities annotation together
# Similarity ratio: 0.8784
# ----
# Query: USHEF and USAAR-USHEF Participationin the WMT15 Quality Estimation Shared Task
# Chosen: USHEF and USAAR-USHEF participation in the WMT15 QE shared task
# Similarity ratio: 0.8794
# ----
# Query: The Rhetorical Parsing of Natural Language Texts
# Chosen: The Rhetorical Parsing of Unrestricted Natural Language Texts
# Similarity ratio: 0.8807
# ----
# Query: Assigning Terms to Domains by Document ClassificationNoemie Elhadad
# Chosen: Assigning Terms to Domains by Document Classification
# Similarity ratio: 0.8833
# ----
# Query: Book Reviews Natural Language Understanding REFERENCE
# Chosen: Book Reviews: Natural Language Understanding
# Similarity ratio: 0.8866
# ----
# Query: A Walk on the Other Side:Adding Statistical Components to a Transfer-Based Translation System
# Chosen: A Walk on the Other Side: Using SMT Components in a Transfer-Based Translation System
# Similarity ratio: 0.8876
# ----
# Query: Using Nominal Compounds for Word Sense Discrimination
# Chosen: Using Synthetic Compounds for Word Sense Discrimination
# Similarity ratio: 0.8889
# ----
# Query: 5. Sublanguages
# Chosen: Sublanguages
# Similarity ratio: 0.8889
# ----
# Query: Computational Linguistics
# Chosen: Computational psycholinguistics
# Similarity ratio: 0.8929
# ----
# Query: A Neural Attention Model for Sentence Summarization
# Chosen: A Neural Attention Model for Abstractive Sentence Summarization
# Similarity ratio: 0.8947
# ----
# Query: Verb Noun Construction MWE Token Supervised Classification
# Chosen: Verb Noun Construction MWE Token Classification
# Similarity ratio: 0.8952
# ----
# Query: Arabic Cross-Document Coreference Detection
# Chosen: Arabic Cross-Document Coreference Resolution
# Similarity ratio: 0.8966
# ----
# Query: A Web Toolkit for Exploratory Relation Extraction
# Chosen: SCHNÄPPER: A Web Toolkit for Exploratory Relation Extraction
# Similarity ratio: 0.8991
# ----
# Query: Simple or Complex?Classifying the Question by the Answer Complexity
# Chosen: Simple or Complex? Classifying Questions by Answering Complexity
# Similarity ratio: 0.9008
# ----
# Query: Regression and Ranking based Optimisation for Sentence Level MachineTranslation Evaluation
# Chosen: Regression and Ranking based Optimisation for Sentence Level MT Evaluation
# Similarity ratio: 0.9024
# ----
# Query: Yet Another Chart-Based Technique for Parsing Ill-Formed InputTsuneaki Kato
# Chosen: Yet Another Chart-Based Technique for Parsing Ill-Formed Input
# Similarity ratio: 0.9051
# ----
# Query: Adaptive Information Presentation for Spoken Dialogue Systems:Evaluation with human subjects
# Chosen: Adaptive Information Presentation for Spoken Dialogue Systems: Evaluation with real users
# Similarity ratio: 0.9061
# ----
# Query: Understanding Complex Natural Language Explanations in Tutorial
# Chosen: Understanding Complex Natural Language Explanations in Tutorial Applications
# Similarity ratio: 0.9065
# ----
# Query: A Study of Academic Collaboration in Computational Linguistics withLatent Mixtures of Authors
# Chosen: A Study of Academic Collaborations in Computational Linguistics using a Latent Mixture of Authors Model
# Similarity ratio: 0.9082
# ----
# Query: T¨LTB˙ITAK-B˙ILGEM German-English Machine Translation Systems for
# Chosen: TÜBİTAK-BİLGEM German-English Machine Translation Systems for W13
# Similarity ratio: 0.9091
# ----
# Query: Going to the Roots of Dependency Parsing
# Chosen: Squibs: Going to the Roots of Dependency Parsing
# Similarity ratio: 0.9091
# ----
# Query: Constrained Arc-Eager Dependency Parsing
# Chosen: Squibs: Constrained Arc-Eager Dependency Parsing
# Similarity ratio: 0.9091
# ----
# Query: Resource sharing among HPSG and LTAG communitiesby a method of grammar conversion from FB-LTAG to HPSG
# Chosen: Resource Sharing Amongst HPSG and LTAG Communities by a Method of Grammar Conversion between FB-LTAG and HPSG
# Similarity ratio: 0.9100
# ----
# Query: A Framework for Robust Semantic Interpretation
# Chosen: A Framework for Robust Semantic Interpretation Learning
# Similarity ratio: 0.9109
# ----
# Query: Breadth and Depth of Semantic LexiconsIntroduction - Notes on the Workshop
# Chosen: Breadth and Depth of Semantic Lexicons - Notes on the Workshop
# Similarity ratio: 0.9118
# ----
# Query: Second Language Writing Assistant System Description
# Chosen: CNRC-TMT: Second Language Writing Assistant System Description
# Similarity ratio: 0.9123
# ----
# Query: A Tale of Two Parsers: investigating and combining graph-based andtransition-based dependency parsing using beam-search
# Chosen: A Tale of Two Parsers: Investigating and Combining Graph-based and Transition-based Dependency Parsing
# Similarity ratio: 0.9140
# ----
# Query: RESTRICTING LOGIC WITH GOVERNMENT-BINDING THEORY
# Chosen: Restricting Logic Grammars with Government-Binding Theory
# Similarity ratio: 0.9143
# ----
# Query: Phrase Linguistic Classification and Generalization for Improving StatisticalMachine TranslationAdri`a de Gispert
# Chosen: Phrase Linguistic Classification and Generalization for Improving Statistical Machine Translation
# Similarity ratio: 0.9143
# ----
# Query: QCRI at WMT12: Experiments in Spanish-English and Machine Translation of News Text
# Chosen: QCRI at WMT12: Experiments in Spanish-English and German-English Machine Translation of News Text
# Similarity ratio: 0.9162
# ----
# Query: On the Problem of Theoretical Termsin Empirical Computational Linguistics
# Chosen: Last Words: On the Problem of Theoretical Terms in Empirical Computational Linguistics
# Similarity ratio: 0.9182
# ----
# Query: Collecting Semantic Data by Mechanical Turk for the LexicalKnowledge Resource of a Text-to-Picture Generating System
# Chosen: Collecting Semantic Data from Mechanical Turk for a Lexical Knowledge Resource in a Text to Picture Generating System
# Similarity ratio: 0.9185
# ----
# Query: UTH: Semantic Relation Classification using Physical Sizes
# Chosen: UTH: SVM-based Semantic Relation Classification using Physical Sizes
# Similarity ratio: 0.9206
# ----
# Query: Collocational Aid for Learners of Japanese as a Second Language
# Chosen: Collocation Assistant for Learners of Japanese as a Second Language
# Similarity ratio: 0.9231
# ----
# Query: SemSim: Multilingual System for MeasuringSemantic Textual Similarity
# Chosen: UMCC_DLSI_SemSim: Multilingual System for Measuring Semantic Textual Similarity
# Similarity ratio: 0.9252
# ----
# Query: CoCoCo: Online Extraction of Russian Multiword Expressions
# Chosen: Online Extraction of Russian Multiword Expressions
# Similarity ratio: 0.9259
# ----
# Query: Named Entity Recognition for Dialectal Arabic
# Chosen: Named Entity Recognition System for Dialectal Arabic
# Similarity ratio: 0.9278
# ----
# Query: Japanese Query Alteration Based on Semantic Similarity
# Chosen: Japanese Query Alteration Based on Lexical Semantic Similarity
# Similarity ratio: 0.9310
# ----
# Query: The State of the Art in Thai Language Processing
# Chosen: Panel: The State of the Art in Thai Language Processing
# Similarity ratio: 0.9320
# ----
# Query: BUAP: Three Approaches for Semantic Textual Similarity
# Chosen: FCC: Three Approaches for Semantic Textual Similarity
# Similarity ratio: 0.9346
# ----
# Query: A computational approach to Yor`ub´a morphology
# Chosen: A Computational Approach to Yorùbá Morphology
# Similarity ratio: 0.9348
# ----
# Query: Joint Named Entity Recognition and Disambiguation
# Chosen: Joint Entity Recognition and Disambiguation
# Similarity ratio: 0.9348
# ----
# Query: UdS at the CoNLL 2013 Shared Task
# Chosen: UdS at CoNLL 2013 Shared Task
# Similarity ratio: 0.9355
# ----
# Query: Phrase-based Transliteration System with Simple Heuristics
# Chosen: Phrase-Based Transliteration with Simple Heuristics
# Similarity ratio: 0.9358
# ----
# Query: English→Russian MT evaluation campaign
# Chosen: English-to-Russian MT evaluation campaign
# Similarity ratio: 0.9367
# ----
# Query: EVALution 1.0: an Evolving Semantic Dataset forTraining and Evaluation of Distributional Semantic ModelsEnrico Santus
# Chosen: EVALution 1.0: an Evolving Semantic Dataset for Training and Evaluation of Distributional Semantic Models
# Similarity ratio: 0.9369
# ----
# Query: Hallym: Named Entity Recognition on Twitter with Induced WordRepresentation
# Chosen: Hallym: Named Entity Recognition on Twitter with Word Representation
# Similarity ratio: 0.9371
# ----
# Query: A Morphological Analyzer and Generator for the Arabic Dialects
# Chosen: MAGEAD: A Morphological Analyzer and Generator for the Arabic Dialects
# Similarity ratio: 0.9394
# ----
# Query: A Study on Convolution Kernels for Shallow Semantic Parsing
# Chosen: A Study on Convolution Kernels for Shallow Statistic Parsing
# Similarity ratio: 0.9412
# ----
# Query: Natural Language
# Chosen: Natural Language I
# Similarity ratio: 0.9412
# ----
# Query: Automatic classification of patternsfrom the Pattern Dictionary of English Verbs
# Chosen: Automatic classification of semantic patterns from the Pattern Dictionary of English Verbs
# Similarity ratio: 0.9412
# ----
# Query: Noun-Phrase Analysis in Unrestricted Text for Information Retrieval
# Chosen: Noun Phrase Analysis in Large Unrestricted Text for Information Retrieval
# Similarity ratio: 0.9429
# ----
# Query: Training and Evaluating Error Minimization Rules for Statistical MachineTranslation
# Chosen: Training and Evaluating Error Minimization Decision Rules for Statistical Machine Translation
# Similarity ratio: 0.9432
# ----
# Query: The Shared Corpora Working Group Report
# Chosen: Shared Corpora Working Group Report
# Similarity ratio: 0.9459
# ----
# Query: a Method for Automatic Evaluation of Machine Translation
# Chosen: Bleu: a Method for Automatic Evaluation of Machine Translation
# Similarity ratio: 0.9492
# ----
# Query: General Word Sense Disambiguation Based on a Full Sentential Context
# Chosen: General Word Sense Disambiguation Method Based on a Full Sentential Context
# Similarity ratio: 0.9510
# ----
# Query: Czech-English Dependency-based Machine Translation
# Chosen: Czech-English Dependency Tree-based Machine Translation
# Similarity ratio: 0.9524
# ----
# Query: TwitterHawk: A Feature Bucket Approach to Sentiment Analysis
# Chosen: TwitterHawk: A Feature Bucket Based Approach to Sentiment Analysis
# Similarity ratio: 0.9524
# ----
# Query: The Syntax Augmented MT (SAMT) System for the Shared Task in the 2007ACL Workshop on Statistical Machine Translation
# Chosen: The Syntax Augmented MT (SAMT) System at the Shared Task for the 2007 ACL Workshop on Statistical Machine Translation
# Similarity ratio: 0.9528
# ----
# Query: The GREC Challenge: Overview and Evaluation Results
# Chosen: The GREC Challenge 2008: Overview and Evaluation Results
# Similarity ratio: 0.9533
# ----
# Query: The Impact of Morphological Stemming on Arabic Detection and Coreference Resolution
# Chosen: The Impact of Morphological Stemming on Arabic Mention Detection and Coreference Resolution
# Similarity ratio: 0.9540
# ----
# Query: An Empirical Study of the Domain Dependence of SupervisedWord Sense Disambiguation Systems*
# Chosen: An Empirical Study of the Domain Dependence of Supervised Word Disambiguation Systems
# Similarity ratio: 0.9545
# ----
# Query: Aligning Clauses in Parallel Texts
# Chosen: Aligning Clattses in Parallel Texts
# Similarity ratio: 0.9565
# ----
# Query: Multi-document summarization using A* search and discriminative training
# Chosen: Multi-Document Summarization Using A* Search and Discriminative Learning
# Similarity ratio: 0.9583
# ----
# Query: Generic binarization for parsing and translation
# Chosen: General binarization for parsing and translation
# Similarity ratio: 0.9583
# ----
# Query: IaCTeM EventMine for BioILP 2013 CG and PC tasks
# Chosen: NaCTeM EventMine for BioNLP 2013 CG and PC tasks
# Similarity ratio: 0.9583
# ----
# Query: An English-to-Hungarian Morpheme-based Statistical MachineTranslation System with Reordering Rules
# Chosen: English to Hungarian Morpheme-based Statistical Machine Translation System with Reordering Rules
# Similarity ratio: 0.9588
# ----
# Query: MultiSumQuery-Based Multi-Document Summarisation
# Chosen: MultiSum: Query-Based Multi-Document Summarization
# Similarity ratio: 0.9592
# ----
# Query: WISDOM: A Web Information Credibility Analysis System
# Chosen: WISDOM: A Web Information Credibility Analysis Systematic
# Similarity ratio: 0.9636
# ----
# Query: Statistical Dependency Parsing of Turkish
# Chosen: Statistical Dependency Parsing for Turkish
# Similarity ratio: 0.9639
# ----
# Query: The CIPS-SIGHAN CLP 2010Chinese Word Segmentation Bakeoff
# Chosen: The CIPS-SIGHAN CLP 2014 Chinese Word Segmentation Bake-off
# Similarity ratio: 0.9655
# ----
# Query: Improving Chinese Grammatical Error Correction using CorpusAugmentation and Hierarchical Phrase-based Statistical MachineTranslation
# Chosen: Improving Chinese Grammatical Error Correction with Corpus Augmentation and Hierarchical Phrase-based Statistical Machine Translation
# Similarity ratio: 0.9660
# ----
# Query: Models of Translational Equivalenceamong Words
# Chosen: Models of translation equivalence among words
# Similarity ratio: 0.9670
# ----
# Query: Interactive Predictive Parsing 1
# Chosen: Interactive Predictive Parsing
# Similarity ratio: 0.9677
# ----
# Query: LIMSI’s Participation in the 2013 Shared Taskon Native Language Identification
# Chosen: LIMSI’s participation to the 2013 shared task on Native Language Identification
# Similarity ratio: 0.9682
# ----
# Query: Semantic Role Lableing System using Maximum Entropy Classifier *
# Chosen: Semantic Role Labeling System Using Maximum Entropy Classifier
# Similarity ratio: 0.9683
# ----
# Query: Joint A∗ CCG Parsing and Semantic Role Labeling
# Chosen: Joint A* CCG Parsing and Semantic Role Labelling
# Similarity ratio: 0.9684
# ----
# Query: ILK2: Semantic Role Labelling for Catalan and Spanish using TiMBL
# Chosen: ILK2: Semantic Role Labeling of Catalan and Spanish using TiMBL
# Similarity ratio: 0.9688
# ----
# Query: Construction of a Chinese Idiom Knowledge Base and Its Applications
# Chosen: Construction of Chinese Idiom Knowledge-base and Its Applications
# Similarity ratio: 0.9697
# ----
# Query: A Dataset for Research on Short-Text Conversation *
# Chosen: A Dataset for Research on Short-Text Conversations
# Similarity ratio: 0.9703
# ----
# Query: Using Senses in EMM Word Alignment
# Chosen: Using Senses in HMM Word Alignment
# Similarity ratio: 0.9706
# ----
# Query: Evaluating and combining biomedical named entity recognition systems
# Chosen: Evaluating and combining and biomedical named entity recognition systems
# Similarity ratio: 0.9714
# ----
# Query: SquibPrepositional Phrase Attachment without Oracles
# Chosen: Squibs: Prepositional Phrase Attachment without Oracles
# Similarity ratio: 0.9720
# ----
# Query: SemEval-2013 Task 11: Word Sense Induction & Disambiguationwithin an End-User Application
# Chosen: SemEval-2013 Task 11: Word Sense Induction and Disambiguation within an End-User Application
# Similarity ratio: 0.9724
# ----
# Query: An Empirical Study in Multilingual Natural LanguageGeneration: What Should A Text Planner Do?
# Chosen: An empirical study of multilingual natural language generation: What Should a Text Planner Do?
# Similarity ratio: 0.9733
# ----
# Query: BALI: SMT shared task system description
# Chosen: RALI: SMT Shared Task System Description
# Similarity ratio: 0.9750
# ----
# Query: Algorithms for Analysing the Temporal Structure ofDiscourse*t
# Chosen: Algorithms for Analysing the Temporal Structure of Discourse
# Similarity ratio: 0.9752
# ----
# Query: INDEXING AND REFERENTIAL DEPENDENCIES WITHIN BINDING THEORY: A COMPUTATIONAL FRAMEWORK
# Chosen: Indexing and a Referential Dependencies Within Binding Theory: Computational Framework
# Similarity ratio: 0.9767
# ----
# Query: Systemic Classification and its Efficiency
# Chosen: Systematic Classification and its Efficiency
# Similarity ratio: 0.9767
# ----
# Query: Dependency Parsing as a Classification Problem
# Chosen: Dependency Parsing as a Classication Problem
# Similarity ratio: 0.9778
# ----
# Query: LetsMT!: A Cloud-Based Platform for Do-It-YourselfMachine Translation
# Chosen: LetsMT!: Cloud-Based Platform for Do-It-Yourself Machine Translation
# Similarity ratio: 0.9781
# ----
# Query: Probabilistic Word Alignment under the Lo-norm
# Chosen: Probabilistic Word Alignment under the L0-norm
# Similarity ratio: 0.9783
# ----
# Query: The Johns Hopkins SENSEVAL2 System Descriptions
# Chosen: The John Hopkins SENSEVAL-2 System Descriptions
# Similarity ratio: 0.9787
# ----
# Query: A Dependency Treebank of Urdu and its Evaluation
# Chosen: Dependency Treebank of Urdu and its Evaluation
# Similarity ratio: 0.9787
# ----
# Query: Constraints and Defaults on Zero Pronouns in JapaneseInstruction Manuals
# Chosen: Constraints and defaults of zero pronouns in Japanese instruction manuals
# Similarity ratio: 0.9793
# ----
# Query: Example-based machine translation using DP-matching betweenword sequences
# Chosen: Example-based machine translation using DP-matching between work sequences
# Similarity ratio: 0.9796
# ----
# Query: Gibbs Sampling with freeness Constraintin Unsupervised Dependency Parsing
# Chosen: Gibbs Sampling with Treeness Constraint in Unsupervised Dependency Parsing
# Similarity ratio: 0.9796
# ----
# Query: Bottom-up Named Entity Recognitionusing a Two-stage Machine Learning Method
# Chosen: Bottom-up Named Entity Recognition using Two-stage Machine Learning Method
# Similarity ratio: 0.9799
# ----
# Query: Slavonic Information Extraction and Partial Parsing
# Chosen: Slavic Information Extraction and Partial Parsing
# Similarity ratio: 0.9800
# ----
# Query: Multilingual Multi-Document Summarization with POL
# Chosen: Multilingual Multi-Document Summarization with POLY2
# Similarity ratio: 0.9804
# ----
# Query: A Unified Framework for Automatic Evaluation usingN-gram Co-Occurrence Statistics
# Chosen: A Unified Framework For Automatic Evaluation Using 4-Gram Co-occurrence Statistics
# Similarity ratio: 0.9816
# ----
# Query: Overview of the SPMRL 2013 Shared Task:Cross-Framework Evaluation of Parsing Morphologically Rich Languages*
# Chosen: Overview of the SPMRL 2013 Shared Task: A Cross-Framework Evaluation of Parsing Morphologically Rich Languages
# Similarity ratio: 0.9817
# ----
# Query: Passive and Pervasive Use of a Bilingual Dictionaryin Statistical Machine Translation
# Chosen: Passive and Pervasive Use of Bilingual Dictionary in Statistical Machine Translation
# Similarity ratio: 0.9822
# ----
# Query: Dependency-based Syntactic Annotation of a Chinese Corpus
# Chosen: Dependency-based Syntactic Annotation of a Chiense Corpus
# Similarity ratio: 0.9825
# ----
# Query: Building a Shallow Arabic Morphological Analyzer in One Day
# Chosen: Building a Shallow Arabic Morphological Analyser in One Day
# Similarity ratio: 0.9831
# ----
# Query: Legal Texts Summarization by Exploration of theThematic Structures and Argumentative Roles
# Chosen: Legal Text Summarization by Exploration of the Thematic Structure and Argumentative Roles
# Similarity ratio: 0.9832
# ----
# Query: Lexicalized Context-Free Grammars
# Chosen: Lexicalized Context-Fee Grammars
# Similarity ratio: 0.9846
# ----
# Query: The Syntax Student’s Companion:an eLearning Tool designed for(Computational) Linguistics Students
# Chosen: he Syntax Student’s Companion: an eLearning Tool designed for (Computational) Linguistics Students
# Similarity ratio: 0.9846
# ----
# Query: Acquisition of Desires before Beliefs: A Computational Investigation
# Chosen: Acquisition of Desires before Beliefs: A Computional Investigation
# Similarity ratio: 0.9851
# ----
# Query: Random Forests in Language Modeling
# Chosen: Random Forests in Language Modelin
# Similarity ratio: 0.9855
# ----
# Query: Unsupervised Semantic Role Labelling
# Chosen: Unsupervised Semantic Role Labellin
# Similarity ratio: 0.9859
# ----
# Query: WIT: _A Toolkit for Building Robust and Real-Time Spoken Dialogue Systems
# Chosen: WIT: A Toolkit for Building Robust and Real-Time Spoken Dialogu Systems
# Similarity ratio: 0.9861
# ----
# Query: A Multilingual Approach to Annotatingand Extracting Temporal Information1
# Chosen: A Multilingual Approach To Annotating And Extracting Temporal Information
# Similarity ratio: 0.9863
# ----
# Query: UDel: Generating Referring ExpressionsGuided by Psycholinguistic Findings
# Chosen: UDel: Generating Referring Expressions Guided by Psycholinguistc Findings
# Similarity ratio: 0.9863
# ----
# Query: Phrase Pair Rescoring with Term Weightings forStatistical Machine Translation
# Chosen: Phrase Pair Rescoring with Term Weighting for Statistical Machine Translation
# Similarity ratio: 0.9870
# ----
# Query: OmnifluentTM English-to-French and Russian-to-English Systems for the2013 Workshop on Statistical Machine Translation
# Chosen: Omnifluent English-to-French and Russian-to-English Systems for the 2013 Workshop on Statistical Machine Translation
# Similarity ratio: 0.9871
# ----
# Query: Mixing Weak Learners in Semantic Parsing
# Chosen: Mixing Weak Learners in Semantic Parsin
# Similarity ratio: 0.9873
# ----
# Query: Empirical lower bounds on alignment error rates in syntax-based machinetranslation
# Chosen: Empirical Lower Bounds on Aligment Error Rates in Syntax-Based Machine Translation
# Similarity ratio: 0.9878
# ----
# Query: Bilingual Correspondence Recursive Autoencodersfor Statistical Machine Translation
# Chosen: Bilingual Correspondence Recursive Autoencoder for Statistical Machine Translation
# Similarity ratio: 0.9878
# ----
# Query: A Two-stage Model for Content Determination
# Chosen: A Two-Staged Model For Content Determination
# Similarity ratio: 0.9885
# ----
# Query: Identification of Caused Motion Constructions
# Chosen: Identification of Caused Motion Construction
# Similarity ratio: 0.9888
# ----
# Query: Machine Transliteration of Names in Arabic Text
# Chosen: Machine Transliteration of Names in Arabic Texts
# Similarity ratio: 0.9895
# ----
# Query: An Empirical Study of Information Synthesis Tasks
# Chosen: An Empirical Study of Information Synthesis Task
# Similarity ratio: 0.9897
# ----
# Query: A PRAGMATICS-BASED APPROACH To ELLIPSIS RESOLUTION
# Chosen: A Pragmatic-Based Approach to Ellipsis Resolution
# Similarity ratio: 0.9899
# ----
# Query: Resolution of Lexical Ambiguities in Spoken Dialogue Systems
# Chosen: Resolution of Lexical Ambiguities in Spoken Dialogue System
# Similarity ratio: 0.9916
# ----
# Query: Using Noisy Bilingual Data for Statistical Machine Translation
# Chosen: Using Noisy Biligual Data for Statistical Machine Translation
# Similarity ratio: 0.9919
# ----
# Query: Modelling Semantic Role Plausibility in Human Sentence Processing
# Chosen: Modelling Semantic Role Pausibility in Human Sentence Processing
# Similarity ratio: 0.9922
# ----
# Query: Automatic Extraction of Linguistic Metaphor with LDA Topic Modeling
# Chosen: Automatic Extraction of Linguistic Metaphors with LDA Topic Modeling
# Similarity ratio: 0.9926
# ----
# Query: Semi-supervised learning of geographical gazetteers from the internet
# Chosen: Semi-supervised learning of geographical gazetteer from the internet
# Similarity ratio: 0.9927
# ----
# Query: Ambiguity Resolution for Machine Translation of Telegraphic Messagesi
# Chosen: Ambiguity Resolution for Machine Translation of Telegraphic Messages
# Similarity ratio: 0.9927
# ----
# Query: Creating a Multilingual Collocation Dictionary from Large Text Corpora
# Chosen: Creating a multilingual collocations dictionary from large text corpora
# Similarity ratio: 0.9929
# ----
# Query: Applying morphological decomposition to statistical machine translation
# Chosen: Applying Morphological Decompositions to Statistical Machine Translation
# Similarity ratio: 0.9930
# ----

# %%
import string


def normalize(s: str) -> str:
    return s.translate(str.maketrans("", "", string.punctuation + string.whitespace)).lower()


def front_half(s: str) -> str:
    n = len(s)
    return s[: n // 2]


def back_half(s: str) -> str:
    n = len(s)
    return s[n // 2 :]

# %%
from acl_anthology import Anthology

anthology = Anthology.from_repo()
norm_titlemap = {normalize(str(p.title)): p for p in anthology.papers()}

# %%
title = "How Creative is Your Writing? A Linguistic Creativity Measure fromComputer Science and Cognitive Psychology Perspectives"
print(f"Processing title: {title} (normed to: {normalize(title)})")


matches = difflib.get_close_matches(normalize(title), norm_titlemap.keys(), n=5, cutoff=0.45)
print(f"Fuzzy matches:")
for match in matches:
    print(f"Match: {norm_titlemap[match].title}")
print("----")
# Out:
# Processing title: How Creative is Your Writing? A Linguistic Creativity Measure fromComputer Science and Cognitive Psychology Perspectives (normed to: howcreativeisyourwritingalinguisticcreativitymeasurefromcomputerscienceandcognitivepsychologyperspectives)
# Fuzzy matches:
# Match: Austrian German – Linguistic, Normative and Political Perspectives
# Match: Computational linguistics and mathematical logic from a computer science point of view
# Match: Benchmarking Machine Reading Comprehension: A Psychological Perspective
# Match: Predictive and Distinctive Linguistic Features in Schizophrenia-Bipolar Spectrum Disorders
# Match: A Survey in Automatic Irony Processing: Linguistic, Cognitive, and Multi-X Perspectives
# ----

# %%
normed_title = normalize(title)
print(f"Normed title (len: {len(normed_title)}): {normed_title}")
normed_title_front = front_half(normed_title)
normed_title_back = back_half(normed_title)
print(f"Front: {normed_title_front}, Back: {normed_title_back}")

matches = [
    t
    for t in norm_titlemap.keys()
    if any(
        [
            normed_title_front in t,
            normed_title_back in t,
            front_half(t) in normed_title,
            back_half(t) in normed_title,
        ]
    )
]
print(f"Substring matches: {matches}")
# Out:
# Normed title (len: 105): howcreativeisyourwritingalinguisticcreativitymeasurefromcomputerscienceandcognitivepsychologyperspectives
# Front: howcreativeisyourwritingalinguisticcreativitymeasure, Back: fromcomputerscienceandcognitivepsychologyperspectives
# Substring matches: ['esprit', 'atlas', 'lmt', 'gms', 'emis', 'sdl', 'liwp', 'ttc', 'passives', 'ucb', 'linguisticcorpussearch', 'tinlap3', 'linguisticdistances', 'howcreativeisyourwriting', 'mice']

# %%
difflib.get_close_matches(normed_title, matches, n=5, cutoff=0.3)
# Out:
# ['howcreativeisyourwriting']

# %%
actual_title = "Analysis of statistical and morphological classes to generate weightedreordering hypotheses on a Statistical Machine Translation system"
norm_actual_title = normalize(actual_title)
print(f"Actual title normed: {norm_actual_title}")
print(f"Normed title in matches: {norm_actual_title in norm_titlemap}")

# %%
difflib.get_close_matches(normed_title, norm_titlemap.keys(), n=3, cutoff=0.6)

# %%
difflib.get_close_matches("foobar", [], n=3, cutoff=0.8)

# %%
normed_title = normalize(title)
front_norm, back_norm = front_half(normed_title), back_half(normed_title)
for key in norm_titlemap:
    if front_norm in key or back_norm in key or front_half(key) in normed_title or back_half(key) in normed_title:
        print(f"Substring match found: {key} -> {norm_titlemap[key].title}")

# %%
import csv

with open("../data/datasets/acl200_global/context_dataset.csv", "r") as f:
    reader = csv.DictReader(f)
    records = [row for row in reader]

# %%
from pprint import pprint

for i, record in enumerate(records):
    if record["target_title"].startswith("}") or record["citing_title"].startswith("}"):
        print(f"Found malformed record {i}:")
        pprint(record)
        print(record["citing_abstract"])
        print("----")

# %%
normalize("Sentence Comparison using Robust Minimal Recursion Semantics and an Ontology") in norm_titlemap

# %%
str(norm_titlemap[normalize("Sentence Comparison using Robust Minimal Recursion Semantics and an Ontology")].title)

# %%
# Get paper by id
paper = anthology.get_paper("J09-4011")
print(paper)
print(paper.title)
# Out:
# Paper(id='11', bibkey='blunsom-2009-book', title=<MarkupText 'Book Review: Learning Machine Translation by Cyril Goutte, Nicola Cancedda, Marc Dymetman, and <span class="acl-fixed-case">G</span>eorge Foster (editors)'>, authors=[NameSpecification(name=Name(first='Phil', last='Blunsom'), id=None, orcid=None, affiliation=None, variants=[])], abstract=None)
# Book Review: Learning Machine Translation by Cyril Goutte, Nicola Cancedda, Marc Dymetman, and George Foster (editors)

# %%
for paper in list(anthology.papers())[:5]:
    print(paper.abstract)
# Out:
# None
# None
# None
# None
# None

# %%
dir(paper)
# Out:
# ['__annotations__',
#  '__attrs_attrs__',
#  '__attrs_own_setattr__',
#  '__attrs_props__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__match_args__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_id',
#  'abstract',
#  'address',
#  'attachments',
#  'authors',
#  'awards',
#  'bibkey',
#  'bibtype',
#  'citeproc_dict',
#  'collection_id',
#  'csltype',
#  'deletion',
#  'doi',
#  'editors',
#  'errata',
#  'from_frontmatter_xml',
#  'from_xml',
#  'full_id',
#  'full_id_tuple',
#  'get_editors',
#  'get_events',
#  'get_ingest_date',
#  'get_issue',
#  'get_journal_title',
#  'id',
#  'ingest_date',
#  'is_deleted',
#  'is_frontmatter',
#  'issue',
#  'journal',
#  'language',
#  'language_name',
#  'month',
#  'note',
#  'pages',
#  'paperswithcode',
#  'parent',
#  'pdf',
#  'publisher',
#  'refresh_bibkey',
#  'revisions',
#  'root',
#  'thumbnail',
#  'title',
#  'to_bibtex',
#  'to_citation',
#  'to_markdown_citation',
#  'to_xml',
#  'type',
#  'venue_ids',
#  'videos',
#  'volume_id',
#  'web_url',
#  'year']
