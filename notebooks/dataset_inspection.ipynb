# %%
import pandas as pd

dataset = pd.read_json("../data/dataset/nontrivial_checked.jsonl", lines=True)

# %%
print(f"Number of rows: {len(dataset)}")

print(f"Number of unique source dois: {dataset['source_doi'].nunique()}")
# Out:
# Number of rows: 14735
# Number of unique source dois: 354

# %%
dataset.head()
# Out:
#                     source_doi  \
# 0  10.1016/j.newar.2024.101694
# 1  10.1016/j.newar.2024.101694
# 2  10.1016/j.newar.2024.101694
# 3  10.1016/j.newar.2024.101694
# 4  10.1016/j.newar.2024.101694
#
#                                        sent_original  \
# 0  Subsequently, Andrews et al. (2017) selected a...
# 1  Andrews et al. (2017) investigated how the sep...
# 2  This led Andrews et al. (2017) to conclude tha...
# 3  It may also owe in part to the mass ratio dist...
# 4  Hwang et al. (2022c) used a related method to ...
#
#                                          sent_no_cit  sent_idx  \
# 0  Subsequently,  selected a wide binary candidat...        58
# 1   investigated how the separation of their cand...        61
# 2  This led  to conclude that most of the pairs w...        64
# 3  It may also owe in part to the mass ratio dist...        90
# 4   used a related method to study the eccentrici...       110
#
# ...

# %%
dataset.tail()
# Out:
#                            source_doi  \
# 14730  10.1146/annurev.astro.38.1.761
# 14731  10.1146/annurev.astro.38.1.761
# 14732  10.1146/annurev.astro.38.1.761
# 14733  10.1146/annurev.astro.38.1.761
# 14734  10.1146/annurev.astro.38.1.761
#
#                                            sent_original  \
# 14730  The red, three arrow symbol denotes the lower ...
# 14731  The continuous line marks the total star forma...
# 14732  Based on the X-ray background, Almaini et al (...
# 14733  A rapidly evolving “burst” mode (exhaust time ...
# 14734  The ultraluminous mergers may be related to th...
#
#                                              sent_no_cit  sent_idx  \
# 14730  The red, three arrow symbol denotes the lower ...       698
# 14731  The continuous line marks the total star forma...       699
# 14732  Based on the X-ray background,  set a limit of...       708
# 14733  A rapidly evolving “burst” mode (exhaust time ...       715
# ...

# %%
reviews = pd.read_json("../data/preprocessed/reviews.jsonl", lines=True)

# %%
sum(len(body) for body in reviews['body']) // 3
# Out:
# 113583512

# %%
i = 0
for body in reviews['body']:
    print(len(body))
    print(body[:500])
    i += 1
    if i >= 3:
        break
    print("-----")
# Out:
# 89315
# 1 Introduction Binary stars have long played a foundational role in astrophysics. They underpin precision measurements of stellar physical parameters, enable robust tests of general relativity, and give rise to an extraordinary zoo of observational phenomenology. Millennia after their discovery (e.g. Jetsu and Porceddu, 2015 ), binaries remain at the heart of many of the interesting open questions in astrophysics: binary evolution modeling is key for understanding the origin of gravitational wav
# -----
# 115742
# ...
