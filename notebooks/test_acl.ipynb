# %%
from acl_anthology import Anthology

anthology = Anthology.from_repo()  # pulls metadata from the official repo

title = "Utilizing Statistical Dialogue Act".lower()
# title = "Stylistic Variation in Multilingual Instructions".lower()

candidates = []
for paper in anthology.papers():
    if title in str(paper.title).lower():
        candidates.append((paper.id, str(paper.title), paper))

print(candidates)  # list of (ACL_ID, title)
# Out:
# [('16', 'Utilizing Statistical Dialogue Act Processing in Verbmobil', Paper(id='16', bibkey='reithinger-maier-1995-utilizing', title=<MarkupText 'Utilizing Statistical Dialogue Act Processing in <span class="acl-fixed-case">V</span>erbmobil'>, authors=[NameSpecification(name=Name(first='Norbert', last='Reithinger'), id=None, orcid=None, affiliation=None, variants=[]), NameSpecification(name=Name(first='Elisabeth', last='Maier'), id=None, orcid=None, affiliation=None, variants=[])], abstract=None))]

# %%
# Get by ACL id
p = anthology.get("W04-0842")
print(p.pdf.url)
# Out:
# https://aclanthology.org/W04-0842.pdf

# %%
title_to_paper = {str(p.title): p for p in anthology.papers()}

# %%
paper = title_to_paper["WSD system based on specialized Hidden Markov Model (upv-shmm-eaw)"]
print(paper.full_id)
print(dir(paper))
# Out:
# W04-0842
# ['__annotations__', '__attrs_attrs__', '__attrs_own_setattr__', '__attrs_props__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__match_args__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_check_id', 'abstract', 'address', 'attachments', 'authors', 'awards', 'bibkey', 'bibtype', 'citeproc_dict', 'collection_id', 'csltype', 'deletion', 'doi', 'editors', 'errata', 'from_frontmatter_xml', 'from_xml', 'full_id', 'full_id_tuple', 'get_editors', 'get_events', 'get_ingest_date', 'get_issue', 'get_journal_title', 'id', 'ingest_date', 'is_deleted', 'is_frontmatter', 'issue', 'journal', 'language', 'language_name', 'month', 'note', 'pages', 'paperswithcode', 'parent', 'pdf', 'publisher', 'refresh_bibkey', 'revisions', 'root', 'thumbnail', 'title', 'to_bibtex', 'to_citation', 'to_markdown_citation', 'to_xml', 'type', 'venue_ids', 'videos', 'volume_id', 'web_url', 'year']

# %%
q = "system precision recall"
candidates = [title for title in title_to_paper if title.lower().startswith(q)]
for candidate in candidates:
    print(f"Title: {candidate}")

# %%
for title, paper in title_to_paper.items():
    authors = paper.authors
    for author in authors:
        if author.name.last.lower().startswith('cozman'):
            print(f"Author: {author.name.last}, {author.name.first}; Title: {title}")
# Out:
# Author: Cozman, Fabio; Title: DaMata: A Robot-Journalist Covering the Brazilian Amazon Deforestation
# Author: Cozman, Fabio; Title: BLAB Reporter: Automated journalism covering the Blue Amazon
# Author: Cozman, Fabio; Title: Imaginary Numbers! Evaluating Numerical Referring Expressions by Neural End-to-End Surface Realization Systems
# Author: Cozman, Fabio; Title: A Simple Audio and Text Collection-Annotation Tool Targeted to Brazilian Indigenous Language Native Speakers

# %%
ORIGINAL: identifying english and hungarian light verb constructions:a contrastive approach, MATCH: identifying english and hungarian light verb constructions: a contrastive approach
original = "identifying english and hungarian light verb constructions:a contrastive approach"
actual = "identifying english and hungarian light verb constructions: a contrastive approach"

# %%
import difflib
matches = difflib.get_close_matches(
    "Generating Semantically Precise Scene Graphs from Textual Descriptionsfor Improved Image Retrieval",
    titles,
    n=3,
    cutoff=0.6,
)
print(matches)
# Out:
# ['generating semantically precise scene graphs from textual descriptions for improved image retrieval']

# %%
print(candidates[0][1])
print(candidates[0][1].full_id)
# Out:
# Paper(id='6', bibkey='dymetman-etal-2012-optimization', title=<MarkupText 'Optimization and Sampling for <span class="acl-fixed-case">NLP</span> from a Unified Viewpoint'>, authors=[NameSpecification(name=Name(first='Marc', last='Dymetman'), id=None, orcid=None, affiliation=None, variants=[]), NameSpecification(name=Name(first='Guillaume', last='Bouchard'), id=None, orcid=None, affiliation=None, variants=[]), NameSpecification(name=Name(first='Simon', last='Carter'), id=None, orcid=None, affiliation=None, variants=[])], abstract=None)
# W12-6106

# %%
paper.month

from datetime import datetime
dt = datetime.strptime(f"{paper.year} {paper.month}", "%Y %B")
print(f"{dt.year}{dt.month:02d}{dt.day:02d}")
# Out:
# 19990201

# %%
import csv

# Find out if the set of citing_titles and target_titles are disjoint or if they have any intersection
citing_titles = set()
target_titles = set()
path_to_data = "../data/datasets/acl200_global/context_dataset.csv"
with open(path_to_data, "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        citing_titles.add(row["citing_title"].lower().strip())
        target_titles.add(row["target_title"].lower().strip())

# %%
print(f"Number of citing titles: {len(citing_titles)}")
print(f"Number of target titles: {len(target_titles)}")
intersection = citing_titles.intersection(target_titles)
union = citing_titles.union(target_titles)
print(f"Number of titles in union: {len(union)}")
print(f"Number of titles in intersection: {len(intersection)}")
print(f"Set difference citing titles that aren't also target titles: {len(citing_titles - target_titles)}")
# Out:
# Number of citing titles: 11786
# Number of target titles: 5192
# Number of titles in union: 13222
# Number of titles in intersection: 3756
# Set difference citing titles that aren't also target titles: 8030

# %%
train_titles = set()
path_to_data = "../data/datasets/acl200_global/context_dataset_train.csv"
with open(path_to_data, "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        train_titles.add(row["citing_title"].lower().strip())
        train_titles.add(row["target_title"].lower().strip())

eval_titles = set()
path_to_data = "../data/datasets/acl200_global/context_dataset_eval.csv"
with open(path_to_data, "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        eval_titles.add(row["citing_title"].lower().strip())
        eval_titles.add(row["target_title"].lower().strip())

train_eval_union = train_titles.union(eval_titles)
print(f"Number of titles in train/eval union: {len(train_eval_union)}")
# Out:
# Number of titles in train/eval union: 13222

# %%
paper.pdf.url
# Out:
# 'https://aclanthology.org/Y99-1036.pdf'

# %%
paper.doi
# Out:
# 'http://hdl.handle.net/2065/12135'

# %%
titles = [str(p.title).lower() for p in anthology.papers()]
print(len(titles))
print(len(set(titles)))
# Out:
# 118474
# 117400

# %%
dupes = {}
for paper in anthology.papers():
    title = str(paper.title).lower()
    if title not in dupes:
        dupes[title] = paper
    else:
        print(f"Duplicate title found: {title} -> {dupes[title].full_id}, {paper.full_id}")
# Out:
# Duplicate title found: discussion -> 1957.earlymt-1.8, 1957.earlymt-1.16
# Duplicate title found: discussion -> 1957.earlymt-1.8, 1957.earlymt-1.22
# Duplicate title found: summation by chairman -> 1960.earlymt-nsmt.8, 1960.earlymt-nsmt.15
# Duplicate title found: research in machine translation -> 1957.earlymt-1.0, 1960.earlymt-nsmt.18
# Duplicate title found: summation by chairman -> 1960.earlymt-nsmt.8, 1960.earlymt-nsmt.21
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1960.earlymt-nsmt.22
# Duplicate title found: summation by chairman -> 1960.earlymt-nsmt.8, 1960.earlymt-nsmt.25
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1960.earlymt-nsmt.30
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1960.earlymt-nsmt.36
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1960.earlymt-nsmt.42
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1960.earlymt-nsmt.47
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1960.earlymt-nsmt.53
# Duplicate title found: summation by chairman -> 1960.earlymt-nsmt.8, 1960.earlymt-nsmt.59
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1960.earlymt-nsmt.60
# Duplicate title found: summation by chairman -> 1960.earlymt-nsmt.8, 1960.earlymt-nsmt.65
# Duplicate title found: automatic translation of languages -> 1962.earlymt-1.2, 1962.earlymt-1.3
# Duplicate title found: list of participants -> 1960.earlymt-nsmt.68, 1978.tc-1.10
# Duplicate title found: list of participants -> 1960.earlymt-nsmt.68, 1981.tc-1.24
# Duplicate title found: biographical notes and list of participants -> 1982.tc-1.37, 1983.tc-1.26
# Duplicate title found: biographical notes on speakers and list of participants -> 1985.tc-1.19, 1986.tc-1.20
# Duplicate title found: concluding remarks -> 1981.tc-1.23, 1987.mtsummit-1.43
# Duplicate title found: concluding remarks -> 1981.tc-1.23, 1987.mtsummit-1.44
# Duplicate title found: concluding remarks -> 1981.tc-1.23, 1987.mtsummit-1.45
# Duplicate title found: the logos system -> 1984.bcs-1.28, 1989.mtsummit-1.4
# Duplicate title found: panel 1: practical experience in the application of mt-systems -> 1989.mtsummit-1.6, 1989.mtsummit-1.7
# Duplicate title found: panel 1: practical experience in the application of mt-systems -> 1989.mtsummit-1.6, 1989.mtsummit-1.8
# Duplicate title found: panel 1: practical experience in the application of mt-systems -> 1989.mtsummit-1.6, 1989.mtsummit-1.10
# Duplicate title found: panel 1: practical experience in the application of mt-systems -> 1989.mtsummit-1.6, 1989.mtsummit-1.11
# Duplicate title found: panel 2: government views of mt -> 1989.mtsummit-1.19, 1989.mtsummit-1.20
# Duplicate title found: biographical notes on speakers and chairs and list of participants -> 1987.tc-1.20, 1989.tc-1.19
# Duplicate title found: biographical notes on speakers and chairs and list of participants -> 1987.tc-1.20, 1990.tc-1.20
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1993.eamt-1.1
# Duplicate title found: logos intelligent translation system -> 1994.amta-1.39, 1996.amta-1.34
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1996.eamt-1.1
# Duplicate title found: conclusion -> 1960.earlymt-nsmt.67, 1996.eamt-1.16
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1997.eamt-1.1
# Duplicate title found: introduction -> 1957.earlymt-1.1, 1997.eamt-1.11
# Duplicate title found: using mt in a corporate setting -> 1997.mtsummit-papers.23, 1997.mtsummit-papers.24
# Duplicate title found: esteam btr -> 1997.mtsummit-systems.11, 1997.mtsummit-exhibits.5
# Duplicate title found: paho mt systems: spanamâ and engspanâ -> 1997.mtsummit-systems.8, 1997.mtsummit-exhibits.12
# Duplicate title found: summary and conclusions -> 1997.eamt-1.14, 1999.eamt-1.16
# Duplicate title found: mt evaluation -> 1998.amta-tutorials.1, 1999.mtsummit-1.31
# Duplicate title found: a gentle introduction to mt: theory and current practice -> 1997.mtsummit-tutorials.1, 2000.amta-tutorials.2
# Duplicate title found: introduction -> 1957.earlymt-1.1, 2000.eamt-1.1
# Duplicate title found: statistical machine translation -> 2000.amta-tutorials.4, 2000.eamt-1.5
# Duplicate title found: example-based machine translation -> 2002.amta-tutorials.1, 2002.tmi-tutorials.1
# Duplicate title found: statistical machine translation -> 2000.amta-tutorials.4, 2002.tmi-tutorials.2
# Duplicate title found: have we found the holy grail? -> 2003.mtsummit-plenaries.5, 2003.mtsummit-plenaries.6
# Duplicate title found: ltc communicator -> 2003.mtsummit-systems.12, 2003.tc-1.13
# Duplicate title found: the added value of free online mt services -> 2006.amta-papers.6, 2006.amta-users.3
# Duplicate title found: presentation -> 2006.amta-panel2.1, 2006.amta-panel2.2
# Duplicate title found: global public health intelligence network (gphin) -> 2005.mtsummit-invited.4, 2007.mtsummit-papers.7
# Duplicate title found: statistical machine translation -> 2000.amta-tutorials.4, 2007.mtsummit-tutorials.1
# Duplicate title found: global public health intelligence network (gphin) -> 2005.mtsummit-invited.4, 2008.amta-govandcom.2
# Duplicate title found: introduction -> 1957.earlymt-1.1, 2009.eamt-smart.1
# Duplicate title found: introduction -> 1957.earlymt-1.1, 2009.mtsummit-plenaries.10
# Duplicate title found: language technology resource center -> 2008.amta-additional.2, 2009.mtsummit-government.2
# Duplicate title found: the business case for machine translation -> 2003.tc-1.1, 2009.mtsummit-tutorials.4
# Duplicate title found: introduction -> 1957.earlymt-1.1, 2009.mtsummit-wpt.10
# Duplicate title found: préface [editorial] -> 2008.tal-3.1, 2009.tal-2.1
# Duplicate title found: language technology resource center -> 2008.amta-additional.2, 2010.eamt-1.8
# Duplicate title found: statistical machine translation -> 2000.amta-tutorials.4, 2011.eamt-1.3
# Duplicate title found: deriving translation units using small additional corpora -> 2011.eamt-1.18, 2011.eamt-1.20
# Duplicate title found: atlas -> 1989.mtsummit-1.5, 2011.eamt-1.44
# Duplicate title found: evaluating the output of machine translation systems -> 2010.amta-tutorials.4, 2011.mtsummit-tutorials.3
# Duplicate title found: préface [foreword] -> 2007.tal-3.1, 2011.tal-2.1
# Duplicate title found: introduction to machine translation -> 2009.mtsummit-tutorials.1, 2012.amta-tutorials.1
# Duplicate title found: préface [foreword] -> 2007.tal-3.1, 2012.tal-3.1
# Duplicate title found: mt@ec: working with translators -> 2012.tc-1.4, 2012.tc-1.13
# Duplicate title found: préface [foreword] -> 2007.tal-3.1, 2013.tal-2.1
# Duplicate title found: casmacat: cognitive analysis and statistical methods for advanced computer aided translation -> 2013.mtsummit-european.3, 2014.eamt-1.12
# Duplicate title found: introduction -> 1957.earlymt-1.1, 2014.lilt-9.1
# Duplicate title found: préface [foreword] -> 2007.tal-3.1, 2014.tal-2.1
# Duplicate title found: abu-matran: automatic building of machine translation -> 2014.eamt-1.29, 2015.eamt-1.45
# Duplicate title found: préface [foreword] -> 2007.tal-3.1, 2015.tal-3.1
# Duplicate title found: abu-matran: automatic building of machine translation -> 2014.eamt-1.29, 2016.eamt-2.19
# Duplicate title found: tramooc: translation for massive open online courses -> 2015.eamt-1.36, 2017.mtsummit-commercial.20
# Duplicate title found: preface -> 1998.eamt-1.1, 2018.clicit-1.1
# Duplicate title found: actes de la conférence taln. volume 1 - articles longs, articles courts de taln -> 2018.jeptalnrecital-long.0, 2018.jeptalnrecital-court.0
# Duplicate title found: actes de la conférence taln. volume 2 - démonstrations, articles des rencontres jeunes chercheurs, ateliers deft -> 2018.jeptalnrecital-recital.0, 2018.jeptalnrecital-demo.0
# Duplicate title found: actes de la conférence taln. volume 2 - démonstrations, articles des rencontres jeunes chercheurs, ateliers deft -> 2018.jeptalnrecital-recital.0, 2018.jeptalnrecital-deft.0
# Duplicate title found: preface -> 1998.eamt-1.1, 2019.clicit-1.1
# Duplicate title found: preface -> 1998.eamt-1.1, 2020.clicit-1.1
# Duplicate title found: on the interplay between fine-tuning and sentence-level probing for linguistic knowledge in pre-trained transformers -> 2020.blackboxnlp-1.7, 2020.findings-emnlp.227
# Duplicate title found: towards domain-independent text structuring trainable on large discourse treebanks -> 2020.dt4tp-1.4, 2020.findings-emnlp.281
# Duplicate title found: do language embeddings capture scales? -> 2020.blackboxnlp-1.27, 2020.findings-emnlp.439
# Duplicate title found: document classification for covid-19 literature -> 2020.findings-emnlp.332, 2020.nlpcovid19-acl.3
# Duplicate title found: analyzing the morphological structures in seediq words -> 2020.ijclclp-2.1, 2020.rocling-1.1
# Duplicate title found: don’t read too much into it: adaptive computation for open-domain question answering -> 2020.emnlp-main.244, 2020.sustainlp-1.9
# Duplicate title found: variants of vector space reductions for predicting the compositionality of english noun compounds -> 2020.lrec-1.539, 2020.winlp-1.13
# Duplicate title found: preface -> 1998.eamt-1.1, 2021.clicit-1.1
# Duplicate title found: proceedings of the workshop on cognitive modeling and computational linguistics -> 2020.cmcl-1.0, 2021.cmcl-1.0
# Duplicate title found: reviewing natural language processing research -> 2020.acl-tutorials.4, 2021.eacl-tutorials.4
# Duplicate title found: improving distantly-supervised named entity recognition with self-collaborative denoising learning -> 2021.emnlp-main.839, 2021.findings-emnlp.131
# Duplicate title found: weasul: weakly supervised dialogue policy learning: reward estimation for multi-turn dialogue -> 2021.dialdoc-1.10, 2021.inlg-1.8
# Duplicate title found: code-mixing on sesame street: dawn of the adversarial polyglots -> 2021.calcs-1.19, 2021.naacl-main.282
# Duplicate title found: learning and evaluating a differentially private pre-trained language model -> 2021.findings-emnlp.102, 2021.privatenlp-1.3
# Duplicate title found: knowledge discovery in covid-19 research literature -> 2020.nlpcovid19-2.22, 2021.ranlp-1.46
# Duplicate title found: unknown intent detection using multi-objective optimization on deep learning classifiers -> 2021.paclic-1.41, 2021.ranlp-1.127
# Duplicate title found: towards code-mixed hinglish dialogue generation -> 2021.nlp4convai-1.26, 2021.ranlp-srw.2
# Duplicate title found: supersense and sensibility: proxy tasks for semantic annotation of prepositions -> 2020.law-1.11, 2021.scil-1.58
# Duplicate title found: consistent unsupervised estimators for anchored pcfgs -> 2020.tacl-1.27, 2021.scil-1.60
# Duplicate title found: will it unblend? -> 2020.findings-emnlp.138, 2021.scil-1.61
# Duplicate title found: smbop: semi-autoregressive bottom-up semantic parsing -> 2021.naacl-main.29, 2021.spnlp-1.2
# Duplicate title found: human-model divergence in the handling of vagueness -> 2021.scil-1.42, 2021.unimplicit-1.6
# Duplicate title found: perceived and intended sarcasm detection with graph attention networks -> 2021.findings-emnlp.408, 2021.wnut-1.12
# Duplicate title found: boosting neural machine translation with similar translations -> 2020.acl-main.144, 2022.amta-upg.20
# Duplicate title found: system description on automatic simultaneous translation workshop -> 2021.autosimtrans-1.4, 2022.autosimtrans-1.3
# Duplicate title found: proceedings of the workshop on cognitive modeling and computational linguistics -> 2020.cmcl-1.0, 2022.cmcl-1.0
# Duplicate title found: grada: graph generative data augmentation for commonsense reasoning -> 2022.coling-1.397, 2022.dlg4nlp-1.6
# Duplicate title found: deepspin: deep structured prediction for natural language processing -> 2020.eamt-1.67, 2022.eamt-1.53
# Duplicate title found: diversifying content generation for commonsense reasoning with mixture of knowledge graph experts -> 2022.dlg4nlp-1.1, 2022.findings-acl.149
# Duplicate title found: how to translate your samples and choose your shots? analyzing translate-train & few-shot cross-lingual transfer -> 2022.deeplo-1.22, 2022.findings-naacl.11
# Duplicate title found: dihutra: a parallel corpus to analyse differences between human translations -> 2022.eamt-1.58, 2022.lrec-1.186
# Duplicate title found: true: re-evaluating factual consistency evaluation -> 2022.dialdoc-1.19, 2022.naacl-main.287
# Duplicate title found: lifelong pretraining: continually adapting language models to emerging corpora -> 2022.bigscience-1.1, 2022.naacl-main.351
# Duplicate title found: generalized quantifiers as a source of error in multilingual nlu benchmarks -> 2022.dadc-1.7, 2022.naacl-main.359
# Duplicate title found: training text-to-text transformers with privacy guarantees -> 2022.findings-acl.171, 2022.privatenlp-1.4
# Duplicate title found: analysis of language change in collaborative instruction following -> 2021.findings-emnlp.239, 2022.scil-1.16
# Duplicate title found: the interaction between cognitive ease and informativeness shapes the lexicons of natural languages -> 2022.fieldmatters-1.5, 2022.scil-1.20
# Duplicate title found: préface [editorial] -> 2008.tal-3.1, 2022.tal-3.1
# Duplicate title found: greasevision: rewriting the rules of the interface -> 2022.dadc-1.2, 2022.woah-1.3
# Duplicate title found: ccl23-eval 任务6系统报告:基于cls动态加权平均和数据增强的电信网络诈骗案件分类(system report for ccl23-eval task 6:::classification of telecom internet fraud cases based on cls dynamic weighted average and data augement) -> 2023.ccl-3.18, 2023.ccl-3.19
# Duplicate title found: pretrained transformers for text ranking: bert and beyond -> 2021.naacl-tutorials.1, 2023.cl-1.8
# Duplicate title found: macocu: massive collection and curation of monolingual and bilingual data: focus on under-resourced languages -> 2022.eamt-1.41, 2023.eamt-1.55
# Duplicate title found: les jeux de données en compréhension du langage naturel et parlé : paradigmes d’annotation et représentations sémantiques -> 2023.jeptalnrecital-rjc.1, 2023.jeptalnrecital-projet.1
# Duplicate title found: overview of the shared task on hope speech detection for equality, diversity, and inclusion -> 2022.ltedi-1.58, 2023.ltedi-1.7
# Duplicate title found: unsupervised opinion summarization using approximate geodesics -> 2023.findings-emnlp.8, 2023.newsum-1.11
# Duplicate title found: the vault: a comprehensive multilingual dataset for advancing code understanding and generation -> 2023.findings-emnlp.316, 2023.nlposs-1.25
# Duplicate title found: knowledge-augmented language model prompting for zero-shot knowledge graph question answering -> 2023.matching-1.7, 2023.nlrse-1.7
# Duplicate title found: symbolic planning and code generation for grounded dialogue -> 2023.emnlp-main.460, 2023.pandl-1.5
# Duplicate title found: tucker decomposition with frequency attention for temporal knowledge graph completion -> 2023.findings-acl.458, 2023.repl4nlp-1.21
# Duplicate title found: visual coherence loss for coherent and visually grounded story generation -> 2023.findings-acl.603, 2023.repl4nlp-1.27
# Duplicate title found: tü-cl at sigmorphon 2023: straight-through gradient estimation for hard attention -> 2023.sigmorphon-1.17, 2023.sigmorphon-1.19
# Duplicate title found: multilingual bert has an accent: evaluating english influences on fluency in multilingual models -> 2023.findings-eacl.89, 2023.sigtyp-1.16
# Duplicate title found: proceedings of the workshop on cognitive modeling and computational linguistics -> 2020.cmcl-1.0, 2024.cmcl-1.0
# Duplicate title found: major entity identification: a generalizable alternative to coreference resolution -> 2024.crac-1.1, 2024.emnlp-main.652
# Duplicate title found: the impact of differential privacy on group disparity mitigation -> 2022.privatenlp-1.2, 2024.findings-naacl.249
# Duplicate title found: proceedings of the 21st international conference on natural language processing (icon): shared task on decoding fake narratives in spreading hateful stories (faux-hate) -> 2024.icon-fauxhate.0, 2024.icon-fauxhate.1
# Duplicate title found: hesum: a novel dataset for abstractive text summarization in hebrew -> 2024.findings-acl.381, 2024.loresmt-1.2
# Duplicate title found: meaning representations for natural languages: design, models and applications -> 2022.emnlp-tutorials.1, 2024.lrec-tutorials.3
# Duplicate title found: mining, assessing, and improving arguments in nlp and the social sciences -> 2023.eacl-tutorials.1, 2024.lrec-tutorials.5
# Duplicate title found: representational isomorphism and alignment of multilingual large language models -> 2024.findings-emnlp.823, 2024.mrl-1.24
# Duplicate title found: faithful persona-based conversational dataset generation with large language models -> 2024.findings-acl.904, 2024.nlp4convai-1.8
# Duplicate title found: what an elegant bridge: multilingual llms are biased similarly in different languages -> 2024.mrl-1.2, 2024.nlp4science-1.3
# Duplicate title found: préface [editorial] -> 2008.tal-3.1, 2024.tal-2.1
# Duplicate title found: creative and context-aware translation of east asian idioms with gpt-4 -> 2024.findings-emnlp.544, 2024.wat-1.1
# Duplicate title found: domain dynamics: evaluating large language models in english-hindi translation -> 2024.icon-1.19, 2024.wmt-1.27
# Duplicate title found: proceedings of the workshop on cognitive modeling and computational linguistics -> 2020.cmcl-1.0, 2025.cmcl-1.0
# Duplicate title found: linguaists@dravidianlangtech 2025: abusive tamil and malayalam text targeting women on social media -> 2025.dravidianlangtech-1.51, 2025.dravidianlangtech-1.116
# Duplicate title found: can dependency parses facilitate generalization in language models? a case study of cross-lingual relation extraction -> 2025.knowledgenlp-1.27, 2025.knowledgenlp-1.28
# Duplicate title found: robust data watermarking in language models by injecting fictitious knowledge -> 2025.findings-acl.736, 2025.l2m2-1.15
# Duplicate title found: beyond english: the impact of prompt translation strategies across languages and tasks in multilingual llms -> 2025.findings-naacl.73, 2025.loresmt-1.9
# Duplicate title found: modeling: a novel dataset for testing linguistic reasoning in language models -> 2024.sigtyp-1.14, 2025.loresmt-1.10
# Duplicate title found: cross-document cross-lingual nli via rst-enhanced graph fusion and interpretability prediction -> 2025.emnlp-main.1611, 2025.mrl-main.2
# Duplicate title found: mug-eval: a proxy evaluation framework for multilingual generation capabilities in any language -> 2025.findings-emnlp.1061, 2025.mrl-main.39
# Duplicate title found: the bridgeai project -> 2024.eamt-2.18, 2025.mtsummit-2.17
# Duplicate title found: hypa-rag: a hybrid parameter adaptive retrieval-augmented generation system for ai legal and policy applications -> 2024.customnlp4u-1.18, 2025.naacl-industry.79
# Duplicate title found: pbi-attack: prior-guided bimodal interactive black-box jailbreak attack for toxicity maximization -> 2025.emnlp-main.32, 2025.trustnlp-main.3
# Duplicate title found: degraded text recognition using word collocation and visual inter-word constraints -> A94-1031, A94-1033
# Duplicate title found: logos machine translation system -> 1997.mtsummit-systems.4, A97-2009
# Duplicate title found: discourse referents -> C69-6902, C69-7001
# Duplicate title found: international conference on computational linguistics coling 1969 -> C69-7200, C69-7300
# Duplicate title found: international conference on computational linguistics coling 1969 -> C69-7200, C69-7400
# Duplicate title found: international conference on computational linguistics coling 1969 -> C69-7200, C69-7500
# Duplicate title found: author index -> C80-1093, C82-1069
# Duplicate title found: preface -> 1998.eamt-1.1, C82-2001
# Duplicate title found: no english translation available -> C82-2047, C82-2050
# Duplicate title found: domain dependent natural language understanding -> C86-1062, C86-1065
# Duplicate title found: preface -> 1998.eamt-1.1, C90-1001
# Duplicate title found: towards personal mt: general design, dialogue structure, potential role of speech -> C90-2006, C90-3006
# Duplicate title found: bilingual generation of weather forecasts in an operations environment -> C90-1021, C90-3059
# Duplicate title found: a matrix representation of the inflectional forms of arabic words: a study of co-occurrence patterns -> C90-3090, C90-3091
# Duplicate title found: author index -> C80-1093, C92-1007
# Duplicate title found: personal notes -> C92-1064, C92-2124
# Duplicate title found: personal notes -> C92-1064, C92-3169
# Duplicate title found: personal notes -> C92-1064, C92-4217
# Duplicate title found: the internet a “natural” channel for language learning -> C96-2175, C96-2176
# Duplicate title found: author index -> C80-1093, C96-2214
# Duplicate title found: self-governing neural networks for on-device short text classification -> D18-1092, D18-1105
# Duplicate title found: codeswitch-reddit: exploration of written multilingual discourse in online discussion forums -> D19-1484, D19-5558
# Duplicate title found: aligning multilingual word embeddings for cross-modal retrieval task -> D19-6402, D19-6605
# Duplicate title found: a flexible pragmatics-driven language generator for animated agents -> E03-1019, E03-1062
# Duplicate title found: the corpora management system based on java and oracle technologies -> E03-1016, E03-1063
# Duplicate title found: the multilingual named entity recognition framework -> E03-1015, E03-1082
# Duplicate title found: creating a multilingual collocations dictionary from large text corpora -> E03-1022, E03-1083
# Duplicate title found: demonstrations -> E03-2000, E06-2000
# Duplicate title found: student research workshop -> E03-3000, E06-3000
# Duplicate title found: universal dependencies -> 2021.cl-2.11, E17-5001
# Duplicate title found: pearl: a probabilistic chart parser -> 1991.iwpt-1.22, E91-1004
# Duplicate title found: ambiguity resolution in a reductionistic parser -> E93-1046, E93-1069
# Duplicate title found: research in continuous speech recognition -> H89-1006, H89-2058
# Duplicate title found: speech research at carnegie mellon -> H89-1014, H89-2064
# Duplicate title found: analysis and symbolic processing of unrestricted speech -> H89-1052, H89-2076
# Duplicate title found: author index -> C80-1093, H89-2079
# Duplicate title found: research in continuous speech recognition -> H89-1006, H90-1079
# Duplicate title found: spoken language systems -> H89-2059, H90-1080
# Duplicate title found: evaluating the use of prosodic information in speech recognition and understanding -> H89-2061, H90-1081
# Duplicate title found: segment-based acoustic models with multi-level search algorithms for continuous speech recognition -> H89-2062, H90-1082
# Duplicate title found: speech research at carnegie mellon -> H89-1014, H90-1084
# Duplicate title found: interactive multimedia explanation for equipment maintenance and repair -> H90-1009, H90-1086
# Duplicate title found: robust speech recognition technology program summary -> H89-2067, H90-1089
# Duplicate title found: research and development for spoken language systems -> H89-2066, H90-1090
# Duplicate title found: real-time speech recognition systems -> H89-2074, H90-1097
# Duplicate title found: natural language research -> H89-1035, H90-1099
# Duplicate title found: adaptive natural language processing -> H90-1078, H91-1079
# Duplicate title found: research in continuous speech recognition -> H89-1006, H91-1080
# Duplicate title found: spoken language systems -> H89-2059, H91-1081
# Duplicate title found: evaluating the use of prosodic information in speech recognition and understanding -> H89-2061, H91-1082
# Duplicate title found: segment-based acoustic models with multi-level search algorithms for continuous speech recognition -> H89-2062, H91-1083
# Duplicate title found: the plus accelerator -> H90-1085, H91-1086
# Duplicate title found: interactive multimedia explanation for equipment maintenance and repair -> H90-1009, H91-1087
# Duplicate title found: robust speech recognition technology program summary -> H89-2067, H91-1091
# Duplicate title found: nist-darpa interagency agreement: sls program -> H90-1091, H91-1092
# Duplicate title found: natural language research -> H89-1035, H91-1103
# Duplicate title found: very large annotated database of american english -> H90-1100, H91-1104
# Duplicate title found: natural language, knowledge representation and discourse -> H89-2071, H91-1105
# Duplicate title found: a simple rule-based part of speech tagger -> A92-1021, H92-1022
# Duplicate title found: lexical disambiguation using simulated annealing -> C92-1056, H92-1046
# Duplicate title found: interaction between structural changes in machine translation -> C92-2102, H92-1051
# Duplicate title found: evaluating the use of prosodic information in speech recognition and understanding -> H89-2061, H92-1099
# Duplicate title found: segment-based acoustic models with multi-level search algorithms for continuous speech recognition -> H89-2062, H92-1100
# Duplicate title found: microphone-array systems for speech recognition input -> H91-1084, H92-1101
# Duplicate title found: spoken-language research at carnegie mellon -> H91-1085, H92-1102
# Duplicate title found: spoken language recognition and understanding -> H91-1090, H92-1107
# Duplicate title found: evaluating text understanding systems -> H91-1093, H92-1111
# Duplicate title found: the consortium for lexical research -> H91-1076, H92-1114
# Duplicate title found: research in natural language processing -> H86-1005, H92-1115
# Duplicate title found: real-time speech recognition system -> H91-1098, H92-1119
# Duplicate title found: natural language research -> H89-1035, H92-1123
# Duplicate title found: recent advances in janus: a speech translation system -> 1993.tmi-1.16, H93-1041
# Duplicate title found: robust continuous speech recognition -> H92-1097, H93-1079
# Duplicate title found: evaluating the use of prosodic information in speech recognition and understanding -> H89-2061, H93-1082
# Duplicate title found: spoken-language research at carnegie mellon -> H91-1085, H93-1084
# Duplicate title found: extracting constraints on word usage from large text corpora -> H92-1103, H93-1085
# Duplicate title found: lingstat: an interactive, machine-aided translation system -> H93-1037, H93-1087
# Duplicate title found: evaluation and analysis of auditory model front ends for robust speech recognition program summary -> H92-1108, H93-1093
# Duplicate title found: robust continuous speech recognition technology program summary -> H92-1109, H93-1094
# Duplicate title found: spoken language recognition and understanding -> H91-1090, H93-1095
# Duplicate title found: nist-darpa interagency agreement: spoken language program -> H92-1110, H93-1096
# Duplicate title found: the consortium for lexical research -> H91-1076, H93-1098
# Duplicate title found: diderot: tipster program, automatic data extraction from text utilizing semantic analysis -> H92-1112, H93-1099
# Duplicate title found: pangloss: a knowledge-based machine assisted translation research project - site -> H92-1113, H93-1100
# Duplicate title found: research in natural language processing -> H86-1005, H93-1101
# Duplicate title found: wordnet: a lexical database for english -> H92-1116, H93-1103
# Duplicate title found: annotation of atis data -> H92-1117, H93-1106
# Duplicate title found: a real-time spoken-language system for interactive problem solving -> H92-1120, H93-1108
# Duplicate title found: natural language research -> H89-1035, H93-1113
# Duplicate title found: session 7: demonstrations -> H93-1043, H94-1043
# Duplicate title found: robust continuous speech recognition -> H92-1097, H94-1088
# Duplicate title found: usable, real-time, interactive spoken language systems -> H93-1081, H94-1090
# Duplicate title found: evaluating the use of prosodic information in speech recognition and understanding -> H89-2061, H94-1091
# Duplicate title found: segment-based acoustic models for continuous speech recognition -> H93-1083, H94-1092
# Duplicate title found: spoken-language research at carnegie mellon -> H91-1085, H94-1094
# Duplicate title found: extracting constraints on word usage from large text corpora -> H92-1103, H94-1095
# Duplicate title found: the automatic component of the lingstat machine-aided translation system -> H94-1029, H94-1096
# Duplicate title found: research in large vocabulary continuous speech recognition -> H93-1088, H94-1097
# Duplicate title found: automatic extraction of grammars from annotated text -> H93-1092, H94-1099
# Duplicate title found: robust continuous speech recognition technology program summary -> H92-1109, H94-1102
# Duplicate title found: spoken language recognition and understanding -> H91-1090, H94-1103
# Duplicate title found: the consortium for lexical research -> H91-1076, H94-1106
# Duplicate title found: diderot: tipster program, automatic data extraction from text utilizing semantic analysis -> H92-1112, H94-1107
# Duplicate title found: research in natural language processing -> H86-1005, H94-1109
# Duplicate title found: robust text processing and information retrieval -> H93-1102, H94-1110
# Duplicate title found: wordnet: a lexical database for english -> H92-1116, H94-1111
# Duplicate title found: annotation of atis data -> H92-1117, H94-1114
# Duplicate title found: research in natural language processing -> H86-1005, H94-1119
# Duplicate title found: author index -> C80-1093, I05-1089
# Duplicate title found: author index -> C80-1093, I05-2050
# Duplicate title found: author index -> C80-1093, I05-3036
# Duplicate title found: author index -> C80-1093, I05-4011
# Duplicate title found: author index -> C80-1093, I05-5013
# Duplicate title found: author index -> C80-1093, I05-6012
# Duplicate title found: author index -> C80-1093, I05-7014
# Duplicate title found: author index -> C80-1093, I08-2145
# Duplicate title found: author index -> C80-1093, I08-4034
# Duplicate title found: author index -> C80-1093, I08-6015
# Duplicate title found: author index -> C80-1093, I08-7022
# Duplicate title found: advertisements -> J00-1007, J00-2018
# Duplicate title found: publications received -> J00-2017, J00-3010
# Duplicate title found: advertisements -> J00-1007, J00-3012
# Duplicate title found: briefly noted -> J00-2016, J00-4010
# Duplicate title found: publications received -> J00-2017, J00-4011
# Duplicate title found: advertisements -> J00-1007, J00-4014
# Duplicate title found: briefly noted -> J00-2016, J01-1009
# Duplicate title found: publications received -> J00-2017, J01-1010
# Duplicate title found: advertisements -> J00-1007, J01-2014
# Duplicate title found: publications received -> J00-2017, J01-3010
# Duplicate title found: advertisements -> J00-1007, J01-3011
# Duplicate title found: briefly noted -> J00-2016, J01-4012
# Duplicate title found: publications received -> J00-2017, J01-4013
# Duplicate title found: advertisements -> J00-1007, J01-4016
# Duplicate title found: briefly noted -> J00-2016, J02-1007
# Duplicate title found: publications received -> J00-2017, J02-2006
# Duplicate title found: briefly noted -> J00-2016, J02-4009
# Duplicate title found: publications received -> J00-2017, J02-4010
# Duplicate title found: author index -> C80-1093, J02-4011
# Duplicate title found: briefly noted -> J00-2016, J03-1008
# Duplicate title found: publications received -> J00-2017, J03-1009
# Duplicate title found: briefly noted -> J00-2016, J03-3008
# Duplicate title found: publications received -> J00-2017, J03-3009
# Duplicate title found: briefly noted -> J00-2016, J03-4006
# Duplicate title found: author index -> C80-1093, J03-4007
# Duplicate title found: title index -> J02-4012, J03-4008
# Duplicate title found: briefly noted -> J00-2016, J04-1007
# Duplicate title found: publications received -> J00-2017, J04-1008
# Duplicate title found: publications received -> J00-2017, J04-2007
# Duplicate title found: briefly noted -> J00-2016, J04-4006
# Duplicate title found: briefly noted -> J00-2016, J05-1008
# Duplicate title found: publications received -> J00-2017, J05-1009
# Duplicate title found: briefly noted -> J00-2016, J05-3008
# Duplicate title found: publications received -> J00-2017, J05-3009
# Duplicate title found: briefly noted -> J00-2016, J06-2008
# Duplicate title found: publications received -> J00-2017, J06-2009
# Duplicate title found: briefly noted -> J00-2016, J06-3009
# Duplicate title found: publications received -> J00-2017, J06-3010
# Duplicate title found: briefly noted -> J00-2016, J06-4010
# Duplicate title found: publications received -> J00-2017, J06-4011
# Duplicate title found: errata -> J06-3011, J06-4014
# Duplicate title found: publications received -> J00-2017, J07-2012
# Duplicate title found: briefly noted/publications received -> J07-3007, J07-4008
# Duplicate title found: publications received -> J00-2017, J08-1007
# Duplicate title found: publications received -> J00-2017, J08-3009
# Duplicate title found: publications received -> J00-2017, J08-4007
# Duplicate title found: letter to the editor -> J07-1001, J09-1001
# Duplicate title found: publications received -> J00-2017, J09-1007
# Duplicate title found: briefly noted -> J00-2016, J09-2007
# Duplicate title found: publications received -> J00-2017, J09-3006
# Duplicate title found: publications received -> J00-2017, J10-2006
# Duplicate title found: publications received -> J00-2017, J10-3011
# Duplicate title found: briefly noted -> J00-2016, J11-3012
# Duplicate title found: publications received -> J00-2017, J11-3013
# Duplicate title found: publications received -> J00-2017, J12-1008
# Duplicate title found: briefly noted: briefly noted -> J11-1012, J12-2013
# Duplicate title found: publications received -> J00-2017, J12-3010
# Duplicate title found: language models for machine translation: original vs. translated texts -> D11-1034, J12-4004
# Duplicate title found: briefly noted -> J00-2016, J13-2008
# Duplicate title found: publications received -> J00-2017, J13-2009
# Duplicate title found: publications received -> J00-2017, J14-1010
# Duplicate title found: erratum -> J00-3011, J14-4001
# Duplicate title found: american journal of computational linguistics (december 1974) -> J74-2000, J74-3000
# Duplicate title found: the finite string, volume 13, number 5 -> J76-2011, J76-2013
# Duplicate title found: the finite string, volume 14, number 1 (continued) -> J77-1003, J77-1007
# Duplicate title found: the finite string, volume 14, number 1 (continued) -> J77-1003, J77-1009
# Duplicate title found: language representation: papers presented in two sessions of tinlap-2 -> J78-3006, J78-3019
# Duplicate title found: american journal of computational linguistics (december 1978) -> J78-3000, J78-4000
# Duplicate title found: book reviews -> J80-1005, J80-1006
# Duplicate title found: announcements -> J80-1009, J80-2010
# Duplicate title found: abstracts of current literature -> J80-1010, J80-2011
# Duplicate title found: guidelines for submissions -> J80-1011, J80-2012
# Duplicate title found: announcements -> J80-1009, J80-3009
# Duplicate title found: abstracts of current literature -> J80-1010, J80-3010
# Duplicate title found: guidelines for submissions -> J80-1011, J80-3012
# Duplicate title found: announcements -> J80-1009, J81-1007
# Duplicate title found: abstracts of current literature -> J80-1010, J81-1008
# Duplicate title found: guidelines for submissions -> J80-1011, J81-1009
# Duplicate title found: abstracts of current literature -> J80-1010, J81-2006
# Duplicate title found: guidelines for submissions -> J80-1011, J81-2007
# Duplicate title found: program of the 1981 acl/lsa sessions -> J81-3006, J81-3007
# Duplicate title found: announcements -> J80-1009, J81-3009
# Duplicate title found: abstracts of current literature -> J80-1010, J81-3010
# Duplicate title found: guidelines for submissions -> J80-1011, J81-3011
# Duplicate title found: announcements -> J80-1009, J81-4010
# Duplicate title found: abstracts of current literature -> J80-1010, J81-4011
# Duplicate title found: announcements -> J80-1009, J82-1006
# Duplicate title found: abstracts of current literature -> J80-1010, J82-1007
# Duplicate title found: machine translation -> H93-1035, J82-2005
# Duplicate title found: call for papers -> J81-3008, J82-2008
# Duplicate title found: call for papers- 1983 acl meeting -> J82-2009, J82-2010
# Duplicate title found: announcements -> J80-1009, J82-2011
# Duplicate title found: abstracts of current literature -> J80-1010, J82-2012
# Duplicate title found: guidelines for submission -> J82-1008, J82-2013
# Duplicate title found: announcements -> J80-1009, J82-3007
# Duplicate title found: abstracts of current literature -> J80-1010, J82-3008
# Duplicate title found: acl membership list -> J81-4012, J82-3009
# Duplicate title found: guidelines for submission -> J82-1008, J82-3010
# Duplicate title found: announcements -> J80-1009, J83-1009
# Duplicate title found: abstracts of current literature -> J80-1010, J83-1010
# Duplicate title found: guidelines for submissions -> J80-1011, J83-1011
# Duplicate title found: announcements -> J80-1009, J83-2007
# Duplicate title found: abstracts of current literature -> J80-1010, J83-2008
# Duplicate title found: guidelines for submissions -> J80-1011, J83-2009
# Duplicate title found: announcements -> J80-1009, J83-3008
# Duplicate title found: abstracts of current literature -> J80-1010, J83-3009
# Duplicate title found: guidelines for submissions -> J80-1011, J83-3010
# Duplicate title found: site report -> J83-3007, J84-1004
# Duplicate title found: announcements -> J80-1009, J84-1005
# Duplicate title found: abstracts of current literature -> J80-1010, J84-1010
# Duplicate title found: guidelines for submission -> J82-1008, J84-1012
# Duplicate title found: calls for papers -> J84-1006, J84-2006
# Duplicate title found: announcements -> J80-1009, J84-2009
# Duplicate title found: abstracts of current literature -> J80-1010, J84-2010
# Duplicate title found: guidelines for submission -> J82-1008, J84-2011
# Duplicate title found: site report -> J83-3007, J84-3008
# Duplicate title found: program -> 1957.earlymt-1.24, J84-3009
# Duplicate title found: abstracts of current literature -> J80-1010, J84-3011
# Duplicate title found: calls for papers -> J84-1006, J85-1005
# Duplicate title found: programs -> J84-2007, J85-1006
# Duplicate title found: announcements -> J80-1009, J85-1007
# Duplicate title found: abstracts of current literature -> J80-1010, J85-1008
# Duplicate title found: calls for papers -> J84-1006, J85-2010
# Duplicate title found: announcements -> J80-1009, J85-2013
# Duplicate title found: abstracts of current literature -> J80-1010, J85-2014
# Duplicate title found: calls for papers -> J84-1006, J85-4007
# Duplicate title found: announcements -> J80-1009, J85-4009
# Duplicate title found: abstracts of current literature -> J80-1010, J85-4010
# Duplicate title found: abstracts of current literature -> J80-1010, J86-1012
# Duplicate title found: author index -> C80-1093, J86-1013
# Duplicate title found: title index -> J02-4012, J86-1014
# Duplicate title found: is mt linguistics? -> J86-1003, J86-2003
# Duplicate title found: books received -> J85-4006, J86-2007
# Duplicate title found: the finite string newsletter: announcements -> J86-1010, J86-2011
# Duplicate title found: abstracts of current literature -> J80-1010, J86-2013
# Duplicate title found: advertisements -> J00-1007, J86-2014
# Duplicate title found: the finite string newsletter: announcements -> J86-1010, J86-3008
# Duplicate title found: the finite string newsletter: calendar of meetings -> J86-1011, J86-3009
# Duplicate title found: abstracts of current literature -> J80-1010, J86-3010
# Duplicate title found: advertisements -> J00-1007, J86-3011
# Duplicate title found: books received -> J85-4006, J86-4008
# Duplicate title found: the finite string newsletter: calls for papers -> J86-1008, J86-4010
# Duplicate title found: the finite string newsletter: announcements -> J86-1010, J86-4011
# Duplicate title found: the finite string newsletter: calendar of meetings -> J86-1011, J86-4012
# Duplicate title found: abstracts of current literature -> J80-1010, J86-4013
# Duplicate title found: advertisements -> J00-1007, J86-4014
# Duplicate title found: book reviews -> J80-1005, J87-1008
# Duplicate title found: the finite string newsletter -> J86-1007, J87-1016
# Duplicate title found: the finite string newsletter: calls for papers -> J86-1008, J87-1017
# Duplicate title found: the finite string newsletter: announcements -> J86-1010, J87-1018
# Duplicate title found: the finite string newsletter: calendar of meetings -> J86-1011, J87-1019
# Duplicate title found: advertisements -> J00-1007, J87-1024
# Duplicate title found: commonsense metaphysics and lexical semantics -> H86-1013, J87-3004
# Duplicate title found: book reviews -> J80-1005, J87-3010
# Duplicate title found: the finite string newsletter -> J86-1007, J87-3012
# Duplicate title found: the finite string newsletter: announcements -> J86-1010, J87-3013
# Duplicate title found: the finite string newsletter: abstracts of current literature -> J87-1020, J87-3014
# Duplicate title found: advertisements -> J00-1007, J87-3015
# Duplicate title found: books received -> J85-4006, J88-1010
# Duplicate title found: abstracts of current literature -> J80-1010, J88-1011
# Duplicate title found: advertisements -> J00-1007, J88-1014
# Duplicate title found: briefly noted -> J00-2016, J88-2013
# Duplicate title found: books received -> J85-4006, J88-2014
# Duplicate title found: abstracts of current literature -> J80-1010, J88-2015
# Duplicate title found: advertisements -> J00-1007, J88-2016
# Duplicate title found: letter to the editor -> J07-1001, J88-3015
# Duplicate title found: advertisements -> J00-1007, J88-3021
# Duplicate title found: briefly noted -> J00-2016, J88-4013
# Duplicate title found: books recieved -> J87-1015, J88-4014
# Duplicate title found: abstracts of current literature -> J80-1010, J88-4015
# Duplicate title found: advertisements -> J00-1007, J88-4016
# Duplicate title found: briefly noted -> J00-2016, J89-1009
# Duplicate title found: books received -> J85-4006, J89-1010
# Duplicate title found: abstracts of current literature -> J80-1010, J89-1011
# Duplicate title found: advertisements -> J00-1007, J89-1014
# Duplicate title found: briefly noted -> J00-2016, J89-2013
# Duplicate title found: books received -> J85-4006, J89-2014
# Duplicate title found: abstracts of current literature -> J80-1010, J89-2015
# Duplicate title found: advertisements -> J00-1007, J89-2016
# Duplicate title found: briefly noted -> J00-2016, J89-3016
# Duplicate title found: books received -> J85-4006, J89-3017
# Duplicate title found: abstracts of current literature -> J80-1010, J89-3018
# Duplicate title found: advertisements -> J00-1007, J89-3019
# Duplicate title found: books received -> J85-4006, J89-4007
# Duplicate title found: abstracts of current literature -> J80-1010, J89-4008
# Duplicate title found: advertisements -> J00-1007, J89-4009
# Duplicate title found: letter to the editor -> J07-1001, J90-1005
# Duplicate title found: briefly noted -> J00-2016, J90-1013
# Duplicate title found: books received -> J85-4006, J90-1014
# Duplicate title found: abstracts of current literature -> J80-1010, J90-1015
# Duplicate title found: advertisements -> J00-1007, J90-1016
# Duplicate title found: briefly noted -> J00-2016, J90-2008
# Duplicate title found: books received -> J85-4006, J90-2009
# Duplicate title found: abstracts of current literature -> J80-1010, J90-2010
# Duplicate title found: advertisements -> J00-1007, J90-2011
# Duplicate title found: briefly noted -> J00-2016, J90-3009
# Duplicate title found: books received -> J85-4006, J90-3010
# Duplicate title found: abstracts of current literature -> J80-1010, J90-3011
# Duplicate title found: advertisements -> J00-1007, J90-3012
# Duplicate title found: letter to the editor -> J07-1001, J90-4004
# Duplicate title found: briefly noted -> J00-2016, J90-4008
# Duplicate title found: books received -> J85-4006, J90-4009
# Duplicate title found: abstracts of current literature -> J80-1010, J90-4010
# Duplicate title found: advertisements -> J00-1007, J90-4011
# Duplicate title found: books received -> J85-4006, J91-1009
# Duplicate title found: advertisements -> J00-1007, J91-1012
# Duplicate title found: briefly noted -> J00-2016, J91-2011
# Duplicate title found: books received -> J85-4006, J91-2012
# Duplicate title found: advertisements -> J00-1007, J91-2013
# Duplicate title found: books received -> J85-4006, J91-3011
# Duplicate title found: advertisements -> J00-1007, J91-3012
# Duplicate title found: books received -> J85-4006, J91-4008
# Duplicate title found: advertisements -> J00-1007, J91-4009
# Duplicate title found: briefly noted -> J00-2016, J92-1012
# Duplicate title found: books received -> J85-4006, J92-1013
# Duplicate title found: advertisements -> J00-1007, J92-1016
# Duplicate title found: advertisements -> J00-1007, J92-2007
# Duplicate title found: briefly noted -> J00-2016, J92-3013
# Duplicate title found: advertisements -> J00-1007, J92-3014
# Duplicate title found: briefly noted -> J00-2016, J92-4013
# Duplicate title found: books received -> J85-4006, J92-4014
# Duplicate title found: advertisements -> J00-1007, J92-4015
# Duplicate title found: structural ambiguity and lexical relations -> H90-1052, J93-1005
# Duplicate title found: briefly noted -> J00-2016, J93-1016
# Duplicate title found: advertisements -> J00-1007, J93-1017
# Duplicate title found: books received -> J85-4006, J93-2012
# Duplicate title found: letters to the editor -> J92-2006, J93-2013
# Duplicate title found: briefly noted -> J00-2016, J93-3010
# Duplicate title found: books received -> J85-4006, J93-3011
# Duplicate title found: advertisements -> J00-1007, J93-3012
# Duplicate title found: briefly noted -> J00-2016, J93-4007
# Duplicate title found: books received -> J85-4006, J93-4008
# Duplicate title found: advertisements -> J00-1007, J93-4011
# Duplicate title found: briefly noted -> J00-2016, J94-1014
# Duplicate title found: advertisements -> J00-1007, J94-1015
# Duplicate title found: briefly noted -> J00-2016, J94-2008
# Duplicate title found: books received -> J85-4006, J94-2009
# Duplicate title found: erratum -> J00-3011, J94-2010
# Duplicate title found: advertisements -> J00-1007, J94-2011
# Duplicate title found: commentary on kaplan and kay -> J94-3002, J94-3003
# Duplicate title found: commentary on lowe and mazaudon -> J94-3005, J94-3006
# Duplicate title found: commentary on daelemans, gillis, and durieux -> J94-3008, J94-3009
# Duplicate title found: commentary on bird and klein -> J94-3011, J94-3012
# Duplicate title found: advertisements -> J00-1007, J94-3016
# Duplicate title found: briefly noted -> J00-2016, J94-4010
# Duplicate title found: books received -> J85-4006, J94-4011
# Duplicate title found: advertisements -> J00-1007, J94-4014
# Duplicate title found: briefly noted -> J00-2016, J95-1011
# Duplicate title found: books received -> J85-4006, J95-1012
# Duplicate title found: advertisements -> J00-1007, J95-1013
# Duplicate title found: briefly noted -> J00-2016, J95-2008
# Duplicate title found: books received -> J85-4006, J95-2009
# Duplicate title found: letter to the editor -> J07-1001, J95-2010
# Duplicate title found: advertisements -> J00-1007, J95-2011
# Duplicate title found: briefly noted -> J00-2016, J95-3009
# Duplicate title found: books received -> J85-4006, J95-3010
# Duplicate title found: advertisements -> J00-1007, J95-3011
# Duplicate title found: briefly noted -> J00-2016, J95-4012
# Duplicate title found: books received -> J85-4006, J95-4013
# Duplicate title found: advertisements -> J00-1007, J95-4016
# Duplicate title found: books received -> J85-4006, J96-1010
# Duplicate title found: advertisements -> J00-1007, J96-1011
# Duplicate title found: briefly noted -> J00-2016, J96-2009
# Duplicate title found: books received -> J85-4006, J96-2010
# Duplicate title found: letters to the editor -> J92-2006, J96-2011
# Duplicate title found: advertisements -> J00-1007, J96-2012
# Duplicate title found: briefly noted -> J00-2016, J96-3013
# Duplicate title found: books received -> J85-4006, J96-3014
# Duplicate title found: advertisements -> J00-1007, J96-3015
# Duplicate title found: briefly noted -> J00-2016, J96-4010
# Duplicate title found: publications received -> J00-2017, J96-4011
# Duplicate title found: advertisements -> J00-1007, J96-4014
# Duplicate title found: advertisements -> J00-1007, J97-1009
# Duplicate title found: briefly noted -> J00-2016, J97-2007
# Duplicate title found: publications received -> J00-2017, J97-2008
# Duplicate title found: advertisements -> J00-1007, J97-2009
# ...
# Duplicate title found: assent and compliance in children’s language comprehension -> J78-3023, T78-1016
# Duplicate title found: speech acts as a basis for understanding dialogue coherence -> J78-3024, T78-1017
# Duplicate title found: a framework for comparing language experiences (with particular emphasis on: the effect of audience on discourse models) -> J78-3025, T78-1018
# Duplicate title found: intentlonallty and human conversations -> J78-3026, T78-1019
# Duplicate title found: on the interdependence of language and perception -> J78-3027, T78-1020
# Duplicate title found: the problem of naming shapes: vision-language interface -> J78-3028, T78-1021
# Duplicate title found: an argument about the composition of conceptual structure -> J78-3029, T78-1022
# Duplicate title found: on the ontological status of visual mental images -> J78-3030, T78-1023
# Duplicate title found: what has language to do with perception? some speculations on the lingua mentis -> J78-3031, T78-1024
# Duplicate title found: semantic primitives in language and vision -> J78-3032, T78-1025
# Duplicate title found: a note on partial match of descriptions. can one simultaneously question (retrieve) and inform (update)? -> J78-3034, T78-1026
# Duplicate title found: with a spoon in hand this must be the eating frame -> J78-3035, T78-1027
# Duplicate title found: fragments of a theory of human plausible reasoning -> J78-3036, T78-1028
# Duplicate title found: indirect responses to loaded questions -> J78-3037, T78-1029
# Duplicate title found: on reasoning by default -> J78-3038, T78-1030
# Duplicate title found: path-based and node-based inference in semantic networks -> J78-3039, T78-1031
# Duplicate title found: the representation of derivable information in memory: when what might have been left unsaid is said -> J78-3040, T78-1032
# Duplicate title found: a heuristic for paradigms -> J78-3041, T78-1033
# Duplicate title found: a computational account of some constraints on language -> J78-3042, T78-1034
# Duplicate title found: remarks on processing, constraints, and the lexicon -> J78-3043, T78-1035
# Duplicate title found: list of questions suggested for consideration in each session -> J78-3044, T78-1036
# Duplicate title found: a compact architecture for dialogue management based on scripts and meta-outputs -> A00-1016, W00-0311
# Duplicate title found: author index -> C80-1093, W00-0907
# Duplicate title found: author index -> C80-1093, W00-1111
# Duplicate title found: author index -> C80-1093, W00-1328
# Duplicate title found: finite-state non-concatenative morphotactics -> P00-1025, W00-1801
# Duplicate title found: automatic summarization -> P11-5003, W01-0100
# Duplicate title found: introduction -> 1957.earlymt-1.1, W01-0901
# Duplicate title found: a best-first alignment algorithm for automatic extraction of transfer mappings from bilingual corpora -> 2001.mtsummit-ebmt.4, W01-1406
# Duplicate title found: preface -> 1998.eamt-1.1, W01-1501
# Duplicate title found: empirical methods for evaluating dialog systems -> W01-0902, W01-1614
# Duplicate title found: high precision extraction of grammatical relations -> C02-1013, W01-1808
# Duplicate title found: nltk: the natural language toolkit -> P04-3031, W02-0109
# Duplicate title found: topic detection based on dialogue history -> C02-1082, W02-0702
# Duplicate title found: towards a road map on human language technology: natural language processing -> 2002.tmi-tmiw.8, W02-1302
# Duplicate title found: author index -> C80-1093, W03-2207
# Duplicate title found: author index -> C80-1093, W03-2318
# Duplicate title found: author index -> C80-1093, W03-2418
# Duplicate title found: author index -> C80-1093, W03-2510
# Duplicate title found: author index -> C80-1093, W03-2610
# Duplicate title found: author index -> C80-1093, W03-2716
# Duplicate title found: chinese word segmentation by classification of characters -> O05-4005, W04-1109
# Duplicate title found: automated induction of sense in context -> C04-1133, W04-1908
# Duplicate title found: author index -> C80-1093, W04-3257
# Duplicate title found: author index -> C80-1093, W05-1109
# Duplicate title found: the role of lexical resources in cjk natural language processing -> W06-0109, W06-1002
# Duplicate title found: constraining the phrase-based, joint probability statistical translation model -> 2006.amta-papers.2, W06-3123
# Duplicate title found: towards a redundancy elimination algorithm for underspecified descriptions -> W06-3904, W06-3905
# Duplicate title found: syntactic reordering integrated with phrase-based smt -> C08-1027, W08-0406
# Duplicate title found: the effect of dialogue system output style variation on users’ evaluation judgments and input style -> W08-0129, W08-1117
# Duplicate title found: author index -> C80-1093, W08-1141
# Duplicate title found: ksc-pal: a peer learning agent that encourages students to take the initiative -> N10-2005, W09-2109
# Duplicate title found: semeval-2010 task 1: coreference resolution in multiple languages -> S10-1001, W09-2411
# Duplicate title found: semeval-2010 task 2: cross-lingual lexical substitution -> S10-1002, W09-2412
# Duplicate title found: semeval-2010 task 3: cross-lingual word sense disambiguation -> S10-1003, W09-2413
# Duplicate title found: semeval-2010 task 7: argument selection and coercion -> S10-1005, W09-2414
# Duplicate title found: semeval-2010 task 8: multi-way classification of semantic relations between pairs of nominals -> S10-1006, W09-2415
# Duplicate title found: semeval-2010 task 10: linking events and their participants in discourse -> S10-1008, W09-2417
# Duplicate title found: semeval-2010 task 17: all-words word sense disambiguation on a specific domain -> S10-1013, W09-2420
# Duplicate title found: co-parsing with competitive models -> R09-1033, W09-3816
# Duplicate title found: author index -> C80-1093, W10-4238
# Duplicate title found: an analysis of questions in a q&a site resubmitted based on indications of unclear points of original questions -> I11-1167, W11-3103
# Duplicate title found: introduction -> 1957.earlymt-1.1, W12-0201
# Duplicate title found: active learning for coreference resolution -> N12-1055, W12-2409
# Duplicate title found: subjectivity word sense disambiguation -> D09-1020, W12-3702
# Duplicate title found: the benefits of a model of annotation -> Q14-1025, W13-2323
# Duplicate title found: unsupervised relation extraction with general domain knowledge -> D13-1040, W13-3809
# Duplicate title found: social metaphor detection via topical analysis -> O14-3001, W13-4203
# Duplicate title found: modeling the helpful opinion mining of online consumer reviews as a classification problem -> O14-3002, W13-4205
# Duplicate title found: unsupervised learning of bilingual categories in inversion transduction grammar induction -> 2013.iwslt-papers.15, W13-5703
# Duplicate title found: power of confidence: how poll scores impact topic dynamics in political debates -> W14-2514, W14-2710
# Duplicate title found: non-projective dependency-based pre-reordering with recurrent neural network for machine translation -> P15-1082, W15-1002
# Duplicate title found: proceedings of the 18th annual conference of the european association for machine translation -> 2015.eamt-1.0, W15-4900
# Duplicate title found: exploiting portability to build an rbmt prototype for a new source language -> 2015.eamt-1.2, W15-4901
# Duplicate title found: using on-line available sources of bilingual information for word-level machine translation quality estimation -> 2015.eamt-1.4, W15-4903
# Duplicate title found: a general framework for minimizing translation effort: towards a principled combination of translation technologies in computer-aided translation -> 2015.eamt-1.5, W15-4904
# Duplicate title found: dependency-based reordering model for constituent pairs in hierarchical smt -> 2015.eamt-1.7, W15-4906
# Duplicate title found: the role of artificially generated negative data for quality estimation of machine translation -> 2015.eamt-1.8, W15-4907
# Duplicate title found: document-level machine translation with word vector models -> 2015.eamt-1.9, W15-4908
# Duplicate title found: the potential and limits of lay post-editing in an online community -> 2015.eamt-1.10, W15-4909
# Duplicate title found: post-editing evaluations: trade-offs between novice and professional participants -> 2015.eamt-1.11, W15-4910
# Duplicate title found: benchmarking smt performance for farsi using the tep++ corpus -> 2015.eamt-1.12, W15-4911
# Duplicate title found: dynamic terminology integration methods in statistical machine translation -> 2015.eamt-1.13, W15-4912
# Duplicate title found: identifying main obstacles for statistical machine translation of morphologically rich south slavic languages -> 2015.eamt-1.14, W15-4913
# Duplicate title found: poor man’s lemmatisation for automatic error classification -> 2015.eamt-1.15, W15-4914
# Duplicate title found: truly exploring multiple references for machine translation evaluation -> 2015.eamt-1.16, W15-4915
# Duplicate title found: searching for context: a study on document-level labels for translation quality estimation -> 2015.eamt-1.17, W15-4916
# Duplicate title found: stripping adjectives: integration techniques for selective stemming in smt systems -> 2015.eamt-1.18, W15-4917
# Duplicate title found: evaluating machine translation for assimilation via a gap-filling task -> 2015.eamt-1.19, W15-4918
# Duplicate title found: assessing linguistically aware fuzzy matching in translation memories -> 2015.eamt-1.21, W15-4920
# Duplicate title found: re-assessing the wmt2013 human evaluation with professional translators trainees -> 2015.eamt-1.22, W15-4921
# Duplicate title found: integrating a large, monolingual corpus as translation memory into statistical machine translation -> 2015.eamt-1.23, W15-4922
# Duplicate title found: word alignment based parallel corpora evaluation and cleaning using machine learning techniques -> 2015.eamt-1.25, W15-4924
# Duplicate title found: pre-reordering for statistical machine translation of non-fictional subtitles -> 2015.eamt-1.27, W15-4926
# Duplicate title found: evaluation of the domain adaptation of mt systems in accurat -> 2015.eamt-1.29, W15-4928
# Duplicate title found: mixedemotions: social semantic emotion analysis for innovative multilingual big data analytics markets -> 2015.eamt-1.30, W15-4929
# Duplicate title found: the accept academic portal: bringing together pre-editing, mt and post-editing into a learning environment -> 2015.eamt-1.31, W15-4930
# Duplicate title found: russian-chinese sentence-level aligned news corpus -> 2015.eamt-1.32, W15-4931
# Duplicate title found: himl (health in my language) -> 2015.eamt-1.33, W15-4932
# Duplicate title found: mt-enhanced fuzzy matching with transit nxt and star moses -> 2015.eamt-1.34, W15-4933
# Duplicate title found: handycat - an open-source platform for cat tool research -> 2015.eamt-1.35, W15-4934
# Duplicate title found: tramooc: translation for massive open online courses -> 2015.eamt-1.36, W15-4935
# Duplicate title found: estonian-english reversible smart phone dictionary of military terms and relevant vocabulary -> 2015.eamt-1.38, W15-4937
# Duplicate title found: falcon: federated active linguistic data curation -> 2015.eamt-1.39, W15-4938
# Duplicate title found: tapadóir -> 2015.eamt-1.40, W15-4939
# Duplicate title found: okapi+quest: translation quality estimation within okapi -> 2015.eamt-1.41, W15-4940
# Duplicate title found: cracker: cracking the language barrier -> 2015.eamt-1.42, W15-4941
# Duplicate title found: ltc knowhow: empowering the social enterprise in the language industry -> 2015.eamt-1.43, W15-4942
# Duplicate title found: multi-dialect machine translation (mudmat) -> 2015.eamt-1.44, W15-4943
# Duplicate title found: abu-matran: automatic building of machine translation -> 2014.eamt-1.29, W15-4944
# Duplicate title found: mnh-tt: a platform to support collaborative translator training -> 2015.eamt-1.46, W15-4945
# Duplicate title found: proceedings of the joint workshop on nlp for computer assisted language learning and nlp for language acquisition -> W16-6500, W17-0300
# Duplicate title found: piecewise latent variables for neural variational text processing -> D17-1043, W17-4308
# Duplicate title found: hindi shabdamitra: a wordnet based e-learning tool for language learning and teaching -> W17-5904, W17-7531
# Duplicate title found: author index -> C80-1093, W17-7625
# Duplicate title found: domain adapted word embeddings for improved sentiment classification -> P18-2007, W18-3407
# Duplicate title found: collecting diverse natural language inference problems for sentence representation evaluation -> D18-1007, W18-5441
# Duplicate title found: grammar induction with neural language models: an unusual replication -> D18-1544, W18-5452
# Duplicate title found: limitations in learning an interpreted language with recurrent models -> 2020.scil-1.55, W18-5456
# Duplicate title found: proceedings of the workshop on cognitive modeling and computational linguistics -> 2020.cmcl-1.0, W19-2900
# Duplicate title found: lipstick on a pig: debiasing methods cover up systematic gender biases in word embeddings but do not remove them -> N19-1061, W19-3621
# Duplicate title found: how does grammatical gender affect noun representations in gender-marking languages? -> K19-1043, W19-3622
# Duplicate title found: evaluating coherence in dialogue systems using entailment -> N19-1381, W19-3646
# Duplicate title found: equiprobable mappings in weighted constraint grammars -> 2020.scil-1.14, W19-4215
# Duplicate title found: adversarial attack on sentiment classification -> W19-3653, W19-4824
# Duplicate title found: a general computational model for word-form recognition and production -> P84-1038, W83-0114
# Duplicate title found: parsing, word associations and typical predicate-argument relations -> H89-2012, W89-0240
# Duplicate title found: author index -> C80-1093, W91-0117
# Duplicate title found: author index -> C80-1093, W91-0224
# Duplicate title found: robust text processing in automated information retrieval -> A94-1028, W93-0302
# Duplicate title found: author index -> C80-1093, W96-0419
# Duplicate title found: author index -> C80-1093, W96-0515
# Duplicate title found: a model for multimodal reference resolution -> J00-2002, W97-1414
# Duplicate title found: using suffix arrays to compute term frequency and document frequency for all substrings in a corpus -> J01-1001, W98-1104
# Duplicate title found: author index -> C80-1093, W98-1313
# Duplicate title found: author index -> C80-1093, W98-1513
# Duplicate title found: preface -> 1998.eamt-1.1, W99-0401
# Duplicate title found: template design for information extraction -> M93-1003, X93-1015
# Duplicate title found: tipster/muc-5 information extraction system evaluation -> M93-1004, X93-1016
# Duplicate title found: the tipster/shogun project -> H94-1098, X93-1020
# Duplicate title found: the message understanding conferences -> X93-1003, X96-1006
# Duplicate title found: spot: trw’s multi-lingual text search tool -> X96-1015, X96-1023
# Duplicate title found: the text retrieval conferences (trecs) -> X96-1007, X96-1046
# Duplicate title found: design of the muc-6 evaluation -> M95-1001, X96-1047
# Duplicate title found: overview of results of the muc-6 evaluation -> M95-1002, X96-1048
# Duplicate title found: the text retrieval conferences (trecs) -> X96-1007, X98-1031
# Duplicate title found: author index -> C80-1093, Y02-1045
# Duplicate title found: multiply quantified internally headed relative clause in japanese: a skolem term based approach -> O06-5002, Y05-1016
# Duplicate title found: machine transliteration -> J98-4003, Y06-1050
# Duplicate title found: towards a semantic annotation of english television news - building and evaluating a constraint grammar framenet -> Y12-1006, Y12-1036
# Duplicate title found: bccwj-timebank: temporal and event information annotation on japanese text -> O14-4001, Y13-1019
# Duplicate title found: chinese spelling check based on neural machine translation -> 2020.ijclclp-1.1, Y18-1042

# %%
title = "A Computational Lexicography of Multi-Word Units: How Efficient Can It Be?".lower()
candidates = {}
for paper in anthology.papers():
    if title in str(paper.title).lower():
        candidates[str(paper.title)] = paper
for c in candidates:
    print(c)

# %%
difflib.get_close_matches("Bilingual Correspondence Recursive Autoencodersfor Statistical Machine Translation".lower(),
candidates.keys(), n=5, cutoff=0.8)
# Out:
# ['Bilingual Correspondence Recursive Autoencoder for Statistical Machine Translation']
