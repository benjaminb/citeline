# %%
import pandas as pd
import json

results_path = "../experiments/multiple_query_expansion/results/search_results.jsonl"
N = 100

with open(results_path) as f:
    
    lines = [json.loads(line) for _, line in zip(range(N), f)]
results = pd.DataFrame(lines)
results.head()
# Out:
#                                               record  \
# 0  {'source_doi': '10.1016/j.newar.2024.101694', ...
# 1  {'source_doi': '10.1016/j.newar.2024.101694', ...
# 2  {'source_doi': '10.1016/j.newar.2024.101694', ...
# 3  {'source_doi': '10.1016/j.newar.2024.101694', ...
# 4  {'source_doi': '10.1016/j.newar.2024.101694', ...
#
#                                              results
# 0  [{'text': 'Secondly, we use the subset of our ...
# 1  [{'text': 'Third panel shows the pairs with (c...
# 2  [{'citation_count': 325, 'text': 'Likely chanc...
# 3  [{'text': 'Population synthesis models of thes...
# 4  [{'doi': '10.3847/2041-8213/ac7c70', 'pubdate'...

# %%
results.iloc[0]['record'].keys()
# Out:
# dict_keys(['source_doi', 'sent_original', 'sent_no_cit', 'sent_idx', 'citation_dois', 'pubdate', 'resolved_bibcodes', 'sent_cit_masked', 'vector_original', 'add_prev_2', 'vector_add_prev_2'])
