# %% [markdown]
# 1. Load a review dataset into memory
# 1. For each paper, parse the body into sentences
# 1. Iterate over sentences:
#     1. Extract any inline citations
#     1. Check if the inline citation is resolvable to a bibcode
#         1. If resolvable, add the (doc, sentence, [bibcodes]) to dataset
#         1. Otherwise, skip it

# %%
import json
import os
from pprint import pprint
from tqdm import tqdm

PATH_TO_DATA = 'data/processed_for_chroma/reviews'
FILENAMES = os.listdir(PATH_TO_DATA)
data = dict()

def load_dataset(filename):
    with open(f'{PATH_TO_DATA}/{filename}', 'r') as file:
        # data[os.path.splitext(os.path.basename(filename))[0]] = json.load(file)
        data = json.load(file)

    for record in data['metadatas']:
        record['reference'] = json.loads(record['reference'])
        record['doi'] = json.loads(record['doi'])

    return data['metadatas']

data = load_dataset('Astro_Reviews.json')
print(data[0].keys())
# Out:
# dict_keys(['bibcode', 'abstract', 'aff', 'author', 'bibstem', 'doctype', 'doi', 'id', 'keyword', 'pubdate', 'title', 'read_count', 'reference', 'citation_count', 'citation', 'body'])

# %%
import pysbd

seg = pysbd.Segmenter(language="en", clean=False)

# %%
# Test the segmentation
sentences = seg.segment(data[0]['body'])
print(f"Length: {len(sentences)}")
print(f"Examples: {sentences[:2]}")
# Out:
# Length: 699
# Examples: ['1. INTRODUCTION The solar chemical composition is a fundamental yardstick in astronomy, to which the elemental abundances of essentially all cosmic objects, be they planets, stars, nebulae or galaxies, are anchored. ', 'The importance of having accurate solar elemental abundances thus can not be overstated. ']

# %%
import re

# Define the patterns
lastname = r"[A-Z][a-zA-ZÀ-ÖØ-öø-ÿ-]*(?:'[A-Z][a-zA-ZÀ-ÖØ-öø-ÿ-]*)?"
year = r"\(?(\d{4}[a-z]?)\)?"
name_sep = r",?\s"
INLINE_CITATION_PATTERN = fr"({lastname}(?:{name_sep}{lastname})*(?: et al.?)?)\s*{year}"

# Compile the regex pattern
inline_regex = re.compile(INLINE_CITATION_PATTERN)


def get_inline_citations(text: str) -> list[tuple[str, str]]:
    return [match.groups() for match in inline_regex.finditer(text)]

# %%
for sentence in sentences[:3]:
    match_groups = inline_regex.finditer(sentence)
    matches = get_inline_citations(sentence)
    print(f"Sentence: {sentence}")
    print(f"Matches: {matches}")
# Out:
# Sentence: 1. INTRODUCTION The solar chemical composition is a fundamental yardstick in astronomy, to which the elemental abundances of essentially all cosmic objects, be they planets, stars, nebulae or galaxies, are anchored.
# Matches: []
# Sentence: The importance of having accurate solar elemental abundances thus can not be overstated.
# Matches: []
# Sentence: From the pioneering efforts of Russell (1929) , Suess Urey (1956) , and Goldberg, Müller Aller (1960) to the more recent works of Anders Grevesse (1989) , Grevesse Sauval (1998) , Lodders (2003) , Asplund, Grevesse Sauval (2005) , Grevesse, Asplund Sauval (2007) , and Lodders, Palme Gail (2009) , compilations of the Solar System abundances have found extremely wide-ranging use in astronomy and cosmology.
# Matches: [('Russell', '1929'), ('Suess Urey', '1956'), ('Goldberg, Müller Aller', '1960'), ('Anders Grevesse', '1989'), ('Grevesse Sauval', '1998'), ('Lodders', '2003'), ('Asplund, Grevesse Sauval', '2005'), ('Grevesse, Asplund Sauval', '2007'), ('Lodders, Palme Gail', '2009')]

# %%
def bibcode_regex(author: str, year: str):
    """
    Given first author and year, return a regex pattern for the
    corresponding bibcode
    """
    initial = author[0]
    year = year[:4]  # cut off any letters at the end
    pattern = fr'^{year}.*{initial}$'
    return re.compile(pattern)


def bibcode_matches(inline_citation: tuple[str, str], references: list[str]) -> int:
    """
    Given an inline citation and a list of references, return the number of
    references that match the inline citation's bibcode regex pattern
    """
    pattern = bibcode_regex(*inline_citation)
    return [s for s in references if pattern.match(s)]


def make_citation_bibcode_list(inline_citations: list[tuple[str, str]], references: list[str]) -> list[tuple[tuple[str, str], str]]:
    """
    Given a paper's list of inline citations and list of references, return a list of
    tuples where the first element is the inline citation and the second element
    is the corresponding bibcode from the references list where there is exactly one match
    """
    return [(citation, matches[0]) for citation in inline_citations
            if len((matches := bibcode_matches(citation, references))) == 1]

def get_bibcodes_from_inline(text: str, references: list[str]) -> list[str]:
    reference_matches = [matches[0] for citation in get_inline_citations(text) if len((matches := bibcode_matches(citation, references))) == 1]
    return reference_matches

# %%
def make_samples_from_record(record: dict, segmenter: pysbd.Segmenter):
    sentences = segmenter.segment(record['body'])
    samples = []
    for sentence in sentences:
        bibcodes = get_bibcodes_from_inline(sentence, record['reference'])
        if bibcodes:
            samples.append({'doi': record['doi'][0], 'sentence': sentence, 'bibcodes': bibcodes})

    return samples


samples = make_samples_from_record(data[0], segmenter=seg)
for i, sample in enumerate(samples):
    print(i, sample)
# Out:
# 0 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'From the pioneering efforts of Russell (1929) , Suess Urey (1956) , and Goldberg, Müller Aller (1960) to the more recent works of Anders Grevesse (1989) , Grevesse Sauval (1998) , Lodders (2003) , Asplund, Grevesse Sauval (2005) , Grevesse, Asplund Sauval (2007) , and Lodders, Palme Gail (2009) , compilations of the Solar System abundances have found extremely wide-ranging use in astronomy and cosmology. ', 'bibcodes': ['1929ApJ....70...11R', '1956RvMP...28...53S', '1960ApJS....5....1G', '1989GeCoA..53..197A', '1998SSRv...85..161G', '2003ApJ...591.1220L']}
# 1 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Prior knowledge of the solar photospheric Si abundance is therefore required in order to place the meteoritic abundances on the same absolute scale as the Sun ( Suess Urey 1956 ). ', 'bibcodes': ['1956RvMP...28...53S']}
# 2 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In the decade since the appearance of the widely used compilation of the solar chemical composition by Grevesse Sauval (1998) , the abundances of a large number of elements have been revised, several rather severely (e.g., Asplund, Grevesse Sauval 2005 ). ', 'bibcodes': ['1998SSRv...85..161G']}
# 3 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The most commonly used optical disk-center intensity spectra of the quiet Sun are the so-called Jungfraujoch or Liège atlas (after its locations of observation and production, respectively; Delbouille, Roland Neven 1973 ) and the Kitt Peak solar atlas ( Neckel Labs 1984 ). ', 'bibcodes': ['1973apds.book.....D', '1984SoPh...90..205N']}
# 4 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'There are also corresponding IR disk-center intensity atlases observed from Kitt Peak ( Delbouille et al. 1981 ) and from the Atmospheric Trace Molecule Spectroscopy (ATMOS ) experiment flown on the space shuttle ( Farmer Norton 1989 ; Abrams et al. 1996 ). ', 'bibcodes': ['1989hra2.book.....F', '1996ApOpt..35.2747A']}
# 5 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Finally, the solar flux spectrum has recently been rereduced by Kurucz (2006) ; see also Kurucz et al. (1984) for an earlier rendition of the same Kitt Peak solar data set. ', 'bibcodes': ['2006astro.ph..5029K', '1984sfat.book.....K']}
# 6 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Much laudable work has been done in improving the gf -values for a large number of transitions (e.g., Kurucz 1992 ; Johansson et al. 2003 ; Lawler et al. 2006 ; Sobeck, Lawler Sneden 2007 ), but several elements and lines still have surprisingly uncertain transition probabilities. ', 'bibcodes': ['1992RMxAA..23...45K', '2003ApJ...584L.107J', '2007ApJ...667.1267S']}
# 7 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': "Another important advancement in recent years is that it is now possible to accurately compute the pressure broadening (also known as van der Waals broadening) of metal lines ( Anstee O'Mara 1995 ; Barklem, Piskunov O'Mara 2000a ; Barklem Aspelund-Johansson 2005 ), which has made the classical Unsöld broadening and its ad hoc enhancement factors largely obsolete, at least for neutral species. ", 'bibcodes': ['1995MNRAS.276..859A']}
# 8 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In the absence of realistic evaluations, classical recipes such as those of van Regemorter (1962) and Drawin (1968) are frequently used but cannot be expected to be more than order-of-magnitude estimates at best. ', 'bibcodes': ['1968ZPhy..211..404D']}
# 9 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Convective energy transport is normally described by the mixing length theory ( Böhm-Vitense 1958 ). ', 'bibcodes': ['1958ZA.....46..108B']}
# 10 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The most widely used theoretical 1D model atmospheres for solar-type stars are the Kurucz (1993) and MARCS ( Gustafsson et al. 2008 ) grids of models. ', 'bibcodes': ['1993A&A...275..269K']}
# 11 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Several semiempirical solar models are on the market, including the Holweger Müller (1974) , VAL3C ( Vernazza, Avrett Loeser 1976 ), and MISS ( Allende Prieto et al. 2001 ) models. ', 'bibcodes': ['1974SoPh...39...19H', '1976ApJS...30....1V']}
# 12 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The venerable Holweger Müller model, in fact, dates back more than forty years, since the 1974 version was simply a new pressure-integration of the original Holweger (1967) model using updated equation of state and continuous opacities. ', 'bibcodes': ['1967ZA.....65..365H']}
# 13 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The light blue shaded region corresponds to the spatial and temporal root mean square variations of the 3D model, whereas the red and yellow curves denote the 1D semiempirical Holweger Müller (1974) and the 1D theoretical MARCS ( Gustafsson et al. 2008 ) model atmospheres, respectively. ', 'bibcodes': ['1974SoPh...39...19H']}
# 14 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'More recently it has become tractable to perform 3D, time-dependent, hydrodynamical simulations of the stellar surface convection (e.g., Stein Nordlund 1998 ; Asplund et al. 1999 ; Freytag, Steffen Dorch 2002 ; Vögler, Bruls Schüssler 2004 ). ', 'bibcodes': ['1998ApJ...499..914S', '1999A&A...346L..17A', '2002AN....323..213F', '2004A&A...421..741V']}
# 15 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Rather than solving for many thousands of frequency points as regularly done in theoretical 1D hydrostatic models, the wavelength variation of opacity is represented by a small number of typical opacity bins (4–20) in order to compute the radiative heating/cooling rate that enters the energy equation ( Nordlund 1982 ). ', 'bibcodes': ['1982A&A...107....1N']}
# 16 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The reader is referred to Nordlund, Stein Asplund (2009) for a recent review of the physics of solar surface convection and the numerical details of its simulation. ', 'bibcodes': ['2009LRSP....6....2N']}
# 17 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The reason that these so-called large-eddy simulations are nevertheless quite successful in reproducing the real photosphere is that the mean stratification is largely independent of numerical resolution ( Stein Nordlund 1998 ; Asplund et al. 2000a ). ', 'bibcodes': ['1998ApJ...499..914S']}
# 18 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Current generations of 3D models are very successful in reproducing the observed solar granulation topology, typical length- and timescales, convective velocities, and intensity brightness contrast (e.g., Nordlund, Stein Asplund 2009 ), clearly none of which 1D models are able to predict. ', 'bibcodes': ['2009LRSP....6....2N']}
# 19 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Ayres, Plymate Keller (2006) have criticized the 3D hydrodynamical model of Asplund et al. (2000b) , ofen used in recent solar abundance analyses, for having too steep a temperature gradient as judged by the observed center-to-limb variation. ', 'bibcodes': ['2006ApJS..165..618A']}
# 20 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Koesterke, Allende Prieto Lambert (2008) reach a somewhat milder conclusion, presumably because they performed spectral synthesis with the full 3D model rather than with only the spatially averaged version used by Ayres, Plymate Keller. ', 'bibcodes': ['2008ApJ...680..764K']}
# 21 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Indeed it outperforms all 1D models, even the semiempirical Holweger Müller (1974) model, which was designed to fit this diagnostic. ', 'bibcodes': ['1974SoPh...39...19H']}
# 22 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Figure 2 Comparison of the predicted continuum center-to-limb variation as a function of wavelength for different solar model atmospheres against observations ( Neckel Labs 1994 ). ', 'bibcodes': ['1994SoPh..153...91N']}
# 23 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The 3D hydrodynamical model (Trampedach et al., in preparation) used in this review outperforms even the Holweger Müller (1974) semiempirical model, which was designed to satisfy this diagnostic (Pereira et al., in preparation). ', 'bibcodes': ['1974SoPh...39...19H']}
# 24 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'With 1D theoretical model atmospheres, the H i lines imply too low T eff for the Sun by 50–100 K and have the wrong line shapes when the most accurate line broadening data are used ( Barklem et al. 2002 ). ', 'bibcodes': ['2002A&A...385..951B']}
# 25 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In contrast, the H i lines suggest that the temperature gradient of the Holweger Müller (1974) semiempirical model is too shallow. ', 'bibcodes': ['1974SoPh...39...19H']}
# 26 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Such line broadening can thus be explained as the result of the Doppler shifts arising from the convective motions with a smaller contribution from the solar oscillations (e.g., Nordlund, Stein Asplund 2009 , and references therein). ', 'bibcodes': ['2009LRSP....6....2N']}
# 27 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'For comparison purposes, also shown is the predicted profile from a 1D model atmosphere ( red line ; Holweger Müller 1974 ); the 1D profile has been computed with a microturbulence of 1 km s −1 and a tuned macroturbulence to obtain the right overall linewidth. ', 'bibcodes': ['1974SoPh...39...19H']}
# 28 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': '[Throughout this review, we adopt the customary astronomical scale for logarithmic abundances where H is defined to be log ε H = 12.00, that is, log ε X = log( N X / N H ) + 12, where N X and N H are the number densities of elements X and H, respectively.] Figure 4 shows how the solar abundances vary with atomic number, illustrating several key features of nuclear and stellar physics: the high primordial H and He abundances; the fragile nature of Li, Be, and B; the relatively high abundance of elements involved in stellar H-, He-, and C-burning, modulated by the odd-even effect and the α -capture effect; the high nuclear binding energy and near-nuclear statistical equilibrium for the Fe-peak; and the production of the heavy elements through successive neutron captures with peaks around the magic nuclei possessing closed neutron shells (e.g., Pagel 1997 ). ', 'bibcodes': ['1997nceg.book.....P']}
# 29 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The first uncertainty has been estimated by taking half the difference between the results with the spatially averaged 3D model (denoted 〈3D〉) and the Holweger Müller (1974) model. ', 'bibcodes': ['1974SoPh...39...19H']}
# 30 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Occasionally, we have employed the difference between the cases with and without inelastic H collisions through the Drawin (1968) formula, while taking into account the recommendations by Asplund (2005) . ', 'bibcodes': ['1968ZPhy..211..404D']}
# 31 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Because the transition arises from the ground state of a minority species, the line is sensitive to both the temperature and photoionizing UV radiation field ( Kiselman 1997 , Asplund 2005 ) The recommended value given in Table 1 stems from the analysis of Müller, Peytremann de La Reza (1975) , which has been corrected for the effects of atmospheric inhomogeneities and 3D non-LTE effects ( Asplund et al. 1999 , Barklem, Belyaev Asplund 2003 ). ', 'bibcodes': ['1997ApJ...489L.107K', '1999A&A...346L..17A']}
# 32 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Early work implied that Be was depleted in the solar convection zone by about a factor of two ( Chmielewski, Brault Müller 1975 ). ', 'bibcodes': ['1975A&A....42...37C']}
# 33 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'This interpretation was challenged by Balachandran Bell (1998) , who argued that one must take into account the long-suspected missing UV opacity (e.g., Short Hauschildt 2005 , and references therein) in synthesizing the Be ii resonance lines at 313 nm. ', 'bibcodes': ['1998Natur.392..791B']}
# 34 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The required extra opacity can be largely attributed to photoionization of Fe i ( Bell, Balachandran Bautista 2001 ). ', 'bibcodes': ['2001ApJ...546L..65B']}
# 35 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Cunha Smith (1999) have reanalyzed the line with careful consideration of the important Mg i photoionization cross sections. ', 'bibcodes': ['1999ApJ...512.1006C']}
# 36 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The effects of departures from LTE ( Kiselman Carlsson 1996 ) and 3D hydrodynamical model atmospheres ( Asplund, Grevesse Sauval 2005 ) are small and opposite in sign. ', 'bibcodes': ['1996A&A...311..680K']}
# 37 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The preliminary abundance log ε C = 8.56 ± 0.04 recommended by Anders Grevesse (1989) eventually became 8.60 ± 0.05 in the final analysis of Grevesse et al. (1991) . ', 'bibcodes': ['1989GeCoA..53..197A', '1991A&A...242..488G']}
# 38 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Grevesse Sauval (1998) based their value of 8.52 ± 0.06 on an unpublished analysis employing a Holweger Müller (1974) model with a modified temperature structure, in an attempt to remove existing trends with excitation potential and equivalent widths for C, N, O, and Fe. ', 'bibcodes': ['1998SSRv...85..161G', '1974SoPh...39...19H']}
# 39 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Allende Prieto, Lambert Asplund (2002) reanalyzed the [C i ] 872.7-nm line and found that the combination of a 3D hydrodynamical solar model ( Asplund et al. 2000b ) and an updated gf -value brought the abundance down to 8.39 ± 0.04. ', 'bibcodes': ['2002ApJ...573L.137A']}
# 40 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In sharp contrast, the abundances estimated with the Holweger Müller (1974) model atmosphere disagreed by ≈0.2 dex. ', 'bibcodes': ['1974SoPh...39...19H']}
# 41 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The presence of temperature inhomogeneities and a cooler mean temperature structure in the 3D model compared to the previously employed Holweger Müller (1974) model reduced the deduced abundance from the molecular lines in particular, whereas significant departures from LTE had a similar effect on the C i lines. ', 'bibcodes': ['1974SoPh...39...19H']}
# 42 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Using weak lines of the extremely temperature-sensitive CO molecule and a self-consistently derived O abundance, Scott et al. (2006) corroborated this finding. ', 'bibcodes': ['2006A&A...456..675S']}
# 43 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Table 2 The derived photospheric solar C, N, and O abundances for the available indicators using different solar model atmospheres a a The results have been obtained with a 3D hydrodynamical model of the solar atmosphere as well as with the temporally and spatially (over equal optical depth surfaces) averaged 3D model (denoted 〈3D〉), the 1D theoretical MARCS model ( Gustafsson et al. 2008 ), and the 1D semiempirical model of Holweger Müller (1974) . ', 'bibcodes': ['1974SoPh...39...19H']}
# 44 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Nitrogen The N abundance can be determined from both atomic and molecular lines, although the forbidden [N i ] lines are too weak in the solar spectrum to be measurable ( Grevesse et al. 1990 ). ', 'bibcodes': ['1990A&A...232..225G']}
# 45 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The N abundance that we recommend here, log ε N = 7.83 ± 0.05, is 0.09 dex lower than that suggested by Grevesse Sauval (1998) and 0.22 dex lower than in Anders Grevesse (1989) . ', 'bibcodes': ['1998SSRv...85..161G', '1989GeCoA..53..197A']}
# 46 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The favored solar content has dropped almost precipitously over the past two decades from log ε O = 8.93 ± 0.04 in Anders Grevesse (1989) to 8.66 in Asplund, Grevesse Sauval (2005) . ', 'bibcodes': ['1989GeCoA..53..197A']}
# 47 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Based on the line profile, they demonstrated that the line is blended by a Ni i line, which was subsequently confirmed experimentally ( Johansson et al. 2003 ). ', 'bibcodes': ['2003ApJ...584L.107J']}
# 48 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Ayres (2008) revisited the 630-nm line with a single snapshot of another 3D model but found a 0.12 dex higher O abundance, partly because he allowed the Ni i gf -value to vary freely in spite of the new accurate measurement by Johansson et al. (2003) . ', 'bibcodes': ['2003ApJ...584L.107J']}
# 49 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Caffau et al. (2008a) used several snapshots from the same CO5BOLD 3D model but instead fixed the Ni contribution assuming the Ni abundance from Grevesse Sauval (1998) , thereby confirming the results of Allende Prieto, Lambert Asplund (2001) and Asplund et al. (2004) . ', 'bibcodes': ['1998SSRv...85..161G']}
# 50 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The predicted non-LTE abundance corrections are little dependent on the model atmosphere in question, be it 1D or 3D ( Asplund et al. 2004 ), but they do depend on the adopted collisional cross sections, in particular the inelastic H collisions (e.g., Kiselman 1993 , Asplund 2005 ). ', 'bibcodes': ['1993A&A...275..269K']}
# 51 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Different approaches have been used in solar abundance works to date, where some neglect the H collisions altogether based on the available atomic physics data for other elements, while others use the classical Drawin (1968) formula, possibly with a scaling factor S H that typically varies from 0 to ', 'bibcodes': ['1968ZPhy..211..404D']}
# 52 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': '1. Holweger (2001) found log ε O = 8.71 ± 0.05 using the Holweger Müller (1974) model with granulation corrections estimated from a 2D solar model, whereas Asplund et al. (2004) obtained a 0.07-dex lower abundance from a 3D non-LTE study; the main difference, however, between the two studies is the adopted H collisions ( S H = 1 and 0, respectively). ', 'bibcodes': ['2001AIPC..598...23H', '1974SoPh...39...19H']}
# 53 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The curves are labeled with the scaling factor used to multiply the classical formula ( Drawin 1968 ). ', 'bibcodes': ['1968ZPhy..211..404D']}
# 54 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The new electron collisional cross sections computed by Barklem (2007a) have also been adopted (see Fabbian et al. 2009 for an account of the impact of these on other stars). ', 'bibcodes': ['2009A&A...500.1221F']}
# 55 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Grevesse, Sauval van Dishoeck (1984) and Sauval et al. (1984) introduced the vibration-rotation and pure rotation lines of OH as solar O abundance indicators. ', 'bibcodes': ['1984ApJ...282..330S']}
# 56 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The agreement between the different abundance indicators is very satisfactory, which is not the case with the Holweger Müller (1974) model as seen in Table 2 . ', 'bibcodes': ['1974SoPh...39...19H']}
# 57 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'As explained above, the use of a 3D model is only one factor in the downward revision of the O abundance from the value 8.83 ± 0.06 given in Grevesse Sauval (1998) , with refined non-LTE line formation, better accounting of blends, and improved atomic and molecular data also playing important roles. ', 'bibcodes': ['1998SSRv...85..161G']}
# 58 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Using CO lines, Scott et al. (2006) determined an isotopic abundance of 16 O/ 18 O = 479 ± 29. ', 'bibcodes': ['2006A&A...456..675S']}
# 59 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The significantly lower, nonterrestrial ratio obtained by Ayres, Plymate Keller (2006) is likely the result of their use of 1D model atmospheres. ', 'bibcodes': ['2006ApJS..165..618A']}
# 60 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The predicted departures from LTE in 1D are slightly negative (≈−0.04 dex) and agree well between different studies ( Allende Prieto, Asplund Fabiani Bendicho 2004 ; Shi, Gehren Zhao 2004 ; Takeda et al. 2003 ). ', 'bibcodes': ['2003ChJAA...3..316T']}
# 61 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Departures from LTE in 1D line formation by Mg i have been considered by Zhao, Butler Gehren (1998) and T. Gehren (private communication); the abundance corrections are small and positive. ', 'bibcodes': ['1998A&A...333..219Z']}
# 62 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'With an improved 3D solar model and non-LTE corrections (≈−0.02 dex) taken from Shi et al. (2008) , we find the same value in our reanalysis (Asplund et al., in preparation). ', 'bibcodes': ['2008A&A...486..303S']}
# 63 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Had we instead opted to use the Holweger Müller (1974) 1D semiempirical model, the result would have been a mere 0.02 dex higher. ', 'bibcodes': ['1974SoPh...39...19H']}
# 64 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Given the very small non-LTE effects seen in S i lines ( Takeda et al. 2005 ), which should behave similarly to the P i lines, departures from LTE are not expected to be significant for P i . ', 'bibcodes': ['2005PASJ...57..751T']}
# 65 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In their 3D-based analysis, Caffau et al. (2007a) obtained a disturbingly large line-to-line scatter: log ε S = 7.21 ± 0.11 ( σ ); this result includes the non-LTE corrections of Takeda et al. (2005) . ', 'bibcodes': ['2005PASJ...57..751T']}
# 66 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'As in previous studies, the line-to-line scatter is disappointingly large for these lines, even when taking into account the theoretical non-LTE effects computed by Zhang et al. (2006) . ', 'bibcodes': ['2006A&A...453..723Z']}
# 67 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'With its relatively low ionization potential, Sc is prone to overionization via non-LTE effects ( Zhang, Gehren Zhao 2008 ). ', 'bibcodes': ['2008A&A...481..489Z']}
# 68 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'With five weak lines of Sc i , twelve of Sc ii, and the non-LTE corrections of Zhang, Gehren Zhao (2008) , the 3D-based abundances show very good agreement between the two ionization stages (Scott et al., in preparation). ', 'bibcodes': ['2008A&A...481..489Z']}
# 69 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Using their own measured oscillator strengths for Cr i , Sobeck, Lawler Sneden (2007) recently revised the solar Cr abundance, which we update here using a 3D model and include the new non-LTE corrections (Scott et al., in preparation). ', 'bibcodes': ['2007ApJ...667.1267S']}
# 70 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'An intense debate long raged as to whether the solar Fe abundance inferred from Fe i lines should be log ε Fe ≈ 7.7 (e.g., Blackwell, Lynas-Gray Smith 1995 ) or log ε Fe ≈ 7.5 (e.g., Holweger, Kock Bard 1995 ), with the choice of equivalent widths, gf -values, microturbulence parameters, and pressure-damping constants all playing a role. ', 'bibcodes': ['1995A&A...296..217B', '1995A&A...296..233H']}
# 71 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': "The advent of improved transition probabilities for Fe ii lines (e.g., Hannaford et al. 1992 ; Schnabel, Kock Holweger 1999 ) and a proper treatment of pressure broadening (e.g., Anstee, O'Mara Ross 1997 ; Barklem, Piskunov O'Mara 2000a ) strengthened the case for a low Fe abundance. ", 'bibcodes': ['1992A&A...259..301H', '1999A&A...342..610S', '1997MNRAS.284..202A']}
# 72 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'An unsatisfactory combination of large abundance scatter, the presence of a free parameter (microturbulence), and a trend with excitation potential still remained with the Holweger Müller (1974) model, however ( Grevesse Sauval 1999 ). ', 'bibcodes': ['1974SoPh...39...19H', '1999A&A...347..348G']}
# 73 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The non-LTE abundance corrections have been estimated to be +0.03 dex for Fe i ( Korn, Shi Gehren 2003 , Collet, Asplund Thévenin 2005 ), although this depends on the still poorly known inelastic H collisions (see Asplund 2005 , and references therein). ', 'bibcodes': ['2003A&A...407..691K']}
# 74 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'We note that with the Holweger Müller (1974) model, there is a trend in Fe i abundances with excitation potential and a discrepancy of 0.14 dex between Fe i and Fe ii . ', 'bibcodes': ['1974SoPh...39...19H']}
# 75 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Same as above but with the 1D semiempirical Holweger Müller (1974) model. ', 'bibcodes': ['1974SoPh...39...19H']}
# 76 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In a beautiful series of papers, they have systematically and methodically measured radiative lifetimes, branching fractions, oscillator strengths, isotopic shifts, and hyperfine constants for all the rare Earth elements: La ( Lawler, Bonvallet Sneden 2001 ); Ce ( Lawler et al. 2009 ); Pr ( Sneden et al. 2009 ); Nd ( Den Hartog et al. 2003 ); Sm ( Lawler et al. 2006 ); Eu ( Lawler et al. 2001b ); Gd ( Den Hartog et al. 2006 ); Tb ( Lawler et al. 2001a ); Dy ( Sneden et al. 2009 ); Ho ( Lawler, Sneden Cowan 2004 ); Er ( Lawler et al. 2008 ); Tm, Yb, and Lu ( Sneden et al. 2009 ). ', 'bibcodes': ['2003ApJS..148..543D', '2004ApJ...604..850L']}
# 77 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The recommended solar abundances provided in Table 1 for these elements have been modified from the original sources by calculating the abundance difference between a 3D hydrodynamical model atmosphere and the Holweger Müller (1974) model, each computed using the same line-formation code with consistent input data (Grevesse et al., in preparation). ', 'bibcodes': ['1974SoPh...39...19H']}
# 78 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In addition, the 1D non-LTE effects on Eu ii predicted by Mashonkina Gehren (2000) have been taken into account in the 3D result; non-LTE studies are not available for any other rare Earth elements. ', 'bibcodes': ['2000A&A...364..249M']}
# 79 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'A similar procedure has been implemented for Cd ( Youssef, Doenszelmann Grevesse 1990 ), W ( Holweger Werner 1982 ), Os ( Quinet et al. 2006 ), Ir ( Youssef Khalil 1988 ), and Au ( Youssef 1986 ), all of which have only heavily blended transitions available in the solar spectrum, necessitating careful and time-consuming spectrum syntheses. ', 'bibcodes': ['1990A&A...239..367Y', '1982SoPh...81....3H', '2006A&A...448.1207Q', '1988A&A...203..378Y', '1986A&A...164..395Y']}
# 80 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Owing to blends, we consider the two As i lines employed by Gopka et al. (2001) too unreliable to base a meaningful abundance determination on and consequently do not provide a solar photospheric As abundance here. ', 'bibcodes': ['2001KFNT...17...37G']}
# 81 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Similarly, we are unable to defend an estimate of the Sb abundance from the very weak and heavily perturbed, purported Sb i line at 323.2 nm reported by Ross Aller (1976) . ', 'bibcodes': ['1976Sci...191.1223R']}
# 82 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'For all other neutron capture elements (Cu, Zn, Ga, Ge, Rb, Sr, Y, Zr, Nb, Mo, Ru, Rh, Pd, Ag, Sn, Ba, Pb, and Th), the adopted abundances come from a complete 3D-based reanalysis using the best atomic data and newly measured equivalent widths or spectrum synthesis for the most reliable lines (Grevesse et al., in preparation); the case of Ru is also discussed in Fivet et al. (2009) . ', 'bibcodes': ['2009A&A...500.1221F']}
# 83 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The available 1D non-LTE abundance corrections for Zn i ( Takeda et al. 2005 ), Sr ii ( Mashonkina Gehren 2001 ), and Ba ii ( Mashonkina Gehren 2000 ) have been included in these estimates. ', 'bibcodes': ['2005PASJ...57..751T', '2001A&A...376..232M', '2000A&A...364..249M']}
# 84 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': "We have found very good agreement (0.02 dex) with recent studies using the Holweger Müller (1974) model when allowance is made for differences in adopted transition probabilities and equivalent widths for Ge ( Biémont et al. 1999 ), Sr ( Barklem O'Mara 2000 ), Pd ( Xu et al. 2006 ), and Pb ( Biémont et al. 2000 ). ", 'bibcodes': ['1974SoPh...39...19H', '2006A&A...452..357X']}
# 85 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The solar F and Cl abundances have instead been inferred from the IR spectrum of sunspots using lines of HF ( Hall Noyes 1969 ) and HCl ( Hall Noyes 1972 ). ', 'bibcodes': ['1969ApL.....4..143H', '1972ApJ...175L..95H']}
# 86 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The same holds for Tl ( Lambert, Mallia Smith 1972 ). ', 'bibcodes': ['1972SoPh...26..250L']}
# 87 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Basu Antia (2004) found a He mass fraction in the convection zone of Y s = 0.2485 ± 0.0034, which corresponds to a He abundance by number of log ε He = 10.93 ± 0.01. ', 'bibcodes': ['2004ApJ...606L..85B']}
# 88 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The uncertainty essentially reflects the difference between the MHD ( Mihalas, Däppen Hummer 1988 ) and OPAL ( Rogers Nayfonov 2002 ) equation of state, but there is also a minor dependency on the assumed metallicity of the reference solar model for the inversion ( Trampedach, Däppen Baturin 2006 ). ', 'bibcodes': ['1988ApJ...331..815M', '2002ApJ...576.1064R', '2006ApJ...646..560T']}
# 89 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'A similar value is obtained when calibrating solar interior models to achieve the correct mass, luminosity, and radius at the present solar age, if the chemical composition of Grevesse Sauval (1998) is adopted and diffusion is considered. ', 'bibcodes': ['1998SSRv...85..161G']}
# 90 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The interpretation is, however, complicated by the so-called first ionization potential (FIP) effect: Elements with ionization potential χ ion 10 eV are enhanced in the upper solar atmosphere and solar wind compared to their photospheric values, whereas the high ionization elements are not or only slightly affected ( Feldman Widing 2003 ). ', 'bibcodes': ['2003SSRv..107..665F']}
# 91 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The corresponding ratio in solar energetic particles is very similar and remarkably constant: 0.152 ± 0.006 ( Reames 1999 ), which was adopted by Asplund, Grevesse Sauval (2005) . ', 'bibcodes': ['1999SSRv...90..413R']}
# 92 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Drake Testa (2005) have argued on the basis of X-ray spectroscopy of nearby stars that the Ne/O ratio is significantly higher (0.41) than the solar ratios discussed above. ', 'bibcodes': ['2005Natur.436..525D']}
# 93 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'One would therefore suspect that the high coronal Ne/O ratio inferred by Drake Testa (2005) is a consequence of the difference in ionization potential, making Ne more susceptible to fractionation than O in high-activity environments. ', 'bibcodes': ['2005Natur.436..525D']}
# 94 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Our value is 0.1 dex lower than the result of Lodders (2008) but 0.2 dex higher than Asplund, Grevesse Sauval (2005) , which was based only on the Ar/O ratio in solar energetic particles ( Reames 1999 ). ', 'bibcodes': ['1999SSRv...90..413R']}
# 95 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In most cases, the terrestrial isotopic abundance ratios as recommended by the International Union of Pure and Applied Chemistry ( Rosman Taylor 1998 ) have been adopted as representative of the Solar System values; direct solar isotopic information can only be gleaned from CO vibration-rotation lines in the IR spectrum of the Sun (e.g., Scott et al. 2006 ), although with comparatively large error bars by terrestrial standards. ', 'bibcodes': ['1998JPCRD..27.1275R', '2006A&A...456..675S']}
# 96 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'It should be noted that except for C and O, the isotopic fractions given here are the more conservative “representative isotopic composition” values from the compilation of Rosman Taylor (1998) , in contrast to Lodders (2003) , who opted for the “best measurement from a single terrestrial source” data from the same reference. ', 'bibcodes': ['1998JPCRD..27.1275R', '2003ApJ...591.1220L']}
# 97 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Most of the isotopic values are taken from Rosman Taylor (1998) with updates for some elements, as discussed in Section 3.10 The protosolar D abundance can be estimated from observations of Jupiter. ', 'bibcodes': ['1998JPCRD..27.1275R']}
# 98 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'An alternative approach makes use of the measured enrichment of the 3 He/ 4 He ratio in the solar wind in comparison with the protosolar ratio 3 He/ 4 He = (1.66 ± 0.05) × 10 −4 inferred from Jupiter ( Mahaffy et al. 1998 ), because the additional 3 He can be attributed to D-burning in the Sun ( Gloeckler Geiss 2000 ). ', 'bibcodes': ['1998SSRv...84..251M', '2000IAUS..198..224G']}
# 99 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'We note that the representative isotopic composition from Rosman Taylor (1998) corresponds to the significantly more uncertain value 12 C/ 13 C = 92 ± 7. ', 'bibcodes': ['1998JPCRD..27.1275R']}
# 100 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The ratio inferred from the solar photosphere using CO lines (86.8 ± 3.8) is consistent with the terrestrial value ( Scott et al. 2006 ). ', 'bibcodes': ['2006A&A...456..675S']}
# 101 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The 14 N/ 15 N ratio varies tremendously between various Solar System objects, from 100 to 450 ( Owen et al. 2001 ). ', 'bibcodes': ['2001ApJ...553L..77O']}
# 102 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The best values to adopt for the protosolar O isotopic ratios are still debated (e.g., Hashizume Chaussidon 2005 , Ireland et al. 2006 ). ', 'bibcodes': ['2005Natur.434..619H', '2006Natur.440..776I']}
# 103 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The solar photospheric ratio 16 O/ 18 O = 479 ± 29 obtained by Scott et al. (2006) is consistent with the terrestrial value, but with larger uncertainties [although in fairness the terrestrial representative isotopic composition from Rosman Taylor (1998) is equally uncertain: 487 ± 35]. ', 'bibcodes': ['2006A&A...456..675S', '1998JPCRD..27.1275R']}
# 104 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Surprisingly, Ayres, Plymate Keller (2006) found strongly subterrestrial ratios (e.g., 16 O/ 18 O = 440 ± 20) from their analysis of the solar CO lines, probably owing to an inadequate consideration of the differing temperature sensitivities of the isotopomer transitions with 1D model atmospheres ( Scott et al. 2006 ). ', 'bibcodes': ['2006A&A...456..675S', '2006A&A...456..675S']}
# 105 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'For Ne, Ar, Kr, and Xe we adopt the recommended values of Wieler (2002) derived from solar wind and lunar sample analyses. ', 'bibcodes': ['2002RvMG...47...21W']}
# 106 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'For Mo, Dy, Er, Yb, and Lu we have exchanged the Rosman Taylor (1998) values with the more recent measurements given in Lodders, Palme Gail (2009) . ', 'bibcodes': ['1998JPCRD..27.1275R']}
# 107 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In comparison with present-day photospheric values, the bulk composition of the Sun is higher by 0.05 dex for He and 0.04 dex for the heavier elements ( Turcotte Wimmer-Schweingruber 2002 ). ', 'bibcodes': ['2002JGRA..107.1442T']}
# 108 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'We note that Lodders (2003) adopted a somewhat larger correction, 0.074 dex, than that of Turcotte Wimmer-Schweingruber (2002) . ', 'bibcodes': ['2003ApJ...591.1220L', '2002JGRA..107.1442T']}
# 109 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In other words, the solar metallicity is no longer the canonical 2% recommended by Anders Grevesse (1989) but rather a substantially smaller 1.4%. ', 'bibcodes': ['1989GeCoA..53..197A']}
# 110 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Table 4 The mass fractions of H (X), He (Y) and metals (Z) for a number of widely used compilations of the solar chemical composition a The He abundances given in Anders Grevesse (1989) and Grevesse Noels (1993) have here been replaced with the current best estimate from helioseismology (Section 3.9). ', 'bibcodes': ['1989GeCoA..53..197A', '1993oee..conf...15G']}
# 111 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'For completeness, we note that the He abundances recommended by Anders Grevesse (1989) and Grevesse Noels (1993) were based on calibration of solar models and, hence, corresponded to bulk composition; here we have substituted those with the helioseismic convection zone He content (Section 3.9) when computing the present-day photospheric values. ', 'bibcodes': ['1989GeCoA..53..197A', '1993oee..conf...15G']}
# 112 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Finally, from Table 4 it is clear that the surface He abundance employed by Lodders (2003) is too low on account of adopting a too efficient elemental diffusion. ', 'bibcodes': ['2003ApJ...591.1220L']}
# 113 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The most primitive, undifferentiated meteorites in this respect are the so-called C I (or C1) carbonaceous chondrites, of which only five are known: the Alais, Ivuna (after which this class of meteorites is named), Orgueil, Revelstoke, and Tonk meteorites ( Lodders 2003 ). ', 'bibcodes': ['2003ApJ...591.1220L']}
# 114 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In principle, the conversion factor could employ additional elements besides Si; Anders Grevesse (1989) , for example, used Na, Mg, Si, Ca, V, Cr, Co, Ni, Y, Zr, Nb, and Mo, whereas Lodders, Palme Gail (2009) included as many as 39 elements. ', 'bibcodes': ['1989GeCoA..53..197A']}
# 115 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The former amounts to 0.04 dex for metals ( Turcotte Wimmer-Schweingruber 2002 ; cf. Section 3.11), whereas the latter is typically predicted to be 0.05–0.15 dex depending on the element in question ( Chiappini, Romano Matteucci 2003 ; Prantzos 2008 ). ', 'bibcodes': ['2002JGRA..107.1442T', '2003MNRAS.339...63C']}
# 116 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'We should bear in mind that most large-scale abundance analyses of Galactic thin disk stars to date (e.g., Edvardsson et al. 1993 ; Reddy et al. 2003 ; Bensby et al. 2005 ; Ramírez, Allende Prieto Lambert 2007 ; Fuhrmann 2008 ) have been performed differentially relative to the Sun to remove the uncertainties from gf -values and to minimize systematic errors due to inadequacies in the stellar modeling. ', 'bibcodes': ['1993A&A...275..101E', '2003MNRAS.340..304R', '2007A&A...465..271R', '2008MNRAS.384..173F']}
# 117 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In his volume-complete sample of stars within 25 pc, Fuhrmann (2008) found a mean spectroscopic metallicity of [Fe/H] = −0.02 ± 0.18. ', 'bibcodes': ['2008MNRAS.384..173F']}
# 118 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The latter have also become more accurate, as reflected in greatly diminished uncertainties (e.g., Daflon Cunha 2004 , Nieva Przybilla 2006 , Morel 2008 ). ', 'bibcodes': ['2004ApJ...617.1115D', '2006ApJ...639L..39N']}
# 119 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Their results are presented in Table 5 ; for S we give the mean abundance from Morel et al. (2006) , whereas the Ar abundance is taken from Lanz et al. (2008) . ', 'bibcodes': ['2006A&A...457..651M']}
# 120 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Although the situation has greatly improved compared to the solar abundances of Grevesse Sauval (1998) and earlier compilations, there is still a tendency for the solar C, N, and Fe abundances to be somewhat higher than in the B stars. ', 'bibcodes': ['1998SSRv...85..161G']}
# 121 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Table 5 Comparison of the protosolar abundances with those in nearby B stars and HII regions a a The solar values given here include the effects of diffusion ( Turcotte Wimmer-Schweingruber 2002 ) as discussed in Section 3.11. ', 'bibcodes': ['2002JGRA..107.1442T']}
# 122 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'b Grevesse Sauval (1998) . ', 'bibcodes': ['1998SSRv...85..161G']}
# 123 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'd Przybilla, Nieva Butler (2008) ; Morel et al. (2006) ; Lanz et al. (2008) . ', 'bibcodes': ['2006A&A...457..651M']}
# 124 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'e Esteban et al. (2004 , 2005) , García-Rojas Esteban (2007) . ', 'bibcodes': ['2004MNRAS.355..229E']}
# 125 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'f Chiappini, Romano Matteucci (2003) . ', 'bibcodes': ['2003MNRAS.339...63C']}
# 126 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'In Table 5 we provide the values from Esteban et al. (2004 , 2005) and García-Rojas Esteban (2007) interpolated to a Galacto-centric radius of 8 kpc. ', 'bibcodes': ['2004MNRAS.355..229E']}
# 127 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'For C and O this somewhat uncertain dust correction amounts to ≈0.1 dex in Orion ( Esteban et al. 2004 ). ', 'bibcodes': ['2004MNRAS.355..229E']}
# 128 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Because of the generally lower temperatures encountered and the consequentially larger degree of dust condensation, the interstellar medium is a less reliable chemical composition gauge than H ii regions ( Jenkins 2004 ). ', 'bibcodes': ['2004oee..symp..336J']}
# 129 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Indeed, rather than setting constraints on the solar abundances, the Sun is often used to infer the amount in the solid phase in the interstellar medium (e.g., Sofia Meyer 2001 ). ', 'bibcodes': ['2001ApJ...554L.221S']}
# 130 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The local abundances of the volatile elements C ( Sofia et al. 2004 ), N ( Jensen, Rachford Snow 2007 ), and O ( Cartledge et al. 2006 ; Jensen, Rachford Snow 2005 ) in the interstellar medium support our recommended solar values in general. ', 'bibcodes': ['2007ApJ...654..955J', '2006ApJ...641..327C', '2005ApJ...619..891J']}
# 131 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'With the older, higher (log ε O = 8.83 − 8.93) solar abundances preferred by Grevesse Sauval (1998) and Anders Grevesse (1989) , it becomes very challenging to hide sufficient amounts of O in dust ( Jensen 2007 ). ', 'bibcodes': ['1998SSRv...85..161G', '1989GeCoA..53..197A', '2007ApJ...654..955J']}
# 132 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Also listed in Table 5 are predictions from models of Galactic chemical evolution ( Chiappini, Romano Matteucci 2003 ). ', 'bibcodes': ['2003MNRAS.339...63C']}
# 133 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'With the Grevesse Sauval (1998) abundances, the predicted sound speed as a function of depth from standard solar models shows very good agreement with the helioseismic values. ', 'bibcodes': ['1998SSRv...85..161G']}
# 134 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'When instead employing the revised values of Asplund, Grevesse Sauval (2005) , this is no longer the case, a situation which has attracted a great deal of attention lately (e.g., Basu Antia 2004 , 2008 ; Turck-Chièze et al. 2004 ; Bahcall et al. 2005 ; Guzik, Watson Cox 2005 ; Delahaye Pinsonneault 2006 ). ', 'bibcodes': ['2004ApJ...606L..85B', '2004PhRvL..93u1102T', '2005ApJ...627.1049G']}
# 135 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Also with the Grevesse Sauval (1998) abundances there was a disagreement in this region but it is greatly aggravated by the further lowering of the solar O and Ne abundances and, to a lesser extent, by the reassessment of C, N, and Fe. ', 'bibcodes': ['1998SSRv...85..161G']}
# 136 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The standard solar models shown here only differ in the assumed chemical compositions: Grevesse Sauval (1998 , here denoted as GS98), gray line ; Asplund, Grevesse Sauval (2005 , AGS05), red line ; and the present work (AGSS09), blue line . ', 'bibcodes': ['1998SSRv...85..161G']}
# 137 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The inferred depth of the convection zone is now too shallow: R BCZ ≈ 0.725 R ⊙ instead of the helioseismic measurement 0.7133 ± 0.0005 R ⊙ ( Basu Antia 2004 ). ', 'bibcodes': ['2004ApJ...606L..85B']}
# 138 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Furthermore, the resulting He abundance when calibrating solar interior models to achieve the correct solar luminosity and temperature at the solar age is similarly inconsistent with the value inferred from helioseismology (see Section 3.9): Y S ≈ 0.238 compared to the observed 0.2485 ± 0.0034 ( Basu Antia 2004 ), where Y S is the present-day He mass fraction at the surface. ', 'bibcodes': ['2004ApJ...606L..85B']}
# 139 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Furthermore, though this may remedy the sound speed discrepancy, problems still remain in terms of the He abundance and depth of the convection zone ( Montalbán et al. 2004 ; Guzik, Watson Cox 2005 ; Yang Bi 2007 ). ', 'bibcodes': ['2005ApJ...627.1049G', '2007ApJ...658L..67Y']}
# 140 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'A hypothetical late accretion of metal-depleted gas during the formation of the Sun runs into the same trouble ( Guzik, Watson Cox 2005 , Castro, Vauclair Richard 2007 ). ', 'bibcodes': ['2005ApJ...627.1049G']}
# 141 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Bahcall, Basu Serenelli (2005) estimated that a factor of three (0.5 dex) higher Ne content compared to the recommended values of Asplund, Grevesse Sauval (2005) , together with minor adjustments of C, N, O, and Ar within their associated uncertainties, would restore the good agreement found with the Grevesse Sauval (1998) solar composition. ', 'bibcodes': ['1998SSRv...85..161G']}
# 142 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'There was initial excitement when Drake Testa (2005) argued for exactly such an increase in Ne on the basis of inferences from coronal spectroscopy of other stars, but there is in fact little support for this idea, as explained in Section 3.9. ', 'bibcodes': ['2005Natur.436..525D']}
# 143 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Using neutrino data from the SuperKamiokande I+II, SNO, and Borexino experiments, Pena-Garay Serenelli (2008) have derived the neutrino oscillations and fluxes expected from solar models constructed with the Grevesse Sauval (1998) and Asplund, Grevesse Sauval (2005) compositions. ', 'bibcodes': ['1998SSRv...85..161G']}
# 144 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'The values we recommend for the most abundant metals C, N, O, Ne, and Fe are significantly smaller (by ∼0.2 dex) than those advocated in the widely used compilation of Anders Grevesse (1989) . ', 'bibcodes': ['1989GeCoA..53..197A']}
# 145 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'With the downward revision of the overall metal content presented here compared to the Grevesse Sauval (1998) abundances, the previous excellent agreement between predicted sound speeds from standard solar models and those inferred from helioseismology is ruined (Section 4.3). ', 'bibcodes': ['1998SSRv...85..161G']}
# 146 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'For completeness, one should include the effects of magnetic fields in the 3D solar atmospheric models, but we do not expect that these will noticeably influence the derived abundances ( Nordlund, Stein Asplund 2009 ). ', 'bibcodes': ['2009LRSP....6....2N']}
# 147 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Fortunately, there has been some laudable progress on this score in recent years, in terms of both experimental efforts (e.g., Johansson et al. 2003 , Blackwell-Whitehead Bergemann 2007 , Lawler et al. 2009 ) and theoretical calculations (e.g., Kurucz 1992 , Plez 1998 , Badnell et al. 2005 ), as discussed in Section 2.2. ', 'bibcodes': ['2003ApJ...584L.107J', '1992RMxAA..23...45K', '1998A&A...337..495P']}
# 148 {'doi': '10.1146/annurev.astro.46.060407.145222', 'sentence': 'Even rarer are solar abundance works going beyond the 1D framework and employing 3D non-LTE calculations (e.g., Asplund, Carlsson Botnen 2003 ; Asplund et al. 2004 ). ', 'bibcodes': ['2003A&A...399L..31A']}

# %%
for i, sentence in enumerate(seg.segment(data[0]['body'])):
    print(i, sentence)
# Out:
# 0 1. INTRODUCTION The solar chemical composition is a fundamental yardstick in astronomy, to which the elemental abundances of essentially all cosmic objects, be they planets, stars, nebulae or galaxies, are anchored.
# 1 The importance of having accurate solar elemental abundances thus can not be overstated.
# 2 From the pioneering efforts of Russell (1929) , Suess Urey (1956) , and Goldberg, Müller Aller (1960) to the more recent works of Anders Grevesse (1989) , Grevesse Sauval (1998) , Lodders (2003) , Asplund, Grevesse Sauval (2005) , Grevesse, Asplund Sauval (2007) , and Lodders, Palme Gail (2009) , compilations of the Solar System abundances have found extremely wide-ranging use in astronomy and cosmology.
# 3 There are two independent and complementary ways of determining the Solar System abundances, each with its pros and cons.
# 4 Through mass spectroscopy of meteorites in terrestrial laboratories, it is possible to directly measure the abundance of almost every element and isotope with remarkable precision.
# 5 The most pristine meteorites are the so-called CI chondrites, which have been modified least by various physical and chemical processes over the past 4.56 Gyr.
# 6 Even in these meteorites volatile elements have been depleted to various degrees, including the six most abundant elements: H, He, C, N, O and Ne.
# 7 As a consequence, it is not possible to rely on meteorites to determine the primordial Solar System abundances for such elements.
# 8 This also implies that one must measure all meteoritic abundances relative to an element other than H, traditionally chosen to be Si.
# 9 Prior knowledge of the solar photospheric Si abundance is therefore required in order to place the meteoritic abundances on the same absolute scale as the Sun ( Suess Urey 1956 ).
# 10 With the exception of a general ∼10% modification owing to diffusion and gravitational settling and depletion of Li and possibly Be, today's photospheric abundances are believed to reflect those at the birth of the Solar System.
# 11 They are of profound importance for the understanding of our own Solar System and the Sun's interior structure and evolution.
# 12 Unfortunately, photospheric abundances cannot be determined with the same accuracy as those from meteorites.
# 13 In particular, very little isotopic abundance information is available.
# 14 Furthermore, photospheric abundances are not observed but inferred.
# 15 Thus, the solar spectrum must be interpreted using realistic models of the solar atmosphere and spectrum-formation process.
# 16 In addition, the required atomic and molecular data are rarely precise enough to rival the accuracy of meteoritic measurements.
# 17 In spite of the remaining uncertainties in solar photospheric determinations, having access to the most accurate solar abundances possible is crucial, not only for understanding our own Sun but also in order to make meaningful comparisons with other stars (for which meteoritic information is obviously unavailable).
# 18 The Sun is also the only possible reference for the interstellar medium, H ii regions, and other galaxies when studying the elements depleted in meteorites.
# 19 In the decade since the appearance of the widely used compilation of the solar chemical composition by Grevesse Sauval (1998) , the abundances of a large number of elements have been revised, several rather severely (e.g., Asplund, Grevesse Sauval 2005 ).
# 20 This is true in particular for C, N, O, and Ne.
# 21 There are three main reasons for the changes: improvements in atomic and molecular transition probabilities, the advent of 3D hydrodynamical solar model atmospheres, and relaxation of the assumption of local thermodynamic equilibrium (LTE) in the spectral line formation.
# 22 Several of the proposed abundance alterations have not gone unchallenged, however.
# 23 It is therefore timely to now critically assess the reference solar chemical composition and make recommendations regarding the most accurate values available to the astronomical community.
# 24 After recapitulating the necessary ingredients in any solar abundance analysis (Section 2), we discuss in detail the solar chemical composition on an element-by-element basis (Section 3).
# 25 We also present a comparison between photospheric solar abundances and those inferred by alternative means, such as via meteorites and stars or gas in the Solar Neighborhood (Section 4).
# 26 We conclude by summarizing the main points and outlining a few open issues for the future (Section 5).
# 27 2. INGREDIENTS FOR SOLAR ABUNDANCE ANALYSIS 2.1.
# 28 Observations Analyses of the solar photospheric chemical composition make use of the elemental fingerprints present in the solar spectrum in the form of spectral absorption lines.
# 29 There are several solar atlases of both intensity and flux spectra in the UV, optical, and IR regions.
# 30 The most commonly used optical disk-center intensity spectra of the quiet Sun are the so-called Jungfraujoch or Liège atlas (after its locations of observation and production, respectively; Delbouille, Roland Neven 1973 ) and the Kitt Peak solar atlas ( Neckel Labs 1984 ).
# 31 The spectral resolving power of the latter is slightly higher, whereas the former is less affected by telluric absorption owing to the higher observing altitude.
# 32 There are also corresponding IR disk-center intensity atlases observed from Kitt Peak ( Delbouille et al. 1981 ) and from the Atmospheric Trace Molecule Spectroscopy (ATMOS ) experiment flown on the space shuttle ( Farmer Norton 1989 ; Abrams et al. 1996 ).
# 33 Finally, the solar flux spectrum has recently been rereduced by Kurucz (2006) ; see also Kurucz et al. (1984) for an earlier rendition of the same Kitt Peak solar data set.
# 34 All solar atlases agree very well with each other except for spectral regions afflicted by telluric features.
# 35 Thus, the quality of observations is in general not a source of significant error in solar abundance analyses.
# 36 2.2.
# 37 Atomic and Molecular Data A critical ingredient in any solar abundance analysis is, of course, the atomic and molecular line input data.
# 38 Of these the transition probability is the most obvious, but there are a raft of other required components that are not always as well determined as one would hope.
# 39 These include line broadening, hyperfine and isotopic splitting, dissociation energies, and partition functions.
# 40 Much laudable work has been done in improving the gf -values for a large number of transitions (e.g., Kurucz 1992 ; Johansson et al. 2003 ; Lawler et al. 2006 ; Sobeck, Lawler Sneden 2007 ), but several elements and lines still have surprisingly uncertain transition probabilities.
# 41 Another important advancement in recent years is that it is now possible to accurately compute the pressure broadening (also known as van der Waals broadening) of metal lines ( Anstee O'Mara 1995 ; Barklem, Piskunov O'Mara 2000a ; Barklem Aspelund-Johansson 2005 ), which has made the classical Unsöld broadening and its ad hoc enhancement factors largely obsolete, at least for neutral species.
# 42 The need for atomic data increases dramatically when relaxing the LTE assumption.
# 43 In non-LTE calculations, one needs transition data not only for the line in question but in principle for all other lines of the element.
# 44 In addition, photoionization cross sections play a crucial role.
# 45 There have been noteworthy improvements in this respect in recent years through the Opacity and Iron Projects ( Badnell et al. 2005 ), for example, but unfortunately the lack of quantum mechanical calculations for most elements preclude detailed non-LTE investigations.
# 46 The most unsatisfactory situation, however, relates to collisional cross sections for excitation and ionization, for which laboratory or theoretical calculations are completely missing bar for a few elements and transitions relevant for spectroscopy of late-type stars (e.g., Belyaev Barklem 2003 ; Barklem 2007a ).
# 47 In the absence of realistic evaluations, classical recipes such as those of van Regemorter (1962) and Drawin (1968) are frequently used but cannot be expected to be more than order-of-magnitude estimates at best.
# 48 Often scaling factors to these formulas are used, sometimes calibrated by achieving an optimal overall fit to the various spectral features.
# 49 It should be remembered that such a procedure may reveal less about the true collisional cross sections than about other shortcomings in the modeling of the stellar atmospheres and line formation ( Asplund 2005 ).
# 50 2.3.
# 51 Solar Atmospheric and Line-Formation Modeling Extracting information about the Sun's chemical composition from the solar spectrum requires realistic models of the solar atmosphere and the line-formation process.
# 52 Traditional solar and stellar abundance analyses employ one-dimensional (1D) model atmospheres assuming time-independence and hydrostatic equilibrium.
# 53 Such models come in two flavors: theoretical and semiempirical.
# 54 The former are constructed assuming a constant total (radiative plus convective) energy flux through the atmosphere, which dictates the temperature stratification given the adopted equation of state and opacities.
# 55 Convective energy transport is normally described by the mixing length theory ( Böhm-Vitense 1958 ).
# 56 The radiative flux is determined by solving the radiative transfer equation, typically under the simplification of LTE.
# 57 To achieve a realistic temperature structure, treatment of the combined effects of spectral lines (line blanketing) must be as complete as possible.
# 58 The most widely used theoretical 1D model atmospheres for solar-type stars are the Kurucz (1993) and MARCS ( Gustafsson et al. 2008 ) grids of models.
# 59 Semiempirical models are often the preferred choice for solar spectroscopists.
# 60 In these models, temperatures are inferred from depth-dependent observations such as the center-to-limb variation of the continuum and/or lines with differing formation heights.
# 61 The resulting atmospheric structure is, thus, sensitive to the ingredients involved in the inversion process, such as LTE for the continuum and line formation, and the adopted line data.
# 62 Hydrostatic equilibrium is still assumed in semiempirical models, but the flux constancy criterion does not need to be obeyed nor is it necessary to estimate convective energy transport.
# 63 Several semiempirical solar models are on the market, including the Holweger Müller (1974) , VAL3C ( Vernazza, Avrett Loeser 1976 ), and MISS ( Allende Prieto et al. 2001 ) models.
# 64 The favored model of solar abundance aficionados is the Holweger Müller model, partially because its temperature stratification is expected to be an accurate representation of the real photosphere—but also partially just by habit.
# 65 Indeed, it is somewhat surprising that the VAL3C model or its successors (e.g., Fontenla et al. 2006 ) have not caught on more within the solar abundance community, because they are built on similar premises but without the LTE restriction.
# 66 The venerable Holweger Müller model, in fact, dates back more than forty years, since the 1974 version was simply a new pressure-integration of the original Holweger (1967) model using updated equation of state and continuous opacities.
# 67 It was constructed to match the observed continuum center-to-limb variation as well as the line-depths of some 900 lines of varying strengths, under the assumption of LTE.
# 68 Owing to the limited spectral resolution of the solar spectrum used by Holweger, one would expect the temperatures to be overestimated by about 50 K in the line-forming region.
# 69 Interestingly, the corrected version of such a temperature structure would be more similar to the MISS semiempirical model ( Allende Prieto et al. 2001 ); both semiempirical models have a shallower temperature gradient than 1D theoretical model atmospheres, as seen in Figure 1 .
# 70 Bear in mind that there exists an ambiguity when employing any 1D model: Although many simply adopt temperatures, pressures, and densities directly from the published model, a more correct procedure is to perform a pressure-integration using only the temperature structure as a function of continuum optical depth, in order to be consistent with the opacities computed with the spectrum synthesis code one employs.
# 71 Figure 1 The mean temperature structure of the 3D hydrodynamical model of Trampedach et al. (in preparation) used throughout this review is shown as a function of optical depth at 500 nm ( blue solid line ).
# 72 The light blue shaded region corresponds to the spatial and temporal root mean square variations of the 3D model, whereas the red and yellow curves denote the 1D semiempirical Holweger Müller (1974) and the 1D theoretical MARCS ( Gustafsson et al. 2008 ) model atmospheres, respectively.
# 73 More recently it has become tractable to perform 3D, time-dependent, hydrodynamical simulations of the stellar surface convection (e.g., Stein Nordlund 1998 ; Asplund et al. 1999 ; Freytag, Steffen Dorch 2002 ; Vögler, Bruls Schüssler 2004 ).
# 74 Here the standard conservation equations of mass, momentum, and energy are solved together with the 3D radiative transfer equation in a small but representative volume of the stellar atmosphere.
# 75 Radiative energy exchange with the gas in the surface layers is crucial, because this is what drives the convective motions.
# 76 Because of the much more computationally demanding nature of such hydrodynamical modeling, approximations must be made in the radiative transfer treatment.
# 77 Rather than solving for many thousands of frequency points as regularly done in theoretical 1D hydrostatic models, the wavelength variation of opacity is represented by a small number of typical opacity bins (4–20) in order to compute the radiative heating/cooling rate that enters the energy equation ( Nordlund 1982 ).
# 78 Detailed comparisons with the monochromatic solution reveal that this scheme is surprisingly accurate.
# 79 The reader is referred to Nordlund, Stein Asplund (2009) for a recent review of the physics of solar surface convection and the numerical details of its simulation.
# 80 A few different 3D hydrodynamical solar model atmospheres have been constructed and employed for abundance purposes (e.g., Asplund et al. 2000b ; Caffau et al. 2008a ; Trampedach et al., in preparation).
# 81 Although these are computed with different codes, they are based on many of the same physical assumptions and approximations.
# 82 It is therefore not too surprising that the resulting atmospheric structures are similar.
# 83 The 3D models have been computed using realistic and comprehensive equation of state, continuous and line opacities.
# 84 The numerical resolution is sufficiently high to adequately resolve the granulation, albeit obviously not high enough to reach down to the microscopic viscous dissipation length scales.
# 85 The reason that these so-called large-eddy simulations are nevertheless quite successful in reproducing the real photosphere is that the mean stratification is largely independent of numerical resolution ( Stein Nordlund 1998 ; Asplund et al. 2000a ).
# 86 Spectral line formation is heavily biased to the upflows, which have a low degree of turbulence in comparison to the downflows, owing to the divergent flow.
# 87 Obviously none of the mixing length parameters required in 1D models enters into 3D simulations, as the convective energy flux is instead a natural consequence of the hydrodynamics.
# 88 Having a suitably realistic solar model atmosphere, the next step when trying to infer the solar chemical composition is to model how the spectrum is formed.
# 89 In order to derive an abundance of an element, solar spectroscopists either measure the total observed line strength as defined by the equivalent width, or directly compare the observed and theoretical spectra through the fitting of line profiles.
# 90 Finally, to compute the line strength requires knowledge of the level populations.
# 91 In LTE, these follow straightforwardly from the local temperature and electron pressure using the Boltzmann and Saha distributions.
# 92 In general, this rather severe simplification cannot be expected to be valid, and the non-LTE case must instead be considered.
# 93 Although non-LTE is a general term covering all situations when LTE is not valid, in practice all calculations referred to herein assume statistical equilibrium, that is, the level populations do not change with time.
# 94 Non-LTE thus requires a simultaneous solution of the rate equations for all relevant levels and species together with the radiative transfer equation for all relevant wavelengths.
# 95 We refer to Asplund (2005) for a detailed account of the principles of non-LTE and the most important non-LTE effects encountered for late-type stars like the Sun.
# 96 2.4.
# 97 Observational Constraints on Solar Modeling Because more sophisticated modeling does not automatically imply a more realistic outcome, it is of paramount importance to carefully test the predictions of the 3D model atmospheres against an arsenal of observational diagnostics.
# 98 This is especially true given that 1D model atmospheres more often than not fail the very same tests.
# 99 Current generations of 3D models are very successful in reproducing the observed solar granulation topology, typical length- and timescales, convective velocities, and intensity brightness contrast (e.g., Nordlund, Stein Asplund 2009 ), clearly none of which 1D models are able to predict.
# 100 Another important constraint is the center-to-limb variation of the continuum as a function of wavelength.
# 101 Ayres, Plymate Keller (2006) have criticized the 3D hydrodynamical model of Asplund et al. (2000b) , ofen used in recent solar abundance analyses, for having too steep a temperature gradient as judged by the observed center-to-limb variation.
# 102 Koesterke, Allende Prieto Lambert (2008) reach a somewhat milder conclusion, presumably because they performed spectral synthesis with the full 3D model rather than with only the spatially averaged version used by Ayres, Plymate Keller.
# 103 The 3D CO5BOLD solar model of Caffau et al. (2008a) appears to perform better in this respect (H. Ludwig, private communication).
# 104 In the present work, we make extensive use of a new 3D solar model (Trampedach et al., in preparation), which has been constructed with an improved treatment of the radiative transfer and updated opacities.
# 105 Because of its somewhat shallower temperature stratification than the 3D model of Asplund et al. (2000b) ( Figure 1 ), the new 3D model satisfies the center-to-limb variation constraint very well, as illustrated in Figure 2 .
# 106 Indeed it outperforms all 1D models, even the semiempirical Holweger Müller (1974) model, which was designed to fit this diagnostic.
# 107 Figure 2 Comparison of the predicted continuum center-to-limb variation as a function of wavelength for different solar model atmospheres against observations ( Neckel Labs 1994 ).
# 108 The results for five different viewing angles μ are shown from near disk center ( μ = 0.9) to close to the limb ( μ = 0.1).
# 109 All intensities are normalized to the corresponding disk-center intensities.
# 110 The 3D hydrodynamical model (Trampedach et al., in preparation) used in this review outperforms even the Holweger Müller (1974) semiempirical model, which was designed to satisfy this diagnostic (Pereira et al., in preparation).
# 111 As for all 1D theoretical model atmospheres, the MARCS ( Gustafsson et al. 2008 ) model has a too steep temperature gradient, which manifests itself in a poor agreement with the center-to-limb variation.
# 112 The wings of the H i Balmer lines are also sensitive tracers of the temperature stratification in the deeper layers of the photosphere.
# 113 In recent years, significant improvements have been made in the treatment of the broadening of H i lines, especially self-broadening ( Barklem, Piskunov O'Mara 2000b ; Allard et al. 2008 ).
# 114 It is still unclear whether noticeable non-LTE effects can be expected in the solar atmosphere, because available calculations for the cross sections of inelastic H+H collisions are uncertain ( Barklem 2007b ).
# 115 With 1D theoretical model atmospheres, the H i lines imply too low T eff for the Sun by 50–100 K and have the wrong line shapes when the most accurate line broadening data are used ( Barklem et al. 2002 ).
# 116 Such problems can be partly cured by playing with the mixing length parameters, however.
# 117 In contrast, the H i lines suggest that the temperature gradient of the Holweger Müller (1974) semiempirical model is too shallow.
# 118 The 3D solar model that we make extensive use of in this review reproduces the H α and H β lines very well, doing so significantly better than any 1D model investigated, but without requiring the tweaking of any free parameters.
# 119 The CO5BOLD model has, to our knowledge, not yet been tested against H i lines.
# 120 As seen in Figure 3 , with 3D hydrodynamical models for the solar atmosphere, it is now possible to achieve highly satisfactory agreement with observed profiles of typical weak and intermediate strong lines (the wings of strong lines reveal more about the pressure broadening data than the employed model atmosphere).
# 121 It is important to remember that this is achieved without invoking the free parameters necessary in any 1D analysis (micro- and macroturbulence) in the line-formation calculations.
# 122 Such line broadening can thus be explained as the result of the Doppler shifts arising from the convective motions with a smaller contribution from the solar oscillations (e.g., Nordlund, Stein Asplund 2009 , and references therein).
# 123 Indeed, even the observed line shifts and asymmetries are very well reproduced with 3D models (e.g., Asplund et al. 2000b ).
# 124 The CO5BOLD solar model produces good overall line profiles (e.g., Caffau et al. 2008a ), but whether this extends also to line asymmetries has not yet been investigated.
# 125 Figure 3 The predicted spectral line profile of a typical Fe i line from the 3D hydrodynamical solar model ( blue solid line ) compared to the observations ( gray rhombuses ).
# 126 The agreement is clearly very satisfactory, which is the result of the Doppler shifts arising from the self-consistently computed convective motions that broaden, shift, and skew the theoretical profile.
# 127 For comparison purposes, also shown is the predicted profile from a 1D model atmosphere ( red line ; Holweger Müller 1974 ); the 1D profile has been computed with a microturbulence of 1 km s −1 and a tuned macroturbulence to obtain the right overall linewidth.
# 128 Note that even with these two free parameters, the 1D profile can predict neither the shift nor the asymmetry of the line.
# 129 In summary, the 3D hydrodynamical model atmosphere that we draw results from in this review outperforms 1D model atmospheres in the available observational tests, from granulation topology and center-to-limb variation to H i lines and the detailed profiles of metallic lines.
# 130 For the purposes of photospheric abundance determinations, the 3D solar model employed here appears to be a very realistic representation of the solar photosphere.
# 131 No large differences are expected from using our 3D model or the corresponding CO5BOLD model ( Caffau et al. 2008a ) given their overall similarities.
# 132 3. PHOTOSPHERIC ABUNDANCES Our recommended solar photospheric elemental abundances are listed in Table 1 , which also provides the corresponding meteoritic values for CI chondrites to be discussed in Section 4.1.
# 133 [Throughout this review, we adopt the customary astronomical scale for logarithmic abundances where H is defined to be log ε H = 12.00, that is, log ε X = log( N X / N H ) + 12, where N X and N H are the number densities of elements X and H, respectively.] Figure 4 shows how the solar abundances vary with atomic number, illustrating several key features of nuclear and stellar physics: the high primordial H and He abundances; the fragile nature of Li, Be, and B; the relatively high abundance of elements involved in stellar H-, He-, and C-burning, modulated by the odd-even effect and the α -capture effect; the high nuclear binding energy and near-nuclear statistical equilibrium for the Fe-peak; and the production of the heavy elements through successive neutron captures with peaks around the magic nuclei possessing closed neutron shells (e.g., Pagel 1997 ).
# 134 Table 1 Element abundances in the present-day solar photosphere.
# 135 Also given are the corresponding values for CI carbonaceous chondrites ( Lodders, Palme Gail 2009 ).
# 136 Indirect photospheric estimates have been used for the noble gases (Section 3.9) Figure 4 The present-day solar photospheric elemental abundances as a function of atomic number.
# 137 As throughout this review, the logarithmic abundance of H is defined to be log ε H = 12.0.
# 138 In this review, we have attempted to reanalyze the solar abundances of (nearly) all elements in a homogeneous manner with the best possible atomic data and state-of-the-art solar modeling.
# 139 As a guiding principle, we have been very discerning when selecting the lines for each element, because inclusion of dubious lines only increases the abundance scatter and tends to skew the results toward higher abundances owing to blends.
# 140 The analysis has been carried out using several 1D and 3D model atmospheres and with non-LTE effects accounted for whenever possible, all done with the same well-tested computer codes.
# 141 Unless specified otherwise, the results presented here have been based on the new 3D hydrodynamical solar model atmosphere of Trampedach et al. (in preparation).
# 142 Below we present in some detail how the abundances were derived but the full description of the analysis (including line lists with all relevant data for the transitions) will appear in a forthcoming series of articles in Astronomy Astrophysics (Asplund et al., in preparation; Grevesse et al., in preparation; Sauval et al., in preparation; Scott et al., in preparation).
# 143 There are a wide range of potential sources of error in solar and stellar abundance analyses, from inaccurate input data for the transition ( gf -values, line broadening, etc.) to difficulties in estimating line strengths (finite signal-to-noise, continuum placement, blends, etc.), to inadequacies in the atmospheric and line-formation modeling (1D, LTE, mixing length and microturbulence parameters, continuous opacities, etc.).
# 144 No consensus exists in the solar abundance literature on how the uncertainties should be quantified.
# 145 Some researchers have used the standard deviation arising from the chosen sample of lines to represent the total error for a given species, while others have employed the standard error of the mean or some different measure altogether.
# 146 Previous compilations of the solar chemical composition contained a mixture of different error estimates, because the values were taken from sources with differing modus operandi.
# 147 We have attempted to quantify three possible systematic errors introduced by the modeling: mean atmospheric stratification, atmospheric inhomogeneities, and departures from LTE.
# 148 The first uncertainty has been estimated by taking half the difference between the results with the spatially averaged 3D model (denoted 〈3D〉) and the Holweger Müller (1974) model.
# 149 The second has been evaluated as half the difference between the full 3D results and those from 〈3D〉.
# 150 The inclusion of the theoretical MARCS ( Gustafsson et al. 2008 ) and semiempirical MISS ( Allende Prieto et al. 2001 ) models serves as a further check on these two systematic errors.
# 151 Owing to the general lack of non-LTE calculations for the majority of elements, the non-LTE uncertainty is more difficult to quantify.
# 152 Somewhat arbitrarily, in most cases we have chosen half of the predicted non-LTE abundance correction as an estimate of the error.
# 153 Occasionally, we have employed the difference between the cases with and without inelastic H collisions through the Drawin (1968) formula, while taking into account the recommendations by Asplund (2005) .
# 154 We have used an arbitrary, minimal estimate of the possible errors in the non-LTE corrections of 0.03 dex.
# 155 In some cases, this might overestimate the non-LTE systematic error, whereas in others it probably underestimates the error; there is, unfortunately, no other consistent way to include such unknown errors.
# 156 Estimating possible systematic errors arising from inappropriate line input data has not been attempted here; relative errors in gf -values will at least be accounted for in the dispersion of the lines.
# 157 When the elemental abundance is determined by only one or very few lines, we have attempted to estimate an additional error arising from uncertainties owing to continuum placement and possible blends.
# 158 The systematic errors have been added in quadrature with the statistical error to estimate the total uncertainty, which is used throughout the review unless specified otherwise.
# 159 The statistical error has been computed from the weighted standard error of the mean, with weights assigned to each line according to uncertainties in the continuum placement and known or suspected minor blends.
# 160 3.1.
# 161 Lithium, Beryllium, and Boron 3.1.1.
# 162 Lithium.
# 163 In the Sun, Li is depleted by about a factor of 150 compared to the already small meteoritic value.
# 164 Even the Li i resonance line at 670.8 nm is therefore very weak.
# 165 The line is blended by an assortment of CN and Fe i lines, which makes the Li abundance determination very challenging.
# 166 Because the transition arises from the ground state of a minority species, the line is sensitive to both the temperature and photoionizing UV radiation field ( Kiselman 1997 , Asplund 2005 ) The recommended value given in Table 1 stems from the analysis of Müller, Peytremann de La Reza (1975) , which has been corrected for the effects of atmospheric inhomogeneities and 3D non-LTE effects ( Asplund et al. 1999 , Barklem, Belyaev Asplund 2003 ).
# 167 The solar Li depletion cannot be explained by standard models based on the mixing length theory of convection but requires additional mixing below the convection zone ( Brun, Turck-Chièze Zahn 1999 , Charbonnel Talon 2005 ).
# 168 3.1.2.
# 169 Beryllium.
# 170 Early work implied that Be was depleted in the solar convection zone by about a factor of two ( Chmielewski, Brault Müller 1975 ).
# 171 This interpretation was challenged by Balachandran Bell (1998) , who argued that one must take into account the long-suspected missing UV opacity (e.g., Short Hauschildt 2005 , and references therein) in synthesizing the Be ii resonance lines at 313 nm.
# 172 They estimated the amount of missing opacity by requiring that the nearby OH electronic lines would return the same O abundance as the OH vibrational lines in the IR, which increased the derived photospheric Be abundance to the meteoritic value.
# 173 The required extra opacity can be largely attributed to photoionization of Fe i ( Bell, Balachandran Bautista 2001 ).
# 174 The Balachandran Bell analysis was corroborated by Asplund (2004) , who found that the basic conclusions are independent of the adopted model atmosphere, whether 1D or 3D.
# 175 The Be ii lines are not sensitive to non-LTE effects in the Sun ( Asplund 2005 ).
# 176 3.1.3.
# 177 Boron.
# 178 The problem of the missing UV opacity may also impact the solar B abundance determination, which can realistically only be based on the B i 249.7-nm resonance line.
# 179 Cunha Smith (1999) have reanalyzed the line with careful consideration of the important Mg i photoionization cross sections.
# 180 The effects of departures from LTE ( Kiselman Carlsson 1996 ) and 3D hydrodynamical model atmospheres ( Asplund, Grevesse Sauval 2005 ) are small and opposite in sign.
# 181 There is still a large uncertainty attached to the resulting abundance, log ε B = 2.70 ± 0.20, owing to the difficulty in analyzing this crowded spectral region.
# 182 Not surprisingly, B does not appear depleted in the solar photosphere.
# 183 3.2.
# 184 Carbon The solar C abundance can be inferred from a wealth of indicators, from low-excitation forbidden and high-excitation permitted atomic C i lines to various molecular transitions of CH, C 2 , and CO ( Lambert 1978 ).
# 185 This fortunate circumstance has not translated into a well-determined abundance over the years as the different diagnostics have often yielded discrepant results.
# 186 The preliminary abundance log ε C = 8.56 ± 0.04 recommended by Anders Grevesse (1989) eventually became 8.60 ± 0.05 in the final analysis of Grevesse et al. (1991) .
# 187 Grevesse Sauval (1998) based their value of 8.52 ± 0.06 on an unpublished analysis employing a Holweger Müller (1974) model with a modified temperature structure, in an attempt to remove existing trends with excitation potential and equivalent widths for C, N, O, and Fe.
# 188 Over the past decade, the solar C abundance has undergone an even more drastic downward revision.
# 189 Allende Prieto, Lambert Asplund (2002) reanalyzed the [C i ] 872.7-nm line and found that the combination of a 3D hydrodynamical solar model ( Asplund et al. 2000b ) and an updated gf -value brought the abundance down to 8.39 ± 0.04.
# 190 The same value was obtained by Asplund et al. (2005) , who also employed C i , C 2 , and CH electronic and vibration lines using the same 3D model.
# 191 Convincingly, all indicators gave consistent results, further strengthening the case for the reality of the low C abundance.
# 192 In sharp contrast, the abundances estimated with the Holweger Müller (1974) model atmosphere disagreed by ≈0.2 dex.
# 193 The presence of temperature inhomogeneities and a cooler mean temperature structure in the 3D model compared to the previously employed Holweger Müller (1974) model reduced the deduced abundance from the molecular lines in particular, whereas significant departures from LTE had a similar effect on the C i lines.
# 194 Using weak lines of the extremely temperature-sensitive CO molecule and a self-consistently derived O abundance, Scott et al. (2006) corroborated this finding.
# 195 They also determined an isotopic ratio of 12 C/ 13 C = 86.8 ± 3.8.
# 196 The value we recommend here, log ε C = 8.43 ± 0.05, is slightly higher than in Asplund, Grevesse Sauval (2005) , and stems from the mean of the 3D-based results for [C i ], C i , CH, and C 2 lines (Asplund et al., in preparation).
# 197 As illustrated in Table 2 , the various C indicators imply highly uniform abundances.
# 198 With the exception of a correlation between derived abundance and line strength for C i , there are no trends with transition properties such as excitation potential or equivalent width for any of the species.
# 199 A similar trend was also present in Asplund et al. (2005) , which was attributed to underestimated non-LTE effects for the stronger lines ( Fabbian et al. 2006 ).
# 200 We note that only 1D non-LTE abundance corrections have been employed for the C i results, while the departures from LTE are expected to be exacerbated in the presence of atmospheric inhomogeneities ( Asplund 2005 ); a full 3D non-LTE study for C would clearly be worthwhile.
# 201 Given the importance of this abundant element, it is essential that our results are confirmed by an independent group using an independent 3D model, akin to the analysis of the solar O abundance ( Caffau et al. 2008a ).
# 202 Table 2 The derived photospheric solar C, N, and O abundances for the available indicators using different solar model atmospheres a a The results have been obtained with a 3D hydrodynamical model of the solar atmosphere as well as with the temporally and spatially (over equal optical depth surfaces) averaged 3D model (denoted 〈3D〉), the 1D theoretical MARCS model ( Gustafsson et al. 2008 ), and the 1D semiempirical model of Holweger Müller (1974) .
# 203 The errors given here are only the standard deviation ( σ ) for each type of transition.
# 204 For the atomic transitions, departures from LTE have been considered.
# 205 3.3.
# 206 Nitrogen The N abundance can be determined from both atomic and molecular lines, although the forbidden [N i ] lines are too weak in the solar spectrum to be measurable ( Grevesse et al. 1990 ).
# 207 A preliminary N abundance was given in Asplund, Grevesse Sauval (2005) using high-excitation N i lines and NH vibration-rotation lines in the IR, whereas in our final analysis also NH-pure rotation lines and a multitude of transitions from various bands of CN have been considered in the framework of an improved 3D model (Sauval et al., in preparation).
# 208 The non-LTE effects for N i are relatively small: ≈−0.05 dex when ignoring H collisions ( Caffau et al. 2009 ).
# 209 In their own analysis of these very weak N i lines using their CO5BOLD 3D solar model, Caffau et al. (2009) obtained a N i -based abundance that is 0.08 dex higher than our corresponding value, largely owing to the selection of lines.
# 210 They included many lines that we consider to be of dubious value owing to known or suspected blends.
# 211 This is also reflected in the dramatically different standard deviations for the N i lines in the two studies: σ = 0.04 and 0.12 dex, respectively.
# 212 We find good agreement between abundances inferred from N i and NH lines, with small dispersion in the NH results.
# 213 The different CN bands also give similar results when employing a self-consistently derived C abundance with the 3D model.
# 214 Unfortunately, Caffau et al. (2009) did not consider molecular lines, and it is therefore not known how well their 3D model performs in achieving consistent results for atoms and molecules.
# 215 It is sometimes stated in the literature that the molecular lines are more temperature sensitive than atomic lines, but in fact the NH lines are less so than these highly excited N i lines.
# 216 The N abundance that we recommend here, log ε N = 7.83 ± 0.05, is 0.09 dex lower than that suggested by Grevesse Sauval (1998) and 0.22 dex lower than in Anders Grevesse (1989) .
# 217 3.4.
# 218 Oxygen Oxygen is the most abundant element in the cosmos not produced in the Big Bang and the third most common overall.
# 219 Oxygen and its isotopes are key tracers of the formation and evolution of planets, stars, and galaxies and as such it is one of the most important elements in all of astronomy.
# 220 Nevertheless, or perhaps consequentially, its abundance often seems to be in dispute; the solar O abundance is no exception.
# 221 The favored solar content has dropped almost precipitously over the past two decades from log ε O = 8.93 ± 0.04 in Anders Grevesse (1989) to 8.66 in Asplund, Grevesse Sauval (2005) .
# 222 The value we recommend here, log ε O = 8.69 ± 0.05, stems from a 3D-based study of the available diagnostics: forbidden [O i ] and permitted O i transitions as well as vibration-rotation and pure rotation lines of OH (Asplund et al., in preparation).
# 223 Allende Prieto, Lambert Asplund (2001) reanalyzed the [O i ] 630-nm line with a 3D model atmosphere.
# 224 Based on the line profile, they demonstrated that the line is blended by a Ni i line, which was subsequently confirmed experimentally ( Johansson et al. 2003 ).
# 225 In combination with the 3D model, recognition of the blend led to a substantial lowering of the solar O abundance compared to the canonical value at the time.
# 226 Ayres (2008) revisited the 630-nm line with a single snapshot of another 3D model but found a 0.12 dex higher O abundance, partly because he allowed the Ni i gf -value to vary freely in spite of the new accurate measurement by Johansson et al. (2003) .
# 227 Caffau et al. (2008a) used several snapshots from the same CO5BOLD 3D model but instead fixed the Ni contribution assuming the Ni abundance from Grevesse Sauval (1998) , thereby confirming the results of Allende Prieto, Lambert Asplund (2001) and Asplund et al. (2004) .
# 228 A more self-consistent approach is to first determine the Ni abundance before considering the [O i ] line, as done by Scott et al. (2009) with the same 3D model as employed by Asplund et al. (2004) .
# 229 As explained by Scott et al. (2009) , it is then possible to very accurately predict the Ni i contribution to the overall line strength, independent of the reference atmospheric model.
# 230 We have updated this analysis with the new 3D model and find that the effects of the increased Ni i proportion and the shallower model temperature gradient in comparison with Allende Prieto, Lambert Asplund (2001) compensate for one another, leaving the abundance at log ε O = 8.66.
# 231 This abundance is also consistent with the center-to-limb variation of the 630-nm feature (Pereira et al., in preparation).
# 232 In addition to the 630-nm line, there are two other [O i ] transitions that can be utilized.
# 233 The 636-nm line is located in the midst of a very broad Ca i autoionization line as well as blended by CN lines; the latter's contribution can, however, be accurately predicted from other neighboring CN lines.
# 234 Like Caffau et al. (2008a) , we find that this line returns a slightly higher abundance than the 630-nm line, but the two lines are still consistent within the uncertainties.
# 235 Meléndez Asplund (2008) added the [O i ] 557-nm line, whose slightly excited lower level makes it largely independent of the model atmosphere.
# 236 Unfortunately, this transition is badly blended by C 2 lines, whose contribution Meléndez Asplund attempted to estimate using nearby C 2 lines with the same line strengths and excitation potential.
# 237 We obtain an abundance from the 557-nm line somewhat higher than those from the other two forbidden transitions.
# 238 The three [O i ] lines imply a solar O abundance of log ε O = 8.70 ± 0.05 when due consideration is given to the blends.
# 239 Recently, Centeno Socas-Navarro (2008) introduced a novel method to estimate the O abundance, namely spectropolarimetry of the [O i ] 630-nm line in a sunspot.
# 240 Because of the different polarization of the [O i ] and Ni i lines, it is possible to disentangle the Ni i contribution.
# 241 After consideration of the fraction of O tied up in CO in the cool environments of sunspots, they obtained a high O abundance of log ε O = 8.86.
# 242 Scott et al. (2009) have, however, pointed out that Centeno Socas-Navarro applied an outdated gf -value for the [O i ] line.
# 243 Furthermore, they showed that when using an improved Ni abundance and an alternative CO treatment, one finds a significantly lower O abundance: log ε O = 8.71; a further reduction is obtained when employing an alternative sunspot model.
# 244 There are a half dozen or so permitted, high-excitation O i lines useful for solar abundance purposes.
# 245 Of these, the relatively strong 777-nm triplet lines are arguably the most reliable because the others are either weak or partly blended.
# 246 The main challenge when employing the O i lines relates to quantifying the non-LTE effects, which can be significant.
# 247 The predicted non-LTE abundance corrections are little dependent on the model atmosphere in question, be it 1D or 3D ( Asplund et al. 2004 ), but they do depend on the adopted collisional cross sections, in particular the inelastic H collisions (e.g., Kiselman 1993 , Asplund 2005 ).
# 248 Different approaches have been used in solar abundance works to date, where some neglect the H collisions altogether based on the available atomic physics data for other elements, while others use the classical Drawin (1968) formula, possibly with a scaling factor S H that typically varies from 0 to
# 249 1. Holweger (2001) found log ε O = 8.71 ± 0.05 using the Holweger Müller (1974) model with granulation corrections estimated from a 2D solar model, whereas Asplund et al. (2004) obtained a 0.07-dex lower abundance from a 3D non-LTE study; the main difference, however, between the two studies is the adopted H collisions ( S H = 1 and 0, respectively).
# 250 Allende Prieto, Asplund Fabiani Bendicho (2004) attempted to calibrate the poorly known collisional efficiency through a comparison of the center-to-limb variation of the O i 777-nm line strengths because the relative importance of H collisions changes as N H / N e increases with smaller optical depths.
# 251 They found that S H = 1 was a marginally better fit than S H = 0, whereas the LTE case could be ruled out at high-significance level.
# 252 Recently, Pereira et al. (in preparation) have revisited the issue equipped with better solar observations and tested additional S H values but have arrived at a similar conclusion, as can be seen in Figure 5 .
# 253 Figure 5 Comparison of the observed ( open gray circles with error bars ) and predicted center-to-limb variation of the equivalent width of the O i 777.19-nm triplet line as a function of viewing angle ( μ = 1 corresponds to disk center and 0 to the limb).
# 254 The theoretical curves are the result of full 3D non-LTE line formation calculations with different adopted efficiency for the poorly known inelastic H collisions; the O abundances have been normalized to fit the disk-center line strengths in each case.
# 255 The curves are labeled with the scaling factor used to multiply the classical formula ( Drawin 1968 ).
# 256 The solar observations thus seem to suggest that this recipe is a rather accurate representation for O i (Pereira et al., in preparation).
# 257 The O i -based abundance we adopt here is based on full 3D non-LTE calculations with S H = 1 (Asplund et al., in preparation; Pereira et al., in preparation).
# 258 The new electron collisional cross sections computed by Barklem (2007a) have also been adopted (see Fabbian et al. 2009 for an account of the impact of these on other stars).
# 259 The revised abundance is slightly higher than that in Asplund et al. (2004) : log ε O = 8.69 ± 0.05.
# 260 Using a different 3D model, Caffau et al. (2008a) obtained log ε O = 8.73 ± 0.06 (unweighted mean) for their disk-center O i lines, in spite of using S H = 1/3; with S H = 1 their result would be 0.02 dex higher.
# 261 Because they were restricted to 1D non-LTE calculations, they were unable to carry out line profile fitting as done by Asplund et al. (in preparation).
# 262 They were, therefore, forced to rely on measuring equivalent widths, which were surprisingly large compared to all previous published studies.
# 263 Reassuringly, when the same input data are adopted (e.g., line strengths, non-LTE corrections), the Caffau et al. (2008a) analysis is in excellent agreement with ours, which shows that the exact choice of 3D model is of relatively little consequence for the permitted O i lines; indeed quite similar results are obtained with 1D models.
# 264 Grevesse, Sauval van Dishoeck (1984) and Sauval et al. (1984) introduced the vibration-rotation and pure rotation lines of OH as solar O abundance indicators.
# 265 In their 3D-based analysis, Asplund et al. (2004) found that the OH lines implied an O abundance only slightly lower than the atomic transitions.
# 266 Although the vibration lines showed no trends with excitation potential or line strength, the pure rotation lines did.
# 267 This is not too surprising, because these strong rotation lines are formed in very high atmospheric layers, which are the most challenging to model realistically owing to, for example, magnetic fields, non-LTE, and nonequilibrium chemistry.
# ...
# 617 Following the initial revisions of the solar C and O abundances by Allende Prieto, Lambert Asplund (2001 , 2002) , many possible solutions have been put forward to explain the problem, albeit with little success to date.
# 618 The most obvious explanation would be that the opacities are underestimated.
# 619 Bahcall et al. (2005) estimated that a 10–20% increase of the OPAL opacities over a relatively substantial fraction of the solar interior ( R = 0.4–0.7 R ⊙ or equivalently T = 2–4 × 10 6 K) would be required; Christensen-Dalsgaard et al. (2009) found even slightly more stringent requirements with the Asplund, Grevesse Sauval (2005) solar abundances.
# 620 Serenelli et al. (in preparation) have investigated the differences with the solar chemical composition presented here and conclude that ≤12% extra opacity is required to restore the previous agreement in sound speed.
# 621 Little suggests, however, that current atomic physics calculations for stellar interiors are missing such a substantial fraction of the opacity.
# 622 For example, Badnell et al. (2005) showed that opacities from the Opacity Project are at most 3% larger than the corresponding OPAL values in the relevant temperature range.
# 623 Although perhaps unlikely to cure the problem by itself, it is wise to bear in mind that a similar situation for pulsating stars in fact existed in the 1980s, which found an unexpected resolution with the more comprehensive calculations by the OPAL and OP collaborations.
# 624 There are other ways to compensate for the lower opacities resulting from the lower C, N, O, and Ne abundances.
# 625 One is that the radiative interior contains more metals than expected from the photospheric abundances and standard models for diffusion.
# 626 Asplund et al. (2004) first suggested that the diffusion efficiency may be seriously underestimated but the required elemental settlement is about twice the predicted value.
# 627 Furthermore, though this may remedy the sound speed discrepancy, problems still remain in terms of the He abundance and depth of the convection zone ( Montalbán et al. 2004 ; Guzik, Watson Cox 2005 ; Yang Bi 2007 ).
# 628 A hypothetical late accretion of metal-depleted gas during the formation of the Sun runs into the same trouble ( Guzik, Watson Cox 2005 , Castro, Vauclair Richard 2007 ).
# 629 Alternatively, the reduced O abundance could conceivably be compensated by a corresponding (but larger) increase in the Ne abundance ( Antia Basu 2005 ).
# 630 Bahcall, Basu Serenelli (2005) estimated that a factor of three (0.5 dex) higher Ne content compared to the recommended values of Asplund, Grevesse Sauval (2005) , together with minor adjustments of C, N, O, and Ar within their associated uncertainties, would restore the good agreement found with the Grevesse Sauval (1998) solar composition.
# 631 There was initial excitement when Drake Testa (2005) argued for exactly such an increase in Ne on the basis of inferences from coronal spectroscopy of other stars, but there is in fact little support for this idea, as explained in Section 3.9.
# 632 The here recommended abundance of Ne is slightly higher than in Asplund, Grevesse Sauval (2005) , as are our recommended values for C, N, and O. This shift only partly allays the solar modeling discrepancy, as seen in Figure 8 .
# 633 Given that the problem exceeds the likely uncertainties in existing input data (e.g., opacities, diffusion, abundances), the only remaining option on the solar interior side seems to be to invoke some physical process not yet accounted for in standard solar models.
# 634 It is perhaps suggestive that the largest deviation occurs immediately below the convection zone.
# 635 Arnett, Meakin Young (2005) have proposed that internal gravity waves generated by the convective motion at the base of the convection zone propagate inward and deposit their energy in the radiative zone.
# 636 The ensuing structure changes are similar to an opacity enhancement, thus going in the right direction.
# 637 In addition, the gravity waves induce additional mixing, which would also help.
# 638 Young Arnett (2005) have investigated these processes using multidimensional hydrodynamical simulations of stellar convection zones and found qualitative improvements in many stellar regimes.
# 639 Owing to the computationally very challenging nature of the hydrodynamics, the modeling is unfortunately not yet able to quantitatively predict whether the effects are sufficient to explain the helioseismic signature.
# 640 Thus, most suggestions to resolve the solar modeling discrepancy have already been ruled out or are considered improbable.
# 641 The few possibilities still standing do so largely because no detailed modeling has as yet been forthcoming to properly put the proposals to test.
# 642 It is possible that a combination of several factors could be the explanation, but such fine tuning would seem rather contrived.
# 643 Should no likely solution be found, it would suggest that the photospheric abundances presented herein are wrong.
# 644 Given the discussion in Sections 2 and 3, it is not easy to understand where such a serious error may lie but the possibility should obviously not be discounted.
# 645 4.4.
# 646 Solar Neutrinos Neutrinos provide another means by which to infer the solar chemical composition, though current experiments are not yet sufficiently sensitive to return decisive results in this respect.
# 647 The metallicity adopted in a solar model modifies the conditions in the core, and thus the neutrino fluxes produced by the pp-chain and CNO-cycle.
# 648 Although the neutrino fluxes cannot be directly associated with abundances of individual elements, the relevant neutrino channels depend most sensitively on C, N, O, Si, and Fe ( Bahcall Serenelli 2005 ).
# 649 Using neutrino data from the SuperKamiokande I+II, SNO, and Borexino experiments, Pena-Garay Serenelli (2008) have derived the neutrino oscillations and fluxes expected from solar models constructed with the Grevesse Sauval (1998) and Asplund, Grevesse Sauval (2005) compositions.
# 650 Intriguingly, the existing data imply 7 Be and 8 B neutrino fluxes that fall between the predictions for the two models; we suspect that the solar neutrinos would favor the new abundances presented herein.
# 651 A more direct test of the heavily debated solar C, N, and O abundances would come from measuring the 13 N and 15 O β -decay neutrinos that follow proton capture on 12 C and 14 N, respectively.
# 652 Meaningful constraints should come from Borexino within the next couple of years, and the proposed SNO+ experiment should weigh in with a definite answer sometime after 2011 ( Haxton Serenelli 2008 ).
# 653 5. CONCLUDING REMARKS 5.1.
# 654 Summary Points We have critically examined all ingredients for the determination of the solar photospheric chemical composition, from the atmospheric and line-formation modeling, required atomic data, and selection of lines to the final estimate of the elemental abundances and associated errors (Section 3).
# 655 A notable feature of this analysis is that for essentially every element, the effects of 3D hydrodynamical model atmospheres have now been accounted for.
# 656 The 3D solar model employed here outperforms any 1D model, theoretical or semiempirical, in a raft of observational tests.
# 657 The values we recommend for the most abundant metals C, N, O, Ne, and Fe are significantly smaller (by ∼0.2 dex) than those advocated in the widely used compilation of Anders Grevesse (1989) .
# 658 Most of these differences can be attributed to the improvements over the past two decades in modeling the solar atmosphere, allowing for departures from LTE in the line formation, properly treating blends, and employing improved atomic and molecular data (Section 2).
# 659 Among other things, these new, lower abundances are supported by the excellent agreement between different abundance indicators for C, N, and O: low-excitation forbidden atomic lines, high-excitation permitted atomic lines, and various molecular features.
# 660 A comparison of the photospheric abundances and the most primitive class of meteorites, the CI chondrites, reveals a very good agreement for nearly all non-volatile elements (Section 4.1).
# 661 Because the volatile elements, including H, have been depleted in the chondrites, the meteoritic abundance scale has been placed on the same absolute level as the photospheric abundances by enforcing equivalence of the Si abundances.
# 662 The remaining few elements that suggest a significant difference between meteorites and the Sun can probably be attributed to poor solar determinations, likely owing to incorrect gf -values, unidentified blends, or unaccounted/wrong non-LTE effects.
# 663 In order to make a meaningful comparison between the Sun and the abundances measured in the Solar Neighborhood, one must first correct for the effects of diffusion in the Sun and chemical enrichment in the Galaxy over the past 4.56 Gyr.
# 664 All elements are predicted to have settled to the solar interior by essentially the same amount, meaning that the bulk, or equivalently the protosolar, composition is higher by 0.04 dex than listed in Table 1 for all elements heavier than He (Section 3.11).
# 665 Our recommended solar abundances agree very well in general with those measured in nearby OB stars, H ii regions like Orion and the local interstellar medium (Section 4.2).
# 666 We note that care should be exercised when comparing our solar results with corresponding abundances for late-type stars derived with classical 1D model atmospheres; ideally a differential study of the stars and the Sun should be performed; the solar abundances presented in Table 1 should be used to place them on an absolute scale.
# 667 In spite of the many apparent successes of the solar chemical composition we recommend here, the outlook is not entirely rosy.
# 668 With the downward revision of the overall metal content presented here compared to the Grevesse Sauval (1998) abundances, the previous excellent agreement between predicted sound speeds from standard solar models and those inferred from helioseismology is ruined (Section 4.3).
# 669 To date, there has been no fully convincing solution put forward.
# 670 The discordance has been alleviated somewhat relative to the recommended values in Asplund, Grevesse Sauval (2005) , but it nevertheless remains a significant discrepancy in urgent need of resolution.
# 671 5.2.
# 672 Future Issues Although major progress has been made in recent years in the inferred solar chemical composition, there is no question that a great deal of work remains before we can confidently state that each solar elemental abundance is known to better than 0.01 dex (2%).
# 673 For many, if not most elements, the achieved accuracy today is more like 0.05 dex or indeed significantly worse in many cases.
# 674 A concerted effort on multiple fronts is required to substantially decrease the remaining uncertainties.
# 675 We do not consider it likely that subsequent generations of 3D hydrodynamical model atmospheres will dramatically (that is, at the >0.1 dex level) amend the inferred solar photospheric chemical composition, given how successful the most recent models are in reproducing key observational diagnostics.
# 676 It is fair to say that the mean temperature structure of the quiet solar granulation, the velocity distribution, and the atmospheric inhomogeneities are now rather well known, at least in the formation regions of the weaker lines largely employed by the abundance studies described herein.
# 677 Higher atmospheric layers, to which the strongest atomic and molecular lines are more sensitive, are naturally less constrained observationally; on the modeling side this requires improved radiative transfer treatment and allowance of departures from LTE for key elements.
# 678 For completeness, one should include the effects of magnetic fields in the 3D solar atmospheric models, but we do not expect that these will noticeably influence the derived abundances ( Nordlund, Stein Asplund 2009 ).
# 679 The greatest uncertainties afflicting solar abundance work today instead stem from poor atomic and molecular data, as well as incomplete modeling of departures from LTE.
# 680 Few spectral lines have their transition probabilities determined to better than a few percent.
# 681 As an example here, it suffices to mention the case of Mg with its relatively simple atomic structure: The majority of the Mg i lines employed here and elsewhere for solar abundance purposes still have quoted uncertainties of 25–50% according to the NIST database, which is clearly unacceptable.
# 682 Fortunately, there has been some laudable progress on this score in recent years, in terms of both experimental efforts (e.g., Johansson et al. 2003 , Blackwell-Whitehead Bergemann 2007 , Lawler et al. 2009 ) and theoretical calculations (e.g., Kurucz 1992 , Plez 1998 , Badnell et al. 2005 ), as discussed in Section 2.2.
# 683 A major problem, however, is the dearth of atomic physicists devoted to satisfying the astronomical need for various types of input data; the astronomical community ought to better appreciate and encourage the relatively few individuals carrying out this important work, given its tremendous benefit for solar and stellar astrophysics especially.
# 684 On the wish list are improved gf -values for Mg i , Mg ii , Si ii , Ca ii , the once-ionized species of the Fe-peak elements, Cu i , and Sr ii .
# 685 Also, atomic lines in the IR have great potential given the accurate determination of the continuum and few blends but more often than not accurate transition probabilities are lacking.
# 686 Equally important is the consideration of non-LTE effects on line formation.
# 687 As discussed by Asplund (2005) , even though departures from LTE are expected to be relatively serene in the Sun, one should always expect non-LTE abundance corrections at around the 0.05 dex level; indeed in many cases the effects will be significantly more severe.
# 688 Still today, most elements have not been exposed to a detailed non-LTE study even in the Sun.
# 689 Even rarer are solar abundance works going beyond the 1D framework and employing 3D non-LTE calculations (e.g., Asplund, Carlsson Botnen 2003 ; Asplund et al. 2004 ).
# 690 In part, the scarcity of non-LTE studies is related to a lack of adequate atomic data.
# 691 Compared to the LTE case, vastly more input data are required in non-LTE calculations than are presently available for most elements.
# 692 Significant headway will only become possible with the advent of detailed photoionization and collisional cross sections; for the latter, estimates of the impact of both electron and H collisions, as well as other processes like charge transfer, are urgently needed.
# 693 There is also an issue of manpower; careful non-LTE studies are very time-consuming and there are not enough specialists working in the field to satisfy the demand.
# 694 Finally, we note that non-LTE line formation should be explored in 3D model atmospheres, because the presence of atmospheric inhomogeneities is generally expected to amplify any existing non-LTE effects seen in 1D.
# 695 A section on future issues in the solar chemical composition would not be complete without stressing the importance of finally resolving the solar modeling problem uncovered by helioseismology (Section 4.3).
# 696 Many hypotheses have been put forward to explain the discrepancy, but no clear solution has been forthcoming.
# 697 Until an explanation has been found, a mutual cloud of doubt will always linger over the solar chemical composition recommended here and current models of the solar interior.
# 698 Whether the problem will be traced in the end to shortcomings in the atmospheric or interior modeling remains to be seen, but whatever the resolution it will place solar and stellar astrophysics—and, by extension, most of astronomy—on a much firmer footing.
