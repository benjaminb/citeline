# %%
import requests
from pprint import pprint
import pandas as pd

df = pd.read_json("data/dataset/100/nontrivial.jsonl", lines=True)

# %%
def ask_ollama(prompt):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "llama3.3",
        "prompt": prompt,
        "temperature": 0.01,
        "stream": False
    }

    response = requests.post(url, json=payload)
    result = response.json()
    return result['response']

# %%
extraction_prompt = """
Output ONLY the inline citations from the text below as a list of tuples
- Each citation becomes a (string, int) tuple where the string is the first author's name and the int is the year
- If there are no citations in the text, output []
- Do not count citations 'in preparation' or lacking a year
- Do not include any introductory text, explanations, or anything before or after the array

Examples of inline citations:
'''
Sentence: "Like Caffau et al. (2008a) , we have similar findings."
Output: [('Caffau et al.', 2008)]

Sentence: "Multiply by the number of stars in the sample ( 10 000 ) and the number of stars in the galaxy ( 100 billion ) to get a total of 10 trillion stars (Caffau Moritz 2008b)."
Output: [('Caffau Moritz', 2008)]

Sentence: "Methods for mixing below the convection zone are well understood ( Brun, Turck-Chièze Zahn 1999 , Charbonnel Talon 2005 )."
Output: [('Brun', 1999), ('Charbonnel', 2005)]

Sentence: "Momentum balance gives an expression ( Fabian 1999 ; Fabian, Wilman Crawford 2002 ; King 2003 , 2005 )"
Output: [('Fabian Moritz', 1999), ('Fabian', 2002), ('King', 2003), ('King', 2005)]

Sentence: "This is consistent with previous results (Pereira et al., in preparation)."
Output: []
'''

Now extract the inline citations from the following text:
'''
{text}
'''

Output format: 
[('first author', year), ('first author', year), ...]
"""
text = 'neglect the H collisions altogether based on the available atomic physics data for other elements, while others use the classical Drawin (1968) formula, possibly with a scaling factor S H that typically varies from 0 to 1. Holweger (2001) found log ε O = 8.71 ± 0.05 using the Holweger Müller (1974) model with granulation corrections'

# print(prompt.format(text=text))
response = ask_ollama(extraction_prompt.format(text=text))
print(response)
# Out:
# [('Drawin', 1968), ('Holweger', 2001), ('Holweger', 1974)]

# %%
strip_prompt = """
Remove the inline citations from the text below.

EXAMPLES:
Sentence: "Like Caffau et al. (2008a) , we have similar findings."
Output: "Like , we have similar findings."

Sentence: "Methods for mixing below the convection zone are well understood ( Brun, Turck-Chièze Zahn 1999 , Charbonnel Talon 2005 )."
Output: "Methods for mixing below the convection zone are well understood."

ONLY respond with the modified text. Do not include any explanations or additional information.
Now remove the inline citations from the following text:

Sentence: "{text}"
Output:
"""

# %%
stripped_text = ask_ollama(strip_prompt.format(text=text))
pprint(stripped_text)
# Out:
# neglect the H collisions altogether based on the available atomic physics data for other elements, while others use the classical  formula, possibly with a scaling factor S H that typically varies from 0 to 1.  found log ε O = 8.71 ± 0.05 using the  model with granulation corrections

# %%
pprint(f"Original: {text}")
pprint(f"Stripped: {stripped_text}")
# Out:
# ('Original: neglect the H collisions altogether based on the available atomic '
#  'physics data for other elements, while others use the classical Drawin '
#  '(1968) formula, possibly with a scaling factor S H that typically varies '
#  'from 0 to 1. Holweger (2001) found log ε O = 8.71 ± 0.05 using the Holweger '
#  'Müller (1974) model with granulation corrections')
# ('Stripped: neglect the H collisions altogether based on the available atomic '
#  'physics data for other elements, while others use the classical  formula, '
#  'possibly with a scaling factor S H that typically varies from 0 to 1.  found '
#  'log ε O = 8.71 ± 0.05 using the  model with granulation corrections')

# %%
cites = ask_ollama(prompt=extraction_prompt.format(text=df.sent_original[0]))
pprint(cites)
# Out:
# "[('Ussiri', 2013)]"

# %%
stripped_sentence = ask_ollama(strip_prompt.format(text=df.sent_original[0]))
pprint(f"Original: {df.sent_original[0]}")
pprint(f"Stripped: {stripped_sentence}")
# Out:
# ('Original: These are minor species, with abundances of 1.5 10 12 , 1.7 10 9 , '
#  'and 7 10 8 kg N, respectively ( Ussiri and Lal, 2013 ).')
# ('Stripped: These are minor species, with abundances of 1.5 10 12 , 1.7 10 9 , '
#  'and 7 10 8 kg N, respectively.')

# %%
for i in range(len(df)):
    pprint(f"{i}: {df.sent_no_cit[i]}")
# Out:
# ('0: These are minor species, with abundances of 1.5 10 12 , 1.7 10 9 , and 7 '
#  '10 8 kg N, respectively ( Ussiri and .')
# ('1: The Ellison-Ramaty fit for the 13 event (not shown), provided an even '
#  'poorer overall fit, fitting the high energy points from ∼15 to 400 MeV with '
#  'an e-folding energy of E 0 ∼110 MeV, but failing entirely to fit the '
#  'spectral break at several MeV.')
# ('2: Building on their ideas, Priest and  developed a model in which the '
#  'magnetic field is written in terms of cylindrical polar coordinates , asdue '
#  'to a ring of X-points near and the field of the current sheet itself.')
# ('3: Focusing on 353-GHz data at high Galactic latitudes, the E and B angular '
#  'power spectra of dust polarization were constrained in the multipole range '
#  'of 40l600 ( .')
# ('4: With the above calibration one obtains from a complete sample of 49 '
#  'inclined, untruncated Virgo cluster spirals, as compiled by , and after a '
#  'small correction for the color difference between calibrators and cluster '
#  'galaxies a mean TF distance of μ0 = 31.58 ± 0.16, or reduced to the center '
#  'of the Local Group μ00 = 31.62 (STS 06).')
# ('5: Proton blazar models (  were initially motivated by the search of sources '
#  'of ultra-high-energy cosmic rays, not with a particular need to explain some '
#  'observed features in the blazar SEDs or variability.')
# ('6: The timing of incorporation of these blocks into Asia is relatively well '
#  'constrained by the age of the faults and orogenic belts that bound the '
#  'blocks ( .')
# ('7: This first contribution describes the cluster dark matter halo (and '
#  'implicitly assumes that the ICM follows a similar distribution; see  for a '
#  'study where this assumption is relaxed).')
# ('8: But assuming the existence of ad hoc density fluctuations, may change the '
#  'volume integrated gamma-ray spectrum as to make it similar to the observed '
#  'one Morlino and .')
# ('9: Close-in giant planets are theorized to have their rotation synchronized '
#  'with their orbital motion by tidal forces, a process that should conclude '
#  'within millions of years (e.g., .')
# ('10: ignored data from carbon spherules generated by both YDIH proponents and '
#  'critics that provides one of the most compelling pieces of evidence against '
#  'the YDIH.')
# ('11: Gyrochronology is based on the stellar spin-down due to magnetic braking '
#  'and uses the surface rotation rate as a clock, adopting the so-called '
#  'Skumanich relation between angular momentum loss and rotation rate, ( .')
# ('12: Of particular importance in this context is the subclass CEMP-no, that '
#  'are characterized by high abundances of light elements (C, N, O, Na, Mg, '
#  'Al), but lack enhancement of neutron-capture elements (, and references '
#  'therein).')
# ('13: noted a correspondence between the cessation of high latitude CMEs and '
#  'the polar field reversal.')
# ('14: Significantly, however, a similar step of 20–40 km in lithospheric '
#  'thickness across the Shield/Platform boundary is reported by  .')
# ('15: concluded that the magnetic field of BP Tau is primarily composed of '
#  'dipole and octupole moments, with () and (), respectively.')
# ('16: It also tended produce a lot of false positives: Neugent and  instead '
#  'built on the image-subtraction techniques that had been developed over the '
#  'years primarily to identify supernovae.')
# ('17: Through radiative transfer modeling of gas-phase lines observed with the '
#  'SMA toward two Class I protostars with well-established disks, Brinch  found '
#  'the former to be the case: Relatively simple models for T Tauri disks could '
#  'be applied to those sources with simple chemistry dictated by the amount of '
#  'shielding, in turn determining in what fraction of the disk CO is frozen '
#  'out.')
# ('18: In an influential paper, Dalal  analyzed radio data for a sample of '
#  'seven quadruply-imaged sources and reported the detection of a surface mass '
#  'fraction in the form of substructure between 0.6% and 7%.')
# ('19: Although this is often interpreted as “preheating”, soft X-ray images '
#  'show that in many cases the precursor, though a part of the flare, does not '
#  'coincide with the structure supporting the impulsive phase (Fárník and , '
#  'hence not reflecting the plasma conditions at the site of major energy '
#  'release.')
# ('20: Comments :  described the new species and synonymised another specimen '
#  'previously described as a thalattosaur by  .')
# ('21: Figure 13 Wilkinson Microwave Anisotropy Probe 5-year (WMAP5) data '
#  'showing the degeneracy between the sum of neutrino masses and H o (from '
#  'figure 17 of .')
# ('22: Following these first observations of the large-scale diffuse infrared '
#  'emission a number of far-infrared high spatial resolution observations were '
#  'made of the inner few parsecs surrounding the prominent radio source Sgr A. '
#  'We mention the 17~r resolution map at 53 #m by  and the three- color '
#  'photometry observations at 30, 50 and 100 #m by .')
# ('23: find that all 7 of the groups they identify within the Vela-Puppis '
#  'region are expanding, Armstrongetal.')
# ('24: used the Relative Surface Connection function as a subgrid function to '
#  'improve the prediction of discharge dynamics.')
# ('25: Reference A review of Titan’s atmospheric phenomena 119 123 123 None '
#  'None /11/21 2005/11/22 2005/11/24 OSIRIS/Keck OSIRIS/Keck OSIRIS/Keck '
#  'VIMS/Cassini NIRC2/Keck VIMS/Cassini VIMS/Cassini OSIRIS/Keck ?')
# ('26: This seems to be related to the fact that a solar eclipse, by '
#  'definition, occurs at new moon, which favors the occurrence of the counter '
#  'electrojet (e.g., .')
# ('27: Here we review on preliminary work by , who simulated fully-compressible '
#  'convection inside a rotating spherical shell extending from to .')
# ('28: undertook an intensive monitoring of the UV spectrum of AB Aurigae with '
#  'the International Ultraviolet Explorer (IUE) and detected variations in the '
#  'Mg II and Fe II lines.')
# ('29: The work of  suggests a fundamental distinction in elemental abundances '
#  'between closed and open magnetic structures, matching the nominal '
#  'photospheric and coronal abundances, respectively.')
# ('30: A younger generation of stars (age Myr) is also observed within the '
#  'central 0.5 pc (; .')
# ('31: While it has been shown that a concentration of clouds in the '
#  'sub-stellar region could maintain temperate climates at insulation even '
#  'higher than experienced by early Venus (, thus favoring this temperate Venus '
#  'scenario, details of 3D atmospheric circulation and resulting clouds '
#  'distribution might prevent early ocean formation on Venus.')
# ('32: Multifrequency radioheliograph observations have shown that moving type '
#  'IV bursts are confined to loops and blobs of CMEs (Kundu et a! 1989, .')
# ('33: Prior to launch, synthetic white light WISPR images, created using the '
#  'sophisticated ray-tracing software (, were used to develop new techniques '
#  'for analyzing observed motions of ejecta.')
# '34: This would be the case in what is known as interface dynamos (.'
# ('35: Turbulent damping and wave leakage Longitudinal Waves in Coronal Loops '
#  '77 Fig. 10 Mean energy flux found in observed chromospheric oscillations, as '
#  'a function of frequency, adapted from  are the main mechanisms proposed to '
#  'account for the damping of the p-modes and a comparison with the energy flux '
#  'contained in the observed coronal perturbations offers a rare opportunity to '
#  'evaluate the contribution of wave leakage by direct observation.')
# ('36: found for their model that although the induced electric field inside '
#  'the WTS is small in absolute terms (about 3 mV/m), it maps into an area that '
#  'is characterized by a small potential electric field and high conductances.')
# ('37: When the flux of water reaches the channel and the subsurface saturated '
#  'area becomes connected to it, there is an immediate increase in subsurface '
#  'storm flow rate ( Tromp-Van Meerveld and .')
# ('38: However, when describing the IMF as a log-normal function ( , the '
#  'parameters for the UFDs are consistent with the Milky Way IMF.')
# ('39: Although the propagation of the bending waves proved problematic in the '
#  'context of the observed galactic warp, they provide a nice check of the '
#  "theory in the case of Saturn's rings ( .")
# ('40: It also hosts a Compton-thick AGN in the Western component, observed '
#  'directly in hard X-rays (Della ; .')
# ('41: Not only is this an elegant method to detect dark matter (see also Buote '
#  ', 1997 ), it serves as a warning, generally ignored, that the dark matter '
#  'may not be distributed in a quasispherical fashion.')
# ('42: Evidence for very great youth comes from the study of BM Ori (θ 1 Ori B) '
#  'by Palla  , who find that star to have an age of 100,000 years.')
# ('43: The time delays (Sect. 6.4 ) involved in the solar dynamo including '
#  'simple amplitude limiting nonlinearity can produce the same period-doubling '
#  'and Gnevyshev–Ohl rule as seen in the complex nonlinear system (.')
# ('44: Modeling of the expected sky brightness increase from development of '
#  'vacant commercial/industrial properties, performed by R. Garstang using an '
#  'early version of his model ( were used to establish a limit of 25,000 (lamp) '
#  'lumens per acre (10,100 lm per hectare) within a zone of 2.5 mile radius '
#  'centered at NOFS.')
# ("45: The very uncertain direct age determinations for the K giants in Baade's "
#  'Window ( allow a substantial age gap, of order 7 Gyr, between these stars '
#  'and the oldest subdwarfs.')
# ('46: The second brightest SCUBA source, falling just outside the primary '
#  'WFPC2 field, has no obvious counterpart in the flanking field WFPC2 images, '
#  'nor in the NICMOS data of  .')
# ('47: Work by ,b) suggests that in jökulhlaup-prone settings, high-magnitude '
#  'flood deposits form the greater part of the Holocene sedimentary record.')
# ('48: doi:10.1086/185542 Belsole E, Worrall DM, Hardcastle MJ, Birkinshaw M, '
#  'Lawrence  XMM-Newton observations of three high-redshift radio galaxies.')
# ('49: In particular, formation of a close binary can start in the early phase '
#  'before the collapse of a second core and even during the protostellar phase '
#  'because of angular momentum redistribution at the center of the system (.')
# ('50: Decades of in situ electric field measurements have failed to find '
#  'electric field strengths anywhere near the conventional breakdown threshold, '
#  'even when the effects of precipitation are included (MacGorman and .')
# ('51: In a detailed model for energy deposition and spectrum formation,  '
#  'estimate a mass M 44 =(1.5±0.5)×10 −4 M ⊙ , which is consistent with the '
#  'NuSTAR observation.')
# ('52: This alternative hypothesis is supported by recent seismic surveys in '
#  'central Tibet that shows no evidence of bright spots outside main Tibetan '
#  'rifts ( .')
# ('53: found in OMC-1 a “polarization hole” at the position of the peak '
#  'continuum on the ridge (as found in other sources), possibly due in part to '
#  'increased optical depth there (clumps sizes smaller than the angular '
#  'resolution used), following the equation: with η =polarization efficiency '
#  '≈8% at λ 100 μ, and τ =optical depth at λ 100 μm.')
# ('54: A decade after the first reports ( , , high-velocity ( v ∼ 0.1 c ), '
#  'highly ionized winds are now established as common in low-redshift AGNs.')
# ('55: The optical counterpart ESO 243-49 HLX-1 emits an Hα emission line '
#  'establishing the object as physically associated with ESO 243-49 (  and has '
#  'a magnitude consistent with a massive star cluster ( .')
# ('56: perform a similar visual analysis of high-pass filtered information at '
#  'each scale of wavelet decomposition to identify landslide structures.')
# ('57: The acceleration time to energy E for stochastic acceleration (once '
#  'particles are relativistic) scales as (  where v A is the Alfvén speed (in '
#  'the downstream medium) and λ mfp is the scattering mean free path.')
# ('58: Models have been suggested for intermittent pulsars and RRATs (e.g., '
#  'Luo  that might be relevant to FRBs but the vastly different energetics may '
#  'make these models less relevant.')
# ('59: These values, and equivalent results obtained for a log-normal IMF, are '
#  'again similar within uncertainties to local disk values from  and .')
# ('60: Typical X-ray temperatures derived from multi-component fits to keV '
#  'spectra are similar to those in solar flares, MK (e.g., ; ; .')
# ('61: Alternatively, it might be assumed ( that the observed correlation '
#  'between MB(max) and MGa1 results, at least in part, from selection effects '
#  'that discriminate SUPERNOVA RATES 367 short intervals, whereas nearby '
#  'galaxies can be monitored less frequently.')
# ('62: showed that kaolinite is preserved at depths in excess of 4000 m, '
#  'suggesting an unusual lack of available potassium.')
# ('63: On asteroids, boulders and blocks are mainly interpreted as produced by '
#  'fragmentation of the target or its parent body in high-velocity impact '
#  'processes ( ; Michikami etal., 2008 , 2019 ).')
# ('64: Helene’s mass has recently been estimated from its perturbation of the '
#  'orbit of Dione (.')
# ('65: However, the lack of high cadence data that could catch the '
#  'brightenings/dimmings associated with early reconnection implied that they '
#  'could not rule out the tether-cutting scenario (see also Sterling and .')
# ('66: 3. GLOBAL ASTROMETRY WITH THE HIPPARCOS–<italic '
#  'toggle="yes">Gaia</italic> CONCEPT The concept for performing global '
#  'astrometry with Gaia follows the same principles that were used for the '
#  'Hipparcos mission ( ; see the sidebar titled Gaia in Brief):')
# ('67: Using a theoretical HR diagram, it is possible to derive an empirical '
#  'relation between A~f and the luminosity L (, and, going one step further, '
#  'and A~f—M relation (since for high masses, the luminosity remains '
#  'approximately constant throughout the evolution), in the form: J~f)~MI~ '
#  '2=108MoY~11 M>Mmn=20M.')
# ('68: The corresponding for an isothermal turbulent field, however, does not '
#  'have a unique functional form (Vázquez-Semadeni and .')
# ('69: There exists another class of massive objects where rotation might be '
#  'even more important: the B[e]-supergiants with a well-determined bimodal '
#  'structure (slow and dense equatorial wind and fast, thin polar wind) (for a '
#  'recent review, see .')
# ('70: In order to produce a catastrophe-like behavior,  applied a method '
#  'similar to the generating function method to the analyses.')
# ('71: Clearly, the coarser dust particles are transported near the ground and '
#  'preferentially deposited relative to the dust cloud as a whole and closer to '
#  'the source (see Fig. 9 in .')
# ('72: This is somewhat above the 95% confidence level upper limit at 1.25 μm '
#  'of  .')
# ('73: used the frequency changes of individual rotationally split components '
#  'within an () multiplet to carry out one-dimensional inversions for frequency '
#  'shifts as a function of latitude; they showed that the frequency shifts were '
#  'closely associated with regions of higher magnetic flux both as a function '
#  'of time and latitude.')
# ('74: The fast rotators span the same range of bulge fractions as spiral '
#  'galaxies ( Krajnović et al. 2013a ), like S0 galaxies ( , Kormendy , and '
#  'include some extremely flat disks.')
# ('75: Continuum linear polarization was also soon detected in the same star '
#  '(Angel and .')
# ('76: (d) the cluster should lie north of declination - 27° and within the '
#  'region of complete identification given in Table 1 of .')
# ('77: The forecasting, which is considered by  the main process of a LEWS, '
#  'includes the definition of thresholds, models and other elements necessary '
#  'to issue a warning.')
# ('78: In regard to the high multiple of 45 suggested by  for the spectrum of '
#  'the 1956 GLE to account for the 774 SEP event, this factor was later found '
#  'to be an underestimate (see Sect. 7.4.2 ).')
# ('79: Initial Discoveries of Strong Lensing Systems The first strong lens, the '
#  'double quasar 0957+561A, B, was discovered in 1979 by .')
# ('80: The FP shifts imply a decrease of the rest-frame M/L ratio Δlog M/L B ≃ '
#  '−0.46 z ( van Dokkum , but—as emphasized above— the formation redshift one '
#  'can derive from it depends on both cosmology and the IMF.')
# ('81: Collisions can result in one or more satellites over a wide range of '
#  'primary size and relative component size (.')
# ('82: An extension of this work to 20 simulated objects with an extensive '
#  'analysis of the dependence of the hydrostatic bias on cluster morphology, '
#  'environment, temperature inhomogeneity and mass is presented in .')
# ('83: DYNAMICAL CONSIDERATIONS  introduced a dynamical approach that uses only '
#  'the observed radial velocities to determine the motions of candidate group '
#  'members relative to the Local Group barycenter.')
# ('84: We are somewhat puzzled by a recently reported 275 Ma pole (  from '
#  'Siberia, since this pole plots near Triassic poles from southern Taimyr and '
#  'Europe/Baltica and its acceptance would inevitably lead to some interesting '
#  'and very radical new reconstructions between Siberia and Baltica (see '
#  'later).')
# ('85: In particular for adiabatic jets, a mass distribution M gal ∝ r −s , '
#  'with s ≤ δ, does not allow the flow to reach a transonic point: The flow is '
#  'stopped inside the galaxy ( .')
# ('86: arXiv:astro-ph/9701133 Inoue S, Aharonian FA, Sugiyama  Hard X-ray and '
#  'gamma-ray emission induced by ultrahigh-energy protons in cluster accretion '
#  'shocks.')
# ('87: These flows can also play an important part in the delivery of organic '
#  'matter and nutrients within lakes ( De .')
# ('88: Alternatively, the SgrA* spin might be low, on the grounds that there is '
#  'no evidence for strong accretion events in the last few Myrs that could have '
#  'spun up the MBH (.')
# ('89: This so-called “unification model” explains in a natural way why the '
#  '(projected) sizes of the jets of RGs are larger than those of quasars (.')
# ('90: The magnitude of the opacity variations also raises a cautionary flag '
#  'for the use of dust emission to retrieve Hi optical depths and spin '
#  'temperatures in the opaque CNM ( .')
# ('91: used the CN band head at 388.3 nm to investigate the evolution of the '
#  'photospheric network.')
# ('92: The standard spectrum of the gyrosynchrotron radiation has a bell shape, '
#  'on which some harmonic structure can be seen at the low-frequency range (; .')
# ('93: This is clearly shown by the lateral duplicate sampling performed by , '
#  'SI fig. S4) .')
# ('94: As demonstrated in M87 (W. Forman, E. Churazov, C. Jones, et al., '
#  'submitted) and Hydra A (  deeper images reveal more cavities.')
# ('95: recently proposed a compilation, in an attempt to evaluate the worldwide '
#  'sea-level change during the last interglacial stage (Marine Isotopic Stage, '
#  'MIS 5e at ~ 122 ka).')
# ('96: Astrophys J 645:1436–1447 Voss B, Koester D, Napiwotzki R, Christlieb N, '
#  'Reimers  High-resolution UVES/VLT spectra of white dwarfs observed for the '
#  'ESO SN Ia progenitor survey.')
# ('97: (c) it reached the secular resonance that took it into the terrestrial '
#  'planet region (, and')
# ('98: Data from the microwave band is a function of both terrain dielectric '
#  'properties and geometric properties, reflecting the composition and surface '
#  'characteristics ( .')
# ('99: Even prior to the  result on the potential rotationally supported plane '
#  'in M31, multiple groups continued to study the observed distribution of '
#  'satellite galaxies, their orbits, and the consistency of these with ΛCDM.')
