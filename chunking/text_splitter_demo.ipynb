# %%
import numpy as np
import pandas as pd
from semantic_text_splitter import TextSplitter
import torch
from tqdm import tqdm
from citeline.embedders import Embedder
import itertools

EMBEDDER = "Qwen/Qwen3-Embedding-0.6B"


def reconstruct_paper(example: pd.Series) -> str:
    return f"{example['title']}\n\nAbstract: {example['abstract']}\n\n{example['body']}"


sample_df = pd.read_json("../data/dataset/nontrivial_checked.jsonl", lines=True).sample(n=10, random_state=42)
target_dois = set(sample_df["citation_dois"].explode().unique())
print(f"Testing text splitter grid search on {len(target_dois)} unique DOIs")

# Get just the target DOI texts and split them
research = pd.read_json("../data/preprocessed/research.jsonl", lines=True)
research = research[research["doi"].isin(target_dois)]
research["paper"] = research.apply(reconstruct_paper, axis=1)
research["pubdate"] = research["pubdate"].apply(lambda x: int(x.replace("-", "")))

research.head()
# Out:
# Testing text splitter grid search on 13 unique DOIs
#                    bibcode                                           abstract  \
# 589    1986ApJ...303...39D  The formation of dwarf, diffuse, metal-poor ga...
# 7901   1993ApJ...410..696O  We have reduced and analyzed a set of narrow-b...
# 8463   2002AJ....123.1454B  Nearby dwarf irregular galaxies were searched ...
# 18980  1985ApJ...295...73K  Core radii and central surface brightnesses of...
# 24992  1977ApJS...34..405B  Techniques are described for constructing comp...
#
#                                                      aff  \
# 589    [Yale University, New Haven, CT; Weizmann Inst...
# 7901   [Rice Univ., Houston, TX, Rice Univ., Houston,...
# 8463   [Lowell Observatory, 1400 West Mars Hill Road,...
# 18980  [Dominion Astrophysical Observatory, Victoria,...
# 24992  [Minnesota, University, Minneapolis, Minn., Ha...
#
#                                                   author            bibstem  \
# 589                                [Dekel, A., Silk, J.]   [ApJ, ApJ...303]
# 7901              [O'Dell, C. R., Wen, Zheng, Hu, Xihai]   [ApJ, ApJ...410]
# 8463   [Billett, Olivia H., Hunter, Deidre A., Elmegr...    [AJ, AJ....123]
# 18980                                     [Kormendy, J.]   [ApJ, ApJ...295]
# 24992                       [Black, J. H., Dalgarno, A.]  [ApJS, ApJS...34]
#
#        doctype             doi        id   pubdate  \
# 589    article  10.1086/164050   1621141  19860401
# 7901   article  10.1086/172786   1876038  19930601
# 8463   article  10.1086/339181  11740864  20020301
# 18980  article  10.1086/163350   1589567  19850801
# 24992  article  10.1086/190455   1365218  19770701
#
#                                                    title  ...  \
# 589    The Origin of Dwarf Galaxies, Cold Dark Matter...  ...
# 7901   Discovery of New Objects in the Orion Nebula o...  ...
# 8463   Compact Star Clusters in Nearby Dwarf Irregula...  ...
# 18980  Families of ellipsoidal stellar systems and th...  ...
# 24992  Models of interstellar clouds. I. The Zeta Oph...  ...
#
#                                                reference  \
# 589    [1961AJ.....66..249H, 1961AJ.....66..384H, 196...
# 7901   [1954TrSht..25....1P, 1958AnDea...7...67S, 195...
# 8463   [1952PASP...64..196G, 1955ApJ...121..161S, 195...
# 18980  [1966AJ.....71...64K, 1970ApJ...160..811F, 197...
# 24992  [1949MNRAS.109..698B, 1951ApJ...113..441B, 195...
#
#                                      data citation_count  \
# 589                   [NED:10, SIMBAD:10]           1975
# 7901            [ESA:1, SIMBAD:26, hst:1]            366
# 8463   [ESA:1, NED:91, SIMBAD:100, hst:1]            126
# 18980                 [NED:30, SIMBAD:35]            553
# 24992                                None            445
#
#                                                 citation  \
# 589    [1986A&A...168...81C, 1986AJ.....92..580A, 198...
# 7901   [1993RMxAA..27...55O, 1993RMxAA..27..153H, 199...
# 8463   [2002A&A...390..481V, 2002AJ....124.1393L, 200...
# 18980  [1985AJ.....90.2221O, 1985ApJ...299..881T, 198...
# 24992  [1977ApJ...217L.109C, 1977ApJS...35..281T, 197...
#
#                                                     body  \
# 589    O'Q! 00 00 o oo KO 00 O'! ^ The Astrophysical ...
# 7901   Ti~w ASTROPHYSICAL JOURNAL, 410:696-700, 1993 ...
# 8463   1. INTRODUCTION The properties of super–star c...
# 18980  1985ApJ. . .295. . .73K The Astrophysical Jour...
# 24992  197 7 Ap J S ... 34. .405B The Astrophysical J...
#
#                                                     dois  \
# 589                                     [10.1086/164050]
# 7901                                    [10.1086/172786]
# 8463   [10.1086/339181, 10.48550/arXiv.astro-ph/0112260]
# 18980                                   [10.1086/163350]
# 24992                                   [10.1086/190455]
#
#                                                 keywords  \
# 589    [Abundance, Cold Plasmas, Dark Matter, Dwarf G...
# 7901   [Herbig-Haro Objects, Hubble Space Telescope, ...
# 8463   [Galaxies: Formation, Galaxies: Irregular, Gal...
# 18980  [Disk Galaxies, Dwarf Galaxies, Elliptical Gal...
# 24992  [Abundance, Astronomical Models, Hydrogen Clou...
#
#                             loaded_from  \
# 589       data/json/Astro_Research.json
# 7901   data/json/salvaged_articles.json
# 8463   data/json/salvaged_articles.json
# 18980  data/json/salvaged_articles.json
# 24992  data/json/salvaged_articles.json
#
#                                           body_sentences  \
# 589    [O'Q!  00 00 o oo KO 00 O'!, ^ The Astrophysic...
# 7901   [Ti~w ASTROPHYSICAL JOURNAL, 410:696-700, 1993...
# 8463   [1. INTRODUCTION The properties of super–star ...
# 18980  [1985ApJ.  .  .295.  ., .73K The Astrophysical...
# 24992  [197 7 Ap J S ... 34. .405B The Astrophysical ...
#
#                                                    paper
# 589    The Origin of Dwarf Galaxies, Cold Dark Matter...
# 7901   Discovery of New Objects in the Orion Nebula o...
# 8463   Compact Star Clusters in Nearby Dwarf Irregula...
# 18980  Families of ellipsoidal stellar systems and th...
# 24992  Models of interstellar clouds. I. The Zeta Oph...
#
# [5 rows x 21 columns]

# %%
# Set up embedder
device = "cuda" if torch.cuda.is_available() else "mps" if torch.mps.is_available() else "cpu"
embedder = Embedder.create(EMBEDDER, device=device, normalize=True)

# %%
def chunk_text(text: str, splitter: TextSplitter) -> list[str]:
    chunks = splitter.chunks(text)
    chunks = [stripped_chunk.replace("\x00", "") for chunk in chunks if (stripped_chunk := chunk.strip())]
    return chunks


tqdm.pandas()
splitter = TextSplitter((200, 400), overlap=50, trim=True)
research["chunks"] = research["paper"].progress_apply(lambda x: chunk_text(x, splitter))
# Out:
# 100%|██████████| 13/13 [00:00<00:00, 720.54it/s]

# %%
print(f"The dataset is {len(research)} rows long, one for each paper.")
print(f"Total number of chunks: {research['chunks'].str.len().sum()}")
research = research.explode("chunks")
print(f"After exploding, the dataset is {len(research)} rows long, one for each chunk.")
# Out:
# The dataset is 13 rows long, one for each paper.
# Total number of chunks: 3122
# After exploding, the dataset is 3122 rows long, one for each chunk.

# %%
len(research)
# Out:
# 3122

# %%
min_lengths = np.arange(50, 1001, 50)
increments = np.arange(50, 1001, 50)
overlaps = np.arange(0, 201, 25)
results = np.zeros((len(overlaps), len(min_lengths), len(increments)))
for min_len, increment, overlap in itertools.product(min_lengths, increments, overlaps):
    overlap = min(min_len - 1, overlap)  # ensure overlap is not greater than min_len
    print(f"Processing min_length={min_len}, increment={increment}, overlap={overlap}...")
    splitter = TextSplitter((min_len, min_len + increment), overlap=overlap, trim=True)
    tqdm.pandas(desc=f"Chunking papers (min_len={min_len}, max_len={min_len + increment}, overlap={overlap})")
    research["chunks"] = research["paper"].progress_apply(lambda x: chunk_paper(x, splitter))
