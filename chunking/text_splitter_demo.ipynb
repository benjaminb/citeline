# %%
import numpy as np
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt

df = pd.read_json("../data/preprocessed/research.jsonl", lines=True, nrows=1000)

np.random.seed(1)
sample_df = df.sample(3)
sample_df
# Out:
#                  bibcode                                           abstract  \
# 507  2007MNRAS.379.1599L  We describe the goals, design, implementation,...
# 818  1994MNRAS.271..676L  We have made a detailed comparison of the resu...
# 452  2020ApJ...900..179K  To reach a deeper understanding of the origin ...
#
#                                                    aff  \
# 507  [Institute for Astronomy, SUPA (Scottish Unive...
# 818                                             [-, -]
# 452  [Centre for Astrophysics Research, Department ...
#
#                                                 author             bibstem  \
# 507  [Lawrence, A., Warren, S. J., Almaini, O., Edg...  [MNRAS, MNRAS.379]
# 818                              [Lacey, C., Cole, S.]  [MNRAS, MNRAS.271]
# 452  [Kobayashi, Chiaki, Karakas, Amanda I., Lugaro...    [ApJ, ApJ...900]
#
#      doctype                               doi        id     pubdate  \
# ...

# %%
from semantic_text_splitter import TextSplitter

splitter = TextSplitter((100, 1000), trim=False)
chunks = [splitter.chunks(sample_df.iloc[i]['body']) for i in range(len(sample_df))]

# %%
from pprint import pprint
ch = chunks[0]
for chunk in ch:
    pprint(chunk)
    print()
# Out:
# ('1 INTRODUCTION The UKIRT Infrared Deep Sky Survey (UKIDSS) can be considered '
#  'the near-infrared (near-IR) counterpart of the Sloan Digital Sky Survey '
#  '(SDSS; York et al. ')
#
# ('2000). It does not cover the whole sky, but is many times deeper than the '
#  'Two-Micron All-Sky Survey (2MASS; Skrutskie et al. ')
#
# ('2006). It is in fact not a single survey but a survey programme combining a '
#  'set of five survey components of complementary combinations of depth and '
#  'area, covering several thousand square degrees to , 35 deg 2 to , and 0.77 '
#  'deg 2 to . ')
#
# ('The survey uses the Wide Field Camera (WFCAM) on the 3.8-m United Kingdom '
#  'Infra-red Telescope (UKIRT). ')
#
# ('WFCAM has an instantaneous field of view of 0.21 deg 2 , considerably larger '
#  'than any previous IR camera on a 4-m class telescope, along with a pixel '
#  'size of 0.4 arcsec. ')
#
# ('The tip-tilt system on UKIRT delivers close to natural seeing (median size '
# ...
